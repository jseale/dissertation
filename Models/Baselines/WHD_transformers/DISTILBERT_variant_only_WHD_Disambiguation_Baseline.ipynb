# %% [markdown]
# # Description
# Trains and evaluates DistilBert token classification model with variant-only Wikipedia Homograph data only; one model for all labels.

# %% [markdown]
# ### Imports

# %%
import os
import sys
import logging
from pathlib import Path
import re
from glob import glob
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
from typing import List, Dict, Tuple, TextIO
from transformers import AutoTokenizer, AutoModelForTokenClassification, BertForTokenClassification, DistilBertForTokenClassification
from transformers import BertTokenizerFast, DistilBertTokenizerFast, EvalPrediction
from transformers import Trainer, TrainingArguments
from transformers import AdamW
from transformers import DistilBertConfig
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, balanced_accuracy_score, f1_score, roc_auc_score, precision_score, recall_score
#from seqeval.metrics import accuracy_score, f1_score, precision_score, recall_score
#from pytorch_lightning.metrics.functional.classification import accuracy

# %% [markdown]
# ### Variables

# %%
#Paths 
WHD_BERT_DATA = "C:/Users/jseal/Dev/dissertation/Data/WHD_Bert/variant_only/"
WHD = 'C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/'

#Txt splits
TRAIN_TXT = WHD_BERT_DATA + "train.txt"
DEV_TXT = WHD_BERT_DATA + "dev.txt"
TEST_TXT = WHD_BERT_DATA + "test.txt"

#Logging path
LOGS = "./whd_variant_only_logs"

#Labels file
LABELS = WHD_BERT_DATA + "labels.txt"

#Homographs
#whd_df = pd.read_csv(WHD + 'WikipediaHomographData.csv')
#homographs = whd_df.drop_duplicates(subset='homograph')['homograph'].tolist()

# Model Variables
MAX_LENGTH = 128 #@param {type: "integer"}
BATCH_SIZE = 16 #@param {type: "integer"}
NUM_EPOCHS = 3 #@param {type: "integer"}
SAVE_STEPS = 100 #@param {type: "integer"}
LOGGING_STEPS = 100 #@param {type: "integer"}
SEED_1 = 15
SEED = 42 #@param {type: "integer"}
STEPS = "steps"
EVAL_STEPS = 100
WARMUP_STEPS = 500
WEIGHT_DECAY = 0.01

MODEL_NAME = "distilbert-base-cased"
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
print(device)

logger = logging.getLogger(__name__)
# Out:
# cuda:0

# %% [markdown]
# ### Functions & classes

# %%
def read_set(file_path):
    file_path = Path(file_path)

    raw_text = file_path.read_text(encoding="utf8").strip()
    raw_docs = re.split(r'\n\t?\n', raw_text)
    token_docs = []
    tag_docs = []
    for doc in raw_docs:
        tokens = []
        tags = []
        for line in doc.split('\n'):
            token, tag = line.split('\t')
            tokens.append(token)
            tags.append(tag)
        token_docs.append(tokens)
        tag_docs.append(tags)

    return token_docs, tag_docs

def encode_tags(tags, encodings):
    labels = [[tag2id[tag] for tag in doc] for doc in tags]
    encoded_labels = []
    for doc_labels, doc_offset in zip(labels, encodings.offset_mapping):
        # create an empty array of -100
        doc_enc_labels = np.ones(len(doc_offset),dtype=int) * -100
        arr_offset = np.array(doc_offset)

        # set labels whose first offset position is 0 and the second is not 0
        doc_enc_labels[(arr_offset[:,0] == 0) & (arr_offset[:,1] != 0)] = doc_labels
        encoded_labels.append(doc_enc_labels.tolist())

    return encoded_labels

class WHDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
       # self.tokenizer = tokenizer
        
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)
    
def align_predictions(predictions: np.ndarray, 
                      label_ids: np.ndarray) -> Tuple[List[int], List[int], List[str]]:
    preds = np.argmax(predictions, axis=2)

    batch_size, seq_len = preds.shape

    out_label_list = [[] for _ in range(batch_size)]
    preds_list = [[] for _ in range(batch_size)]

    for i in range(batch_size):
        for j in range(seq_len):
            if label_ids[i, j] != nn.CrossEntropyLoss().ignore_index:
                out_label_list[i].append(id2tag[label_ids[i][j]])
                preds_list[i].append(id2tag[preds[i][j]])
    return preds_list, out_label_list

def homograph_check(preds_list, out_label_list):
    '''Check that predictions to be evaluated are homographs, 
    not tokens from the sentence provided as context.'''
    pred_labels = zip(preds_list, out_label_list)
    unique_tags = [label.strip("\n") for label in open(LABELS).readlines()]
    preds = []
    labels = []
    for e in pred_labels:
        pred_label_pair = zip(e[0], e[1])
        for pred, label in pred_label_pair:
            if label is not 'O':
                preds.append(pred)
                labels.append(label)
    return labels, preds
    
def compute_metrics(p: EvalPrediction) -> Dict:
    '''Only compute metrics on homograph pronunciation predictions'''
    preds_list, labels_list = align_predictions(p.predictions, p.label_ids)
    targets, preds = homograph_check(preds_list, labels_list)
#     preds = [tag2id[pred] for pred in preds]
#     targets = [tag2id[target] for target in targets]
#     preds = torch.as_tensor(preds)
#     targets = torch.as_tensor(targets)
    return {
        "accuracy_score": accuracy_score(targets, preds),
        "balanced_accuracy_score": balanced_accuracy_score(targets, preds),
        #"micro_auc_roc": roc_auc_score(targets, preds, average='micro')
#         "micro_accuracy": accuracy(preds, targets, class_reduction='micro', num_classes=len(unique_tags)),
#         "macro_accuracy": accuracy(preds, targets, class_reduction='macro', num_classes=len(unique_tags)),
    }

def write_predictions_to_file(writer: TextIO, test_input_reader: TextIO, preds_list: List):
    example_id = 0
    for line in test_input_reader:
        if line.startswith("-DOCSTART-") or line == "" or line == "\n":
            writer.write(line)
            if not preds_list[example_id]:
                example_id += 1
        elif preds_list[example_id]:
            output_line = line.split()[0] + " " + preds_list[example_id].pop(0) + "\n"
            writer.write(output_line)
        else:
            logger.warning("Maximum sequence length exceeded: No prediction for '%s'.", line.split()[0])

# %% [markdown]
# # Script

# %%
#Get unique labels, enumeration/IDs, and make mappings
unique_tags = [label.strip("\n") for label in open(LABELS).readlines()]
tag2id = {tag: id for id, tag in enumerate(unique_tags)}
id2tag = {id: tag for tag, id in tag2id.items()}

# %%
#Make separate lists of aligned texts and tags
train_texts, train_tags = read_set(TRAIN_TXT)
dev_texts, dev_tags = read_set(DEV_TXT)
test_texts, test_tags = read_set(TEST_TXT)

# %%
#Make encodings for text 
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-cased')
train_encodings = tokenizer(train_texts, is_split_into_words=True, return_offsets_mapping=True, padding=True, truncation=True)
dev_encodings = tokenizer(dev_texts, is_split_into_words=True, return_offsets_mapping=True, padding=True, truncation=True)

# %%
#Make encodings for labels
train_labels = encode_tags(train_tags, train_encodings)
dev_labels = encode_tags(dev_tags, dev_encodings)

# %%
#Make datasets
train_encodings.pop("offset_mapping") # don't want to pass this to the model
dev_encodings.pop("offset_mapping")
train_dataset = WHDataset(train_encodings, train_labels)
dev_dataset = WHDataset(dev_encodings, dev_labels)
#print(dev_dataset[0])

# %%
#Instantiate model, training args and trainer; train and evaluate
# config = DistilBertConfig.from_pretrained(MODEL_NAME, 
#                                           output_hidden_states=True, 
#                                           #idx2label=id2tag, 
#                                           num_labels=len(unique_tags))
# model = DistilBertForTokenClassification.from_pretrained(MODEL_NAME,config=config)
model = DistilBertForTokenClassification.from_pretrained(MODEL_NAME,
                                                         num_labels=len(unique_tags))
model.to(device)

training_args = TrainingArguments(
    load_best_model_at_end=True,
    output_dir='./whd-variant-only-model',    # output directory
    num_train_epochs=NUM_EPOCHS,              # total # of training epochs
    per_device_train_batch_size=BATCH_SIZE,   # batch size per device during training
    per_device_eval_batch_size=BATCH_SIZE,    # batch size for evaluation
    warmup_steps=WARMUP_STEPS,                # number of warmup steps for learning rate scheduler
    weight_decay=WEIGHT_DECAY,                # strength of weight decay
    logging_dir=LOGS,                         # directory for storing logs
    evaluation_strategy=STEPS,
    eval_steps=EVAL_STEPS,
    seed=SEED_1,
    overwrite_output_dir=True,
)

trainer = Trainer(
    model=model,                         # instantiated Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=dev_dataset,            # evaluation dataset
    compute_metrics=compute_metrics
)

trainer.train()
trainer.evaluate()
# Out:
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForTokenClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='2172' max='2172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2172/2172 04:40, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy Score</th>
#       <th>Balanced Accuracy Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.624773</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.444250</td>
#       <td>0.006834</td>
#       <td>0.004255</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.298110</td>
#       <td>0.183751</td>
#       <td>0.136855</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.157770</td>
#       <td>0.696279</td>
#       <td>0.518739</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.028181</td>
#       <td>0.092436</td>
#       <td>0.801063</td>
#       <td>0.600998</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.028181</td>
#       <td>0.071331</td>
#       <td>0.821564</td>
#       <td>0.637587</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.028181</td>
#       <td>0.057945</td>
#       <td>0.859529</td>
#       <td>0.689034</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.028181</td>
#       <td>0.048776</td>
#       <td>0.877752</td>
#       <td>0.716197</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.028181</td>
#       <td>0.043806</td>
#       <td>0.899013</td>
#       <td>0.763355</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.064223</td>
#       <td>0.037140</td>
#       <td>0.903569</td>
#       <td>0.782982</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.064223</td>
#       <td>0.034309</td>
#       <td>0.918755</td>
#       <td>0.807801</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.064223</td>
#       <td>0.032363</td>
#       <td>0.928626</td>
#       <td>0.827834</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.064223</td>
#       <td>0.030967</td>
#       <td>0.933181</td>
#       <td>0.840125</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.064223</td>
#       <td>0.029598</td>
#       <td>0.936978</td>
#       <td>0.853291</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.030910</td>
#       <td>0.028254</td>
#       <td>0.935459</td>
#       <td>0.853901</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.030910</td>
#       <td>0.028796</td>
#       <td>0.945330</td>
#       <td>0.874956</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.030910</td>
#       <td>0.026369</td>
#       <td>0.940774</td>
#       <td>0.865387</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.030910</td>
#       <td>0.026455</td>
#       <td>0.946849</td>
#       <td>0.877899</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.030910</td>
#       <td>0.026412</td>
#       <td>0.949127</td>
#       <td>0.881464</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.018080</td>
#       <td>0.025762</td>
#       <td>0.949886</td>
#       <td>0.885399</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.018080</td>
#       <td>0.024990</td>
#       <td>0.947608</td>
#       <td>0.882030</td>
#     </tr>
#   </tbody>
# </table><p>
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='162' max='81' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [81/81 00:03]
#     </div>
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# {'eval_loss': 0.024989990517497063,
#  'eval_accuracy_score': 0.9476082004555809,
#  'eval_balanced_accuracy_score': 0.8820297196892942,
#  'epoch': 3.0,
#  'total_flos': 1132382659351500}

# %%
from statistics import mean 
predictions, label_ids, metrics = trainer.predict(dev_dataset)
preds_list, targets_list = align_predictions(predictions, label_ids)
targets_list, preds_list = homograph_check(preds_list, targets_list)

output_results_file = os.path.join(training_args.output_dir, "results.txt")
if trainer.is_world_master():
    with open(output_results_file, "w", encoding="utf8") as writer:
        for key, value in metrics.items():
            logger.info("  %s = %s", key, value)
            writer.write("%s = %s\n" % (key, value))

# Save predictions
#output_predictions_file = os.path.join(training_args.output_dir, "predictions.txt")
to_df = zip(preds_list, targets_list)
print('Micro Accuracy')
df = pd.DataFrame(to_df, columns=['Preds', 'Targets'])
df_correct = df[df['Preds'] == df['Targets']]
print(len(df_correct)/len(df))
print('Macro Accuracy')
group_accuracies_for_mean = []
group_accuracies = []
for idx, group in df.groupby('Targets'):
    grp = {}
    grp["wordid"] = idx
    print(idx)
    correct = group[group['Preds'] == group['Targets']]
    accuracy = len(correct)/len(group)
    print(accuracy)
    grp["accuracy"] = accuracy
    group_accuracies.append(grp)
    group_accuracies_for_mean.append(accuracy)
print(mean(group_accuracies_for_mean))
accuracies_df = pd.DataFrame(group_accuracies)
# Out:
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\sklearn\metrics\_classification.py:1814: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# Micro Accuracy
# 0.9476082004555809
# Macro Accuracy
# abstract_adj-nou
# 1.0
# abuse_nou
# 0.7777777777777778
# abuses_nou
# 1.0
# abuses_vrb
# 1.0
# advocate_nou
# 1.0
# advocate_vrb
# 1.0
# affect
# 1.0
# affiliate_nou
# 1.0
# affiliate_vrb
# 0.0
# aged
# 1.0
# aggregate_adj-nou
# 1.0
# aggregate_vrb
# 1.0
# alternate_adj-nou
# 1.0
# alternate_vrb
# 0.0
# analyses_nou
# 0.8888888888888888
# animate_adj-nou
# 1.0
# animate_vrb
# 0.8333333333333334
# appropriate_adj
# 0.7777777777777778
# approximate_adj-nou
# 1.0
# approximate_vrb
# 1.0
# articulate_adj
# 1.0
# articulate_vrb
# 1.0
# associate_adj-nou
# 1.0
# associate_vrb
# 1.0
# attribute_nou
# 1.0
# attribute_vrb
# 1.0
# august
# 1.0
# august_nam
# 0.0
# axes_nou
# 1.0
# axes_nou-vrb
# 1.0
# bass
# 1.0
# bass_corp
# 1.0
# blessed_adj
# 1.0
# blessed_vrb
# 1.0
# bologna
# 0.0
# bologna_geo
# 1.0
# bow_nou-knot
# 0.6
# bow_nou-ship
# 0.8
# buffet_nou
# 1.0
# buffet_vrb
# 0.0
# celtic
# 1.0
# celtic_adj-nou-sports
# 1.0
# close_adj-nou
# 1.0
# close_vrb
# 0.0
# combine_vrb
# 1.0
# compound_nou
# 0.8888888888888888
# compress
# 0.8888888888888888
# conduct_nou
# 1.0
# conduct_vrb
# 1.0
# confines_nou
# 1.0
# confines_vrb
# 1.0
# conflict_nou
# 1.0
# conjugate_adj-nou
# 1.0
# conscript_nou
# 0.8888888888888888
# console_nou
# 1.0
# construct_vrb
# 1.0
# consummate_adj
# 1.0
# consummate_vrb
# 1.0
# content_nou
# 1.0
# contest_nou
# 1.0
# contest_vrb
# 1.0
# contract_nou
# 0.8888888888888888
# contrast_nou
# 1.0
# converse_adj-nou
# 1.0
# converse_vrb
# 1.0
# convert_vrb
# 0.8888888888888888
# convict_nou
# 0.875
# convict_vrb
# 1.0
# coordinate_adj-nou
# 1.0
# coordinate_vrb
# 0.8333333333333334
# correlate_nou-vrb
# 1.0
# decrease_nou
# 1.0
# decrease_vrb
# 1.0
# defect_nou
# 1.0
# degenerate_adj-nou
# 1.0
# degenerate_vrb
# 1.0
# delegate_nou
# 1.0
# deliberate_adj
# 1.0
# deviate_vrb
# 1.0
# diagnoses_nou
# 0.875
# diagnoses_vrb
# 1.0
# diffuse_adj
# 1.0
# diffuse_vrb
# 1.0
# discard_nou
# 1.0
# discard_vrb
# 1.0
# discharge_nou
# 1.0
# discharge_vrb
# 1.0
# discount_nou
# 1.0
# document_nou
# 1.0
# document_vrb
# 1.0
# dove
# 1.0
# duplicate_adj-nou
# 1.0
# duplicate_vrb
# 1.0
# escort_nou
# 1.0
# escort_vrb
# 1.0
# estimate_nou
# 1.0
# estimate_vrb
# 1.0
# excuse_nou
# 1.0
# excuse_vrb
# 1.0
# expatriate_nou
# 1.0
# exploit_vrb
# 1.0
# export_nou
# 0.7777777777777778
# expose_nou
# 0.0
# expose_vrb
# 1.0
# extract_nou
# 1.0
# extract_vrb
# 1.0
# fragment_nou
# 1.0
# frequent_adj
# 1.0
# graduate_adj-nou
# 1.0
# graduate_vrb
# 0.0
# house_nou
# 0.8888888888888888
# impact_nou
# 1.0
# implant_nou
# 1.0
# implement_nou
# 1.0
# implement_vrb
# 1.0
# import_nou
# 0.8571428571428571
# import_vrb
# 1.0
# incline_nou
# 1.0
# increase_nou
# 1.0
# increase_vrb
# 1.0
# increment_nou
# 1.0
# increment_vrb
# 0.0
# initiate_nou
# 1.0
# initiate_vrb
# 1.0
# insert_nou
# 1.0
# insert_vrb
# 1.0
# insult_nou
# 1.0
# insult_vrb
# 1.0
# intrigue_nou
# 1.0
# invalid_adj
# 1.0
# invalid_nou
# 1.0
# invert_adj-nou
# 0.6666666666666666
# invert_vrb
# 0.8333333333333334
# invite_nou
# 1.0
# invite_vrb
# 1.0
# isolate
# 1.0
# isolate_nou
# 1.0
# jesus
# 1.0
# laminate_nou
# 1.0
# lead_nou
# 1.0
# lead_nou-vrb
# 0.75
# learned_adj
# 0.0
# learned_vrb
# 1.0
# live_adj
# 1.0
# live_vrb
# 1.0
# lives_nou
# 1.0
# lives_vrb
# 1.0
# mate
# 1.0
# minute
# 1.0
# minute_adj
# 1.0
# misuse_nou
# 1.0
# misuse_vrb
# 0.0
# mobile
# 1.0
# moderate_adj-nou
# 0.8888888888888888
# nestle_nam
# 1.0
# nestle_vrb
# 1.0
# ornament_nou
# 1.0
# overthrow_nou
# 0.6666666666666666
# overthrow_vrb
# 1.0
# pasty_adj
# 1.0
# pasty_nou
# 0.3333333333333333
# perfect_adj
# 1.0
# perfume_nou
# 1.0
# permit_nou
# 1.0
# permit_vrb
# 1.0
# pervert_nou
# 1.0
# polish_geo
# 1.0
# postulate_nou
# 1.0
# postulate_vrb
# 1.0
# precipitate_adj-nou
# 1.0
# precipitate_vrb
# 1.0
# predicate_nou
# 1.0
# present_adj-nou
# 1.0
# produce_nou
# 0.0
# produce_vrb
# 1.0
# progress_nou
# 1.0
# progress_vrb
# 1.0
# project_nou
# 1.0
# protest_nou
# 0.875
# protest_vrb
# 1.0
# ravel_nam
# 1.0
# ravel_nou
# 0.0
# read_past
# 0.6666666666666666
# read_present
# 1.0
# reading_en
# 1.0
# rebel_nou
# 0.8888888888888888
# record_nou
# 1.0
# record_vrb
# 0.5
# recount_nou
# 1.0
# recount_vrb
# 1.0
# refund_nou
# 1.0
# refund_vrb
# 1.0
# refuse_nou
# 1.0
# refuse_vrb
# 1.0
# reject_nou
# 0.0
# reject_vrb
# 1.0
# rerelease
# 1.0
# rerelease_vrb
# 1.0
# resume_vrb
# 0.8888888888888888
# retard_nou
# 1.0
# retard_vrb
# 1.0
# rodeo
# 1.0
# sake
# 1.0
# sake_jp
# 0.0
# separate_adj
# 0.8571428571428571
# separate_vrb
# 0.0
# sow
# 1.0
# sow_nou
# 1.0
# subordinate_adj-nou
# 1.0
# subordinate_vrb
# 0.0
# supplement_nou
# 1.0
# supplement_vrb
# 1.0
# suspect_adj-nou
# 1.0
# suspect_vrb
# 1.0
# syndicate_nou
# 1.0
# syndicate_vrb
# 0.0
# tear_nou
# 1.0
# tear_vrb
# 1.0
# transform
# 1.0
# transform_nou
# 1.0
# transplant_nou
# 1.0
# transplant_vrb
# 0.0
# transport_nou
# 1.0
# upset_nou
# 0.8571428571428571
# upset_vrb
# 1.0
# use_nou
# 1.0
# use_vrb
# 0.6666666666666666
# uses_nou
# 1.0
# uses_vrb
# 0.875
# wind_nou
# 1.0
# wind_vrb
# 0.0
# winds_nou
# 1.0
# winds_vrb
# 0.0
# wound_nou-vrb
# 0.8333333333333334
# wound_vrb
# 1.0
# 0.8820297196892941
# C:\Users\jseal\anaconda3\envs\dissertation_huggingface\lib\site-packages\transformers\trainer.py:1118: FutureWarning: This method is deprecated, use `Trainer.is_world_process_zero()` instead.
#   warnings.warn("This method is deprecated, use `Trainer.is_world_process_zero()` instead.", FutureWarning)

# %%
output_predictions_file = os.path.join('./whd-variant-only-model', "predictions.txt")

# %%
output_predictions_file
# Out:
# './whd-variant-only-model\\predictions.txt'

# %%
pd.set_option('display.max_rows', None)

# %%
accuracies_df.sort_values("accuracy")
# Out:
#                     wordid  accuracy
# 215          syndicate_vrb  0.000000
# 173            produce_nou  0.000000
# 27              august_nam  0.000000
# 102             expose_nou  0.000000
# 151             misuse_vrb  0.000000
# 221         transplant_vrb  0.000000
# 181              ravel_nou  0.000000
# 209        subordinate_vrb  0.000000
# 109           graduate_vrb  0.000000
# 13           alternate_vrb  0.000000
# 34                 bologna  0.000000
# 39              buffet_vrb  0.000000
# 8            affiliate_vrb  0.000000
# 141            learned_adj  0.000000
# 203                sake_jp  0.000000
# 43               close_vrb  0.000000
# 230               wind_vrb  0.000000
# 121          increment_vrb  0.000000
# 232              winds_vrb  0.000000
# 205           separate_vrb  0.000000
# 194             reject_nou  0.000000
# 160              pasty_nou  0.333333
# 187             record_vrb  0.500000
# 36            bow_nou-knot  0.600000
# 182              read_past  0.666667
# 131         invert_adj-nou  0.666667
# 226                use_vrb  0.666667
# 157          overthrow_nou  0.666667
# 140           lead_nou-vrb  0.750000
# 101             export_nou  0.777778
# 1                abuse_nou  0.777778
# 17         appropriate_adj  0.777778
# 37            bow_nou-ship  0.800000
# 233          wound_nou-vrb  0.833333
# 132             invert_vrb  0.833333
# 69          coordinate_vrb  0.833333
# 16             animate_vrb  0.833333
# 115             import_nou  0.857143
# 204           separate_adj  0.857143
# 223              upset_nou  0.857143
# 178            protest_nou  0.875000
# 228               uses_vrb  0.875000
# 79           diagnoses_nou  0.875000
# 66             convict_nou  0.875000
# 61            contract_nou  0.888889
# 153       moderate_adj-nou  0.888889
# 110              house_nou  0.888889
# 65             convert_vrb  0.888889
# 53           conscript_nou  0.888889
# 185              rebel_nou  0.888889
# 14            analyses_nou  0.888889
# 45            compound_nou  0.888889
# 46                compress  0.888889
# 198             resume_vrb  0.888889
# 158          overthrow_vrb  1.000000
# 148                 minute  1.000000
# 149             minute_adj  1.000000
# 150             misuse_nou  1.000000
# 220         transplant_nou  1.000000
# 152                 mobile  1.000000
# 219          transform_nou  1.000000
# 159              pasty_adj  1.000000
# 161            perfect_adj  1.000000
# 147                   mate  1.000000
# 217               tear_vrb  1.000000
# 154             nestle_nam  1.000000
# 155             nestle_vrb  1.000000
# 156           ornament_nou  1.000000
# 216               tear_nou  1.000000
# 214          syndicate_nou  1.000000
# 218              transform  1.000000
# 197          rerelease_vrb  1.000000
# 146              lives_vrb  1.000000
# 133             invite_nou  1.000000
# 134             invite_vrb  1.000000
# 135                isolate  1.000000
# 136            isolate_nou  1.000000
# 137                  jesus  1.000000
# 138           laminate_nou  1.000000
# 231              winds_nou  1.000000
# 222          transport_nou  1.000000
# 139               lead_nou  1.000000
# 227               uses_nou  1.000000
# 225                use_nou  1.000000
# 142            learned_vrb  1.000000
# 224              upset_vrb  1.000000
# 143               live_adj  1.000000
# 144               live_vrb  1.000000
# 145              lives_nou  1.000000
# 229               wind_nou  1.000000
# 162            perfume_nou  1.000000
# 164             permit_vrb  1.000000
# 165            pervert_nou  1.000000
# 184             reading_en  1.000000
# 206                    sow  1.000000
# 202                   sake  1.000000
# 201                  rodeo  1.000000
# 186             record_nou  1.000000
# 188            recount_nou  1.000000
# 189            recount_vrb  1.000000
# 190             refund_nou  1.000000
# 191             refund_vrb  1.000000
# 192             refuse_nou  1.000000
# 193             refuse_vrb  1.000000
# 200             retard_vrb  1.000000
# 199             retard_nou  1.000000
# 195             reject_vrb  1.000000
# 196              rerelease  1.000000
# 183           read_present  1.000000
# 207                sow_nou  1.000000
# 208    subordinate_adj-nou  1.000000
# 210         supplement_nou  1.000000
# 166             polish_geo  1.000000
# 167          postulate_nou  1.000000
# 168          postulate_vrb  1.000000
# 169    precipitate_adj-nou  1.000000
# 170        precipitate_vrb  1.000000
# 171          predicate_nou  1.000000
# 172        present_adj-nou  1.000000
# 163             permit_nou  1.000000
# 213            suspect_vrb  1.000000
# 174            produce_vrb  1.000000
# 175           progress_nou  1.000000
# 176           progress_vrb  1.000000
# 177            project_nou  1.000000
# 211         supplement_vrb  1.000000
# 179            protest_vrb  1.000000
# 180              ravel_nam  1.000000
# 212        suspect_adj-nou  1.000000
# 0         abstract_adj-nou  1.000000
# 117            incline_nou  1.000000
# 129            invalid_adj  1.000000
# 35             bologna_geo  1.000000
# 38              buffet_nou  1.000000
# 40                  celtic  1.000000
# 41   celtic_adj-nou-sports  1.000000
# 42           close_adj-nou  1.000000
# 44             combine_vrb  1.000000
# 47             conduct_nou  1.000000
# 48             conduct_vrb  1.000000
# 49            confines_nou  1.000000
# 50            confines_vrb  1.000000
# 33             blessed_vrb  1.000000
# 51            conflict_nou  1.000000
# 54             console_nou  1.000000
# 55           construct_vrb  1.000000
# 56          consummate_adj  1.000000
# 57          consummate_vrb  1.000000
# 58             content_nou  1.000000
# 59             contest_nou  1.000000
# 60             contest_vrb  1.000000
# 62            contrast_nou  1.000000
# 63        converse_adj-nou  1.000000
# 64            converse_vrb  1.000000
# 52       conjugate_adj-nou  1.000000
# 67             convict_vrb  1.000000
# 32             blessed_adj  1.000000
# 30                    bass  1.000000
# 2               abuses_nou  1.000000
# 3               abuses_vrb  1.000000
# 4             advocate_nou  1.000000
# 5             advocate_vrb  1.000000
# 6                   affect  1.000000
# 7            affiliate_nou  1.000000
# 9                     aged  1.000000
# 10       aggregate_adj-nou  1.000000
# 11           aggregate_vrb  1.000000
# 12       alternate_adj-nou  1.000000
# 31               bass_corp  1.000000
# 15         animate_adj-nou  1.000000
# 19         approximate_vrb  1.000000
# 20          articulate_adj  1.000000
# 21          articulate_vrb  1.000000
# 22       associate_adj-nou  1.000000
# 23           associate_vrb  1.000000
# 24           attribute_nou  1.000000
# 25           attribute_vrb  1.000000
# 26                  august  1.000000
# 28                axes_nou  1.000000
# 29            axes_nou-vrb  1.000000
# 18     approximate_adj-nou  1.000000
# 68      coordinate_adj-nou  1.000000
# 70       correlate_nou-vrb  1.000000
# 71            decrease_nou  1.000000
# 100            exploit_vrb  1.000000
# 103             expose_vrb  1.000000
# 104            extract_nou  1.000000
# 105            extract_vrb  1.000000
# 106           fragment_nou  1.000000
# 107           frequent_adj  1.000000
# 108       graduate_adj-nou  1.000000
# 111             impact_nou  1.000000
# 112            implant_nou  1.000000
# 113          implement_nou  1.000000
# 99          expatriate_nou  1.000000
# 114          implement_vrb  1.000000
# 118           increase_nou  1.000000
# 119           increase_vrb  1.000000
# 120          increment_nou  1.000000
# 122           initiate_nou  1.000000
# 123           initiate_vrb  1.000000
# 124             insert_nou  1.000000
# 125             insert_vrb  1.000000
# 126             insult_nou  1.000000
# 127             insult_vrb  1.000000
# 128           intrigue_nou  1.000000
# 116             import_vrb  1.000000
# 98              excuse_vrb  1.000000
# 97              excuse_nou  1.000000
# 96            estimate_vrb  1.000000
# 72            decrease_vrb  1.000000
# 73              defect_nou  1.000000
# 74      degenerate_adj-nou  1.000000
# 75          degenerate_vrb  1.000000
# 76            delegate_nou  1.000000
# 77          deliberate_adj  1.000000
# 78             deviate_vrb  1.000000
# 80           diagnoses_vrb  1.000000
# 81             diffuse_adj  1.000000
# 82             diffuse_vrb  1.000000
# 83             discard_nou  1.000000
# 84             discard_vrb  1.000000
# 85           discharge_nou  1.000000
# 86           discharge_vrb  1.000000
# 87            discount_nou  1.000000
# 88            document_nou  1.000000
# 89            document_vrb  1.000000
# 90                    dove  1.000000
# 91       duplicate_adj-nou  1.000000
# 92           duplicate_vrb  1.000000
# 93              escort_nou  1.000000
# 94              escort_vrb  1.000000
# 95            estimate_nou  1.000000
# 130            invalid_nou  1.000000
# 234              wound_vrb  1.000000

# %%
hids = pd.read_csv("C:/Users/jseal/Dev/dissertation/Data_Exploration/WHD/hids.csv")

# %%
hids_acc = pd.merge(hids, accuracies_df, on='wordid')

# %%
hids_acc.sort_values(["accuracy"])
# Out:
#      Unnamed: 0    homograph                 wordid  wordid_count  ttl  \
# 215           1    syndicate          syndicate_vrb             4   90
# 43            1        close              close_vrb             5   89
# 202           0         sake                sake_jp            13   89
# 39            1       buffet             buffet_vrb             5   88
# 205           1     separate           separate_vrb             6   91
# 35            1      bologna                bologna             1   90
# 209           1  subordinate        subordinate_vrb             3   90
# 181           1        ravel              ravel_nou             1   90
# 174           1      produce            produce_nou             6   90
# 26            0       august             august_nam             9   88
# 103           1       expose             expose_nou             4   89
# 151           1       misuse             misuse_vrb             7   88
# 221           1   transplant         transplant_vrb             5   90
# 109           1     graduate           graduate_vrb             3   90
# 195           1       reject             reject_nou             5   86
# 141           0      learned            learned_adj             7   90
# 13            1    alternate          alternate_vrb             5   92
# 7             0    affiliate          affiliate_vrb             3   89
# 230           1         wind               wind_vrb             6   90
# 232           1        winds              winds_vrb             6   87
# 120           0    increment          increment_vrb            11   89
# 160           1        pasty              pasty_nou            22   85
# 187           1       record             record_vrb            12   90
# 36            0          bow           bow_nou-knot            43   90
# 226           1          use                use_vrb            37   91
# 157           0    overthrow          overthrow_nou            28   90
# 132           1       invert         invert_adj-nou            27   89
# 182           0         read              read_past            52  112
# 139           0         lead           lead_nou-vrb            83  104
# 101           0       export             export_nou            75   89
# 1             0        abuse              abuse_nou            81   90
# 17            0  appropriate        appropriate_adj            88   90
# 37            1          bow           bow_nou-ship            47   90
# 15            0      animate            animate_vrb            50   86
# 233           0        wound          wound_nou-vrb            61   89
# 68            0   coordinate         coordinate_vrb            44   89
# 131           0       invert             invert_vrb            62   89
# 204           0     separate           separate_adj            85   91
# 115           0       import             import_nou            68   88
# 223           0        upset              upset_nou            65   89
# 66            0      convict            convict_nou            80   90
# 178           0      protest            protest_nou            80   90
# 227           0         uses               uses_vrb            78   90
# 79            0    diagnoses          diagnoses_nou            70   90
# 110           0        house              house_nou            88   90
# 53            0    conscript          conscript_nou            75   89
# 65            0      convert            convert_vrb            78   90
# 153           0     moderate       moderate_adj-nou            89   90
# 61            0     contract           contract_nou            88   90
# 185           0        rebel              rebel_nou            84   90
# 14            0     analyses           analyses_nou            79   90
# 45            0     compound           compound_nou            87   90
# 46            0     compress               compress            84   88
# 198           0       resume             resume_vrb            80   88
# 158           1    overthrow          overthrow_vrb            62   90
# 148           0       minute                 minute            75   87
# 149           1       minute             minute_adj            12   87
# 150           0       misuse             misuse_nou            81   88
# 220           0   transplant         transplant_nou            85   90
# 219           1    transform              transform            60   90
# 152           0       mobile                 mobile            85   89
# 159           0        pasty              pasty_adj            63   85
# 161           0      perfect            perfect_adj            85   91
# 147           0         mate                   mate            89   90
# 217           1         tear               tear_vrb            57   89
# 154           0       nestle             nestle_nam            63   77
# 155           1       nestle             nestle_vrb            14   77
# 156           0     ornament           ornament_nou            86   90
# 216           0         tear               tear_nou            32   89
# 214           0    syndicate          syndicate_nou            86   90
# 218           0    transform          transform_nou            30   90
# 197           1    rerelease          rerelease_vrb            13   90
# 146           1        lives              lives_nou            34   91
# 133           0       invite             invite_vrb            71   90
# 134           1       invite             invite_nou            19   90
# 135           0      isolate            isolate_nou            21   90
# 136           1      isolate                isolate            69   90
# 137           0        jesus                  jesus            88   90
# 138           0     laminate           laminate_nou            87   90
# 231           0        winds              winds_nou            81   87
# 222           0    transport          transport_nou            84   89
# 229           0         wind               wind_nou            84   90
# 228           1         uses               uses_nou            12   90
# 225           0          use                use_nou            54   91
# 142           1      learned            learned_vrb            83   90
# 224           1        upset              upset_vrb            24   89
# 143           0         live               live_adj            55   88
# 144           1         live               live_vrb            33   88
# 145           0        lives              lives_vrb            57   91
# 140           1         lead               lead_nou            21  104
# 162           0      perfume            perfume_nou            88   90
# 164           1       permit             permit_vrb            40   89
# 165           0      pervert            pervert_nou            69   90
# 184           0      reading             reading_en            74   90
# 206           0          sow                sow_nou            34   86
# 203           1         sake                   sake            76   89
# 201           0        rodeo                  rodeo            83   86
# 186           0       record             record_nou            78   90
# 188           0      recount            recount_nou            65   90
# 189           1      recount            recount_vrb            25   90
# 190           0       refund             refund_nou            66   90
# 191           1       refund             refund_vrb            24   90
# 192           0       refuse             refuse_vrb            77   90
# 193           1       refuse             refuse_nou            13   90
# 194           0       reject             reject_vrb            81   86
# 200           1       retard             retard_nou            14   85
# 199           0       retard             retard_vrb            71   85
# 196           0    rerelease              rerelease            77   90
# 207           1          sow                    sow            52   86
# 183           1         read           read_present            60  112
# 208           0  subordinate    subordinate_adj-nou            87   90
# 210           0   supplement         supplement_vrb            29   89
# 166           0       polish             polish_geo            87   90
# 167           0    postulate          postulate_nou            60   90
# 168           1    postulate          postulate_vrb            30   90
# 169           0  precipitate        precipitate_vrb            51   90
# 170           1  precipitate    precipitate_adj-nou            39   90
# 171           0    predicate          predicate_nou            89   90
# 172           0      present        present_adj-nou            83   90
# 163           0       permit             permit_nou            49   89
# 173           0      produce            produce_vrb            84   90
# 212           0      suspect            suspect_vrb            26   90
# 175           0     progress           progress_nou            74   89
# 176           1     progress           progress_vrb            15   89
# 177           0      project            project_nou            89   90
# 211           1   supplement         supplement_nou            60   89
# 179           1      protest            protest_vrb            10   90
# 180           0        ravel              ravel_nam            89   90
# 213           1      suspect        suspect_adj-nou            64   90
# 0             0     abstract       abstract_adj-nou            89   90
# 117           0      incline            incline_nou            86   89
# 129           0      invalid            invalid_adj            67   89
# 34            0      bologna            bologna_geo            89   90
# 38            0       buffet             buffet_nou            83   88
# 40            0       celtic  celtic_adj-nou-sports            28   90
# 41            1       celtic                 celtic            62   90
# 42            0        close          close_adj-nou            84   89
# 44            0      combine            combine_vrb            81   89
# 47            0      conduct            conduct_vrb            49   90
# 48            1      conduct            conduct_nou            41   90
# 49            0     confines           confines_nou            73   89
# 50            1     confines           confines_vrb            16   89
# 33            1      blessed            blessed_vrb            44   86
# 51            0     conflict           conflict_nou            86   90
# 54            0      console            console_nou            88   90
# 55            0    construct          construct_vrb            81   90
# 56            0   consummate         consummate_adj            49   90
# 57            1   consummate         consummate_vrb            41   90
# 58            0      content            content_nou            89   90
# 59            0      contest            contest_nou            78   90
# 60            1      contest            contest_vrb            12   90
# 62            0     contrast           contrast_nou            89   90
# 63            0     converse           converse_vrb            32   90
# 64            1     converse       converse_adj-nou            58   90
# 52            0    conjugate      conjugate_adj-nou            86   90
# 67            1      convict            convict_vrb            10   90
# 32            0      blessed            blessed_adj            42   86
# 30            0         bass                   bass            74   87
# 2             0       abuses             abuses_nou            74   90
# 3             1       abuses             abuses_vrb            16   90
# 4             0     advocate           advocate_nou            76   90
# 5             1     advocate           advocate_vrb            14   90
# 6             0       affect                 affect            85   90
# 8             1    affiliate          affiliate_nou            86   89
# 9             0         aged                   aged            87   91
# 10            0    aggregate      aggregate_adj-nou            79   88
# 11            1    aggregate          aggregate_vrb             9   88
# 12            0    alternate      alternate_adj-nou            87   92
# 31            1         bass              bass_corp            13   87
# 16            1      animate        animate_adj-nou            36   86
# 19            1  approximate        approximate_vrb            11   89
# 20            0   articulate         articulate_adj            42   90
# 21            1   articulate         articulate_vrb            48   90
# 22            0    associate      associate_adj-nou            81   90
# 23            1    associate          associate_vrb             9   90
# 24            0    attribute          attribute_vrb            37   90
# 25            1    attribute          attribute_nou            53   90
# 27            1       august                 august            78   88
# 28            0         axes               axes_nou            47   90
# 29            1         axes           axes_nou-vrb            43   90
# 18            0  approximate    approximate_adj-nou            78   89
# 69            1   coordinate     coordinate_adj-nou            45   89
# 70            0    correlate      correlate_nou-vrb            83   90
# 71            0     decrease           decrease_nou            41   89
# 100           0      exploit            exploit_vrb            77   90
# 102           0       expose             expose_vrb            85   89
# 104           0      extract            extract_vrb            47   90
# 105           1      extract            extract_nou            43   90
# 106           0     fragment           fragment_nou            86   89
# 107           0     frequent           frequent_adj            86   90
# 108           0     graduate       graduate_adj-nou            87   90
# 111           0       impact             impact_nou            88   90
# 112           0      implant            implant_nou            82   90
# 113           0    implement          implement_vrb            81   90
# 99            0   expatriate         expatriate_nou            89   90
# 114           1    implement          implement_nou             9   90
# 118           0     increase           increase_vrb            42   90
# 119           1     increase           increase_nou            48   90
# 121           1    increment          increment_nou            78   89
# 122           0     initiate           initiate_vrb            83   90
# 123           1     initiate           initiate_nou             7   90
# 124           0       insert             insert_vrb            43   90
# 125           1       insert             insert_nou            47   90
# 126           0       insult             insult_nou            66   90
# 127           1       insult             insult_vrb            24   90
# 128           0     intrigue           intrigue_nou            86   90
# 116           1       import             import_vrb            20   88
# 98            1       excuse             excuse_vrb            15   89
# 97            0       excuse             excuse_nou            74   89
# 96            1     estimate           estimate_vrb            27   89
# 72            1     decrease           decrease_vrb            48   89
# 73            0       defect             defect_nou            79   90
# 74            0   degenerate     degenerate_adj-nou            75   90
# 75            1   degenerate         degenerate_vrb            15   90
# 76            0     delegate           delegate_nou            82   90
# 77            0   deliberate         deliberate_adj            86   89
# 78            0      deviate            deviate_vrb            87   89
# 80            1    diagnoses          diagnoses_vrb            20   90
# 81            0      diffuse            diffuse_adj            56   90
# 82            1      diffuse            diffuse_vrb            34   90
# 83            0      discard            discard_nou            24   90
# 84            1      discard            discard_vrb            66   90
# 85            0    discharge          discharge_nou            80   90
# 86            1    discharge          discharge_vrb            10   90
# 87            0     discount           discount_nou            87   90
# 88            0     document           document_nou            76   90
# 89            1     document           document_vrb            14   90
# 90            1         dove                   dove            52   58
# 91            0    duplicate      duplicate_adj-nou            67   90
# 92            1    duplicate          duplicate_vrb            23   90
# 93            0       escort             escort_nou            81   90
# 94            1       escort             escort_vrb             9   90
# 95            0     estimate           estimate_nou            62   89
# 130           1      invalid            invalid_nou            22   89
# 234           1        wound              wound_vrb            28   89
#
#      percent_ttl  accuracy
# 215     0.044444  0.000000
# 43      0.056180  0.000000
# 202     0.146067  0.000000
# 39      0.056818  0.000000
# 205     0.065934  0.000000
# 35      0.011111  0.000000
# 209     0.033333  0.000000
# 181     0.011111  0.000000
# 174     0.066667  0.000000
# 26      0.102273  0.000000
# 103     0.044944  0.000000
# 151     0.079545  0.000000
# 221     0.055556  0.000000
# 109     0.033333  0.000000
# 195     0.058140  0.000000
# 141     0.077778  0.000000
# 13      0.054348  0.000000
# 7       0.033708  0.000000
# 230     0.066667  0.000000
# 232     0.068966  0.000000
# 120     0.123596  0.000000
# 160     0.258824  0.333333
# 187     0.133333  0.500000
# 36      0.477778  0.600000
# 226     0.406593  0.666667
# 157     0.311111  0.666667
# 132     0.303371  0.666667
# 182     0.464286  0.666667
# 139     0.798077  0.750000
# 101     0.842697  0.777778
# 1       0.900000  0.777778
# 17      0.977778  0.777778
# 37      0.522222  0.800000
# 15      0.581395  0.833333
# 233     0.685393  0.833333
# 68      0.494382  0.833333
# 131     0.696629  0.833333
# 204     0.934066  0.857143
# 115     0.772727  0.857143
# 223     0.730337  0.857143
# 66      0.888889  0.875000
# 178     0.888889  0.875000
# 227     0.866667  0.875000
# 79      0.777778  0.875000
# 110     0.977778  0.888889
# 53      0.842697  0.888889
# 65      0.866667  0.888889
# 153     0.988889  0.888889
# 61      0.977778  0.888889
# 185     0.933333  0.888889
# 14      0.877778  0.888889
# 45      0.966667  0.888889
# 46      0.954545  0.888889
# 198     0.909091  0.888889
# 158     0.688889  1.000000
# 148     0.862069  1.000000
# 149     0.137931  1.000000
# 150     0.920455  1.000000
# 220     0.944444  1.000000
# 219     0.666667  1.000000
# 152     0.955056  1.000000
# 159     0.741176  1.000000
# 161     0.934066  1.000000
# 147     0.988889  1.000000
# 217     0.640449  1.000000
# 154     0.818182  1.000000
# 155     0.181818  1.000000
# 156     0.955556  1.000000
# 216     0.359551  1.000000
# 214     0.955556  1.000000
# 218     0.333333  1.000000
# 197     0.144444  1.000000
# 146     0.373626  1.000000
# 133     0.788889  1.000000
# 134     0.211111  1.000000
# 135     0.233333  1.000000
# 136     0.766667  1.000000
# 137     0.977778  1.000000
# 138     0.966667  1.000000
# 231     0.931034  1.000000
# 222     0.943820  1.000000
# 229     0.933333  1.000000
# 228     0.133333  1.000000
# 225     0.593407  1.000000
# 142     0.922222  1.000000
# 224     0.269663  1.000000
# 143     0.625000  1.000000
# 144     0.375000  1.000000
# 145     0.626374  1.000000
# 140     0.201923  1.000000
# 162     0.977778  1.000000
# 164     0.449438  1.000000
# 165     0.766667  1.000000
# 184     0.822222  1.000000
# 206     0.395349  1.000000
# 203     0.853933  1.000000
# 201     0.965116  1.000000
# 186     0.866667  1.000000
# 188     0.722222  1.000000
# 189     0.277778  1.000000
# 190     0.733333  1.000000
# 191     0.266667  1.000000
# 192     0.855556  1.000000
# 193     0.144444  1.000000
# 194     0.941860  1.000000
# 200     0.164706  1.000000
# 199     0.835294  1.000000
# 196     0.855556  1.000000
# 207     0.604651  1.000000
# 183     0.535714  1.000000
# 208     0.966667  1.000000
# 210     0.325843  1.000000
# 166     0.966667  1.000000
# 167     0.666667  1.000000
# 168     0.333333  1.000000
# 169     0.566667  1.000000
# 170     0.433333  1.000000
# 171     0.988889  1.000000
# 172     0.922222  1.000000
# 163     0.550562  1.000000
# 173     0.933333  1.000000
# 212     0.288889  1.000000
# 175     0.831461  1.000000
# 176     0.168539  1.000000
# 177     0.988889  1.000000
# 211     0.674157  1.000000
# 179     0.111111  1.000000
# 180     0.988889  1.000000
# 213     0.711111  1.000000
# 0       0.988889  1.000000
# 117     0.966292  1.000000
# 129     0.752809  1.000000
# 34      0.988889  1.000000
# 38      0.943182  1.000000
# 40      0.311111  1.000000
# 41      0.688889  1.000000
# 42      0.943820  1.000000
# 44      0.910112  1.000000
# 47      0.544444  1.000000
# 48      0.455556  1.000000
# 49      0.820225  1.000000
# 50      0.179775  1.000000
# 33      0.511628  1.000000
# 51      0.955556  1.000000
# 54      0.977778  1.000000
# 55      0.900000  1.000000
# 56      0.544444  1.000000
# 57      0.455556  1.000000
# 58      0.988889  1.000000
# 59      0.866667  1.000000
# 60      0.133333  1.000000
# 62      0.988889  1.000000
# 63      0.355556  1.000000
# 64      0.644444  1.000000
# 52      0.955556  1.000000
# 67      0.111111  1.000000
# 32      0.488372  1.000000
# 30      0.850575  1.000000
# 2       0.822222  1.000000
# 3       0.177778  1.000000
# 4       0.844444  1.000000
# 5       0.155556  1.000000
# 6       0.944444  1.000000
# 8       0.966292  1.000000
# 9       0.956044  1.000000
# 10      0.897727  1.000000
# 11      0.102273  1.000000
# 12      0.945652  1.000000
# 31      0.149425  1.000000
# 16      0.418605  1.000000
# 19      0.123596  1.000000
# 20      0.466667  1.000000
# 21      0.533333  1.000000
# 22      0.900000  1.000000
# 23      0.100000  1.000000
# 24      0.411111  1.000000
# 25      0.588889  1.000000
# 27      0.886364  1.000000
# 28      0.522222  1.000000
# 29      0.477778  1.000000
# 18      0.876404  1.000000
# 69      0.505618  1.000000
# 70      0.922222  1.000000
# 71      0.460674  1.000000
# 100     0.855556  1.000000
# 102     0.955056  1.000000
# 104     0.522222  1.000000
# 105     0.477778  1.000000
# 106     0.966292  1.000000
# 107     0.955556  1.000000
# 108     0.966667  1.000000
# 111     0.977778  1.000000
# 112     0.911111  1.000000
# 113     0.900000  1.000000
# 99      0.988889  1.000000
# 114     0.100000  1.000000
# 118     0.466667  1.000000
# 119     0.533333  1.000000
# 121     0.876404  1.000000
# 122     0.922222  1.000000
# 123     0.077778  1.000000
# 124     0.477778  1.000000
# 125     0.522222  1.000000
# 126     0.733333  1.000000
# 127     0.266667  1.000000
# 128     0.955556  1.000000
# 116     0.227273  1.000000
# 98      0.168539  1.000000
# 97      0.831461  1.000000
# 96      0.303371  1.000000
# 72      0.539326  1.000000
# 73      0.877778  1.000000
# 74      0.833333  1.000000
# 75      0.166667  1.000000
# 76      0.911111  1.000000
# 77      0.966292  1.000000
# 78      0.977528  1.000000
# 80      0.222222  1.000000
# 81      0.622222  1.000000
# 82      0.377778  1.000000
# 83      0.266667  1.000000
# 84      0.733333  1.000000
# 85      0.888889  1.000000
# 86      0.111111  1.000000
# 87      0.966667  1.000000
# 88      0.844444  1.000000
# 89      0.155556  1.000000
# 90      0.896552  1.000000
# 91      0.744444  1.000000
# 92      0.255556  1.000000
# 93      0.900000  1.000000
# 94      0.100000  1.000000
# 95      0.696629  1.000000
# 130     0.247191  1.000000
# 234     0.314607  1.000000

# %%
hids_acc = hids_acc[hids_acc['accuracy'] < 1.0]

# %%
hids_acc_prevalence = hids_acc[["wordid", "percent_ttl"]]
hids_acc_acc = hids_acc[["wordid", "accuracy"]]

# %%
import matplotlib.pylab as plt
# %matplotlib inline  

ax = hids_acc_acc.plot(
    x='wordid', linestyle='-', marker='o', color="red")
hids_acc_prevalence.plot(x='wordid', kind='bar', ax=ax, figsize=(15,10))

plt.show()

# %%
hids_acc = pd.merge(hids, accuracies_df, on='wordid')
homs = hids_acc[hids_acc["percent_ttl"] < 0.2]['homograph'].tolist()
homs
# Out:
# ['abuses',
#  'advocate',
#  'affiliate',
#  'aggregate',
#  'alternate',
#  'approximate',
#  'associate',
#  'august',
#  'bass',
#  'bologna',
#  'buffet',
#  'close',
#  'confines',
#  'contest',
#  'convict',
#  'degenerate',
#  'discharge',
#  'document',
#  'escort',
#  'excuse',
#  'expose',
#  'graduate',
#  'implement',
#  'increment',
#  'initiate',
#  'learned',
#  'minute',
#  'misuse',
#  'nestle',
#  'produce',
#  'progress',
#  'protest',
#  'ravel',
#  'record',
#  'refuse',
#  'reject',
#  'rerelease',
#  'retard',
#  'sake',
#  'separate',
#  'subordinate',
#  'syndicate',
#  'transplant',
#  'uses',
#  'wind',
#  'winds']

# %%
len(homs)
# Out:
# 46

# %%
hids_acc['homograph'].nunique()
# Out:
# 144

# %% [markdown]
# # Train and eval together

# %%
hids = pd.read_csv("C:/Users/jseal/Dev/dissertation/Data_Exploration/WHD/train_eval_hids.csv")

# %%
hids_acc = pd.merge(hids, accuracies_df, on='wordid')
hids_acc = hids_acc[hids_acc['accuracy'] < 1.0]
hids_acc_prevalence = hids_acc[["wordid", "percent_ttl"]]
hids_acc_acc = hids_acc[["wordid", "accuracy"]]
ax = hids_acc_acc.plot(
    x='wordid', linestyle='-', marker='o', color="red")
hids_acc_prevalence.plot(x='wordid', kind='bar', ax=ax, figsize=(20,10))

plt.show()

# %%
hids_acc = pd.merge(hids, accuracies_df, on='wordid')
hids_acc = hids_acc[hids_acc['percent_ttl'] < 0.1]
hids_acc_prevalence = hids_acc[["wordid", "percent_ttl"]]
hids_acc_acc = hids_acc[["wordid", "accuracy"]]
ax = hids_acc_acc.plot(
    x='wordid', linestyle='-', marker='o', color="red")
hids_acc_prevalence.plot(x='wordid', kind='bar', ax=ax, figsize=(20,10))

plt.show()

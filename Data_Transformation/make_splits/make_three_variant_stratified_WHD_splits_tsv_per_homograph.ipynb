# %% [markdown]
# # Description
# **Functionality**: The Wikipedia Homograph Data provided by Google is a two-way split dataset: train and eval. For the purposes of this study, we split the data into train, valid, and test and ensure the presence of each pronunciation class in each split.
#
# This module splits the Wikipedia homograph train split into 90% train, 10% valid. For the test split, the original Wikipedia homograph eval split is copied over.
#
# **Use**: The train and valid splits are used to train neural net models for homograph disambiguation, while the test set is held out for final evaluation.

# %% [markdown]
# ### Imports

# %%
import os
import shutil
from glob import iglob
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ### Variables

# %%
#Paths 

WHD_DATA_VARIANT = "C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/variant_limit_data/"
TRAIN = WHD_DATA_VARIANT + "train/"
EVAL = WHD_DATA_VARIANT + "eval/"
SPLIT_DIRS = [TRAIN, EVAL]

WHD_DATA = "C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/"
THREE_SPLITS = WHD_DATA + "three_split_stratified_variant_data_corrected/"
NEW_TRAIN = THREE_SPLITS + "train/"
NEW_DEV = THREE_SPLITS + "dev/"
NEW_TEST = THREE_SPLITS + "test/"

pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Functions

# %%
def make_df(split_dir): 
    dfs = []
    for f in tqdm(iglob(split_dir +'*.tsv')):
        f_name = os.path.basename(f)
        dfs.append(pd.read_table(f))
    return dfs

def combine_train_eval():
    dfs = []
    for split_dir in SPLIT_DIRS:
        print(split_dir)
        for df in make_df(split_dir): 
            dfs.append(df) 
    all_data = pd.concat(dfs, ignore_index=True)
    all_data['orig_idx'] = all_data.index
    return all_data     

def stratify_sample(data_df):
    data_df = data_df.sample(frac=1)
    #Append stratified samples per wordid, with enforcement of at least one sample per split
    train_samples = []
    dev_samples = []
    test_samples = []
    for i, gp in data_df.groupby("wordid"):
        print(i)
        print(len(gp))
            
        #Randomize samples
        gp = gp.sample(frac=1)
        
        #If only three samples, assign one to each split
        if len(gp) == 3: 
            train = gp.head(1) 
            test = gp.tail(1)
            dev = gp[~gp.orig_idx.isin(train.orig_idx)]
            dev = dev[~dev.orig_idx.isin(test.orig_idx)]
            print('train')
            print(train.shape[0])
            print('dev')
            print(dev.shape[0])
            assert len(dev) > 0, f"dev has no samples"
            assert (set(train.orig_idx) & set(dev.orig_idx)) == set(), f"train and dev not mutex. Mutual idx: " + str(set(train.orig_idx) & set(dev.orig_idx))
            print('test')
            print(test.shape[0])
            assert len(test) > 0, f"test has no samples"
            assert (set(train.orig_idx) & set(test.orig_idx)) == set(), f"train and test not mutex. Mutual idx: " + str(set(train.orig_idx) & set(test.orig_idx))
            assert (set(dev.orig_idx) & set(test.orig_idx)) == set(), f"dev and test not mutex. Mutual idx: : " + str(set(dev.orig_idx) & set(test.orig_idx))
            
            train_samples.append(train)
            dev_samples.append(dev)
            test_samples.append(test)
        
        else:
            n = gp.shape[0]
            #Take 80% for train
            train = gp.sample(frac=.8)
            print('train')
            print(train.shape[0])
            #Used to check if the data left after train is 
            #created has at least 2 samples - one for dev, and one for test
            check_rest = gp[~gp.index.isin(train.index)]
        
            if (len(check_rest) < 2): 

                #If less than 2, take the last sample from train, and make a new train
                train_new = train[:-1]
                train_samples.append(train_new)
                # Make new remaining data by removing smaller, new train set
                dev_test = gp[~gp.index.isin(train_new.index)]
                dev = dev_test.head(1)
                print('dev')
                print(dev.shape[0])
                assert len(dev) > 0, f"dev has no samples"
                assert (set(train_new.orig_idx) & set(dev.orig_idx)) == set(), f"train and dev not mutex. Mutual idx: " + str(set(train_new.orig_idx) & set(dev.orig_idx))
                dev_samples.append(dev)
                
                test = dev_test.tail(1)
                print('test')
                print(test.shape[0])
                assert len(test) > 0, f"test has no samples"
                assert (set(train_new.orig_idx) & set(test.orig_idx)) == set(), f"train and test not mutex. Mutual idx: " + str(set(train.orig_idx) & set(test.orig_idx))
                assert (set(dev.orig_idx) & set(test.orig_idx)) == set(), f"dev and test not mutex. Mutual idx: : " + str(set(dev.orig_idx) & set(test.orig_idx))
                test_samples.append(test)
            else: 
                train_samples.append(train)
                dev_test = gp[~gp.index.isin(train.index)]
                
                dev = dev_test.sample(frac=.5)
                print('dev')
                print(dev.shape[0])
                assert len(dev) > 0, f"dev has no samples"
                assert (set(train.orig_idx) & set(dev.orig_idx)) == set(), f"train and dev not mutex. Mutual idx: " + str(set(train.orig_idx) & set(dev.orig_idx))
                dev_samples.append(dev)
                
                test = dev_test[~dev_test.index.isin(dev.index)]
                print('test')
                print(test.shape[0])
                assert len(test) > 0, f"test has no samples"
                assert (set(train.orig_idx) & set(test.orig_idx)) == set(), f"train and test not mutex. Mutual idx: " + str(set(train.orig_idx) & set(test.orig_idx))
                assert (set(dev.orig_idx) & set(test.orig_idx)) == set(), f"dev and test not mutex. Mutual idx: : " + str(set(dev.orig_idx) & set(test.orig_idx))
                test_samples.append(test)
    train_df = pd.concat(train_samples)
    dev_df = pd.concat(dev_samples)
    test_df = pd.concat(test_samples)

    return train_df, dev_df, test_df

# %% [markdown]
# # Script

# %%
all_data = combine_train_eval()
# Out:
# 128it [00:00, 687.62it/s]
# C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/variant_limit_data/train/
# 128it [00:00, 785.87it/s]
# C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/variant_limit_data/eval/

# %%
all_data.head(10)
# Out:
#   homograph     wordid                                           sentence  \
# 0     abuse  abuse_nou  Some such suits accuse the Vatican of complici...
# 1     abuse  abuse_nou  Similarly the novel deals with the misuse and ...
# 2     abuse  abuse_nou  In December 1988, he announced a pilot project...
# 3     abuse  abuse_vrb  Marty can already tell how much Judd is going ...
# 4     abuse  abuse_nou  Advocacy services that encourage victims to es...
# 5     abuse  abuse_nou  Barros has been accused of complicity in an ab...
# 6     abuse  abuse_nou  Some conditions they face include no time off;...
# 7     abuse  abuse_nou              This valve is weakened by drug abuse.
# 8     abuse  abuse_nou  Tanenbaum notes that MacKinnon misrepresents t...
# 9     abuse  abuse_nou  Prevention of Mental Disorders, Substance Abus...
#
#    start  end  orig_idx
# 0     59   64         0
# 1     46   51         1
# 2     61   66         2
# 3     49   54         3
# 4     54   59         4
# 5     44   49         5
# 6     79   84         6
# 7     31   36         7
# 8     76   81         8
# 9     42   47         9

# %%
for i, gp in all_data.groupby('homograph'): 
    print(gp['wordid'].value_counts())
# Out:
# abuse_nou    90
# abuse_vrb    10
# Name: wordid, dtype: int64
# abuses_nou    83
# abuses_vrb    17
# Name: wordid, dtype: int64
# advocate_nou    83
# advocate_vrb    17
# Name: wordid, dtype: int64
# affect            95
# affect_nou-psy     5
# Name: wordid, dtype: int64
# affiliate_nou    96
# affiliate_vrb     3
# Name: wordid, dtype: int64
# aged        96
# aged_adj     5
# Name: wordid, dtype: int64
# aggregate_adj-nou    88
# aggregate_vrb        10
# Name: wordid, dtype: int64
# alternate_adj-nou    97
# alternate_vrb         5
# Name: wordid, dtype: int64
# analyses_nou    89
# analyses_vrb    11
# Name: wordid, dtype: int64
# animate_vrb        58
# animate_adj-nou    37
# Name: wordid, dtype: int64
# approximate_adj-nou    88
# approximate_vrb        11
# Name: wordid, dtype: int64
# articulate_vrb    54
# articulate_adj    46
# Name: wordid, dtype: int64
# associate_adj-nou    88
# associate_vrb        12
# Name: wordid, dtype: int64
# attribute_nou    54
# attribute_vrb    46
# Name: wordid, dtype: int64
# axes_nou        51
# axes_nou-vrb    49
# Name: wordid, dtype: int64
# bass         84
# bass_corp    13
# Name: wordid, dtype: int64
# blessed_vrb    51
# blessed_adj    45
# Name: wordid, dtype: int64
# bow_nou-ship    53
# bow_nou-knot    47
# Name: wordid, dtype: int64
# buffet_nou    93
# buffet_vrb     5
# Name: wordid, dtype: int64
# celtic                   70
# celtic_adj-nou-sports    30
# Name: wordid, dtype: int64
# close_adj-nou    93
# close_vrb         6
# Name: wordid, dtype: int64
# combine_vrb    90
# combine_nou     9
# Name: wordid, dtype: int64
# compound_nou    97
# compound_vrb     3
# Name: wordid, dtype: int64
# compress        93
# compress_nou     5
# Name: wordid, dtype: int64
# conduct_vrb    52
# conduct_nou    48
# Name: wordid, dtype: int64
# confines_nou    77
# confines_vrb    22
# Name: wordid, dtype: int64
# conflict_nou    96
# conflict_vrb     4
# Name: wordid, dtype: int64
# conjugate_adj-nou    95
# conjugate_vrb         5
# Name: wordid, dtype: int64
# conscript_nou    84
# conscript_vrb    15
# Name: wordid, dtype: int64
# construct_vrb    90
# construct_nou    10
# Name: wordid, dtype: int64
# consummate_adj    51
# consummate_vrb    49
# Name: wordid, dtype: int64
# content_nou            96
# content_adj-nou-vrb     4
# Name: wordid, dtype: int64
# contest_nou    85
# contest_vrb    15
# Name: wordid, dtype: int64
# converse_adj-nou    63
# converse_vrb        37
# Name: wordid, dtype: int64
# convert_vrb    86
# convert_nou    14
# Name: wordid, dtype: int64
# convict_nou    88
# convict_vrb    12
# Name: wordid, dtype: int64
# coordinate_vrb        52
# coordinate_adj-nou    47
# Name: wordid, dtype: int64
# correlate_nou-vrb    90
# correlate_nou        10
# Name: wordid, dtype: int64
# decrease_vrb    53
# decrease_nou    46
# Name: wordid, dtype: int64
# defect_nou    89
# defect_vrb    11
# Name: wordid, dtype: int64
# degenerate_adj-nou    84
# degenerate_vrb        16
# Name: wordid, dtype: int64
# delegate_nou    92
# delegate_vrb     8
# Name: wordid, dtype: int64
# deliberate_adj    95
# deliberate_vrb     4
# Name: wordid, dtype: int64
# diagnoses_nou    78
# diagnoses_vrb    22
# Name: wordid, dtype: int64
# diffuse_adj    63
# diffuse_vrb    37
# Name: wordid, dtype: int64
# discard_vrb    73
# discard_nou    27
# Name: wordid, dtype: int64
# discharge_nou    89
# discharge_vrb    11
# Name: wordid, dtype: int64
# discount_nou    97
# discount_vrb     3
# Name: wordid, dtype: int64
# document_nou    85
# document_vrb    15
# Name: wordid, dtype: int64
# dove        57
# dove_vrb     7
# Name: wordid, dtype: int64
# duplicate_adj-nou    73
# duplicate_vrb        27
# Name: wordid, dtype: int64
# escort_nou    88
# escort_vrb    12
# Name: wordid, dtype: int64
# estimate_nou    72
# estimate_vrb    27
# Name: wordid, dtype: int64
# excuse_nou    81
# excuse_vrb    18
# Name: wordid, dtype: int64
# exploit_vrb    86
# exploit_nou    14
# Name: wordid, dtype: int64
# export_nou    84
# export_vrb    15
# Name: wordid, dtype: int64
# expose_vrb    93
# expose_nou     6
# Name: wordid, dtype: int64
# extract_vrb    52
# extract_nou    48
# Name: wordid, dtype: int64
# fragment_nou    96
# fragment_vrb     3
# Name: wordid, dtype: int64
# frequent_adj    95
# frequent_vrb     5
# Name: wordid, dtype: int64
# graduate_adj-nou    95
# graduate_vrb         5
# Name: wordid, dtype: int64
# impact_nou    97
# impact_vrb     3
# Name: wordid, dtype: int64
# implant_nou    91
# implant_vrb     9
# Name: wordid, dtype: int64
# implement_vrb    90
# implement_nou    10
# Name: wordid, dtype: int64
# import_nou    75
# import_vrb    23
# Name: wordid, dtype: int64
# incline_nou    95
# incline_vrb     4
# Name: wordid, dtype: int64
# increase_nou    53
# increase_vrb    47
# Name: wordid, dtype: int64
# increment_nou    87
# increment_vrb    12
# Name: wordid, dtype: int64
# initiate_vrb    91
# initiate_nou     9
# Name: wordid, dtype: int64
# insert_nou    52
# insert_vrb    48
# Name: wordid, dtype: int64
# insult_nou    74
# insult_vrb    26
# Name: wordid, dtype: int64
# intrigue_nou        95
# intrigue_nou-vrb     5
# Name: wordid, dtype: int64
# invalid_adj    76
# invalid_nou    23
# Name: wordid, dtype: int64
# invert_vrb        68
# invert_adj-nou    31
# Name: wordid, dtype: int64
# invite_vrb    79
# invite_nou    21
# Name: wordid, dtype: int64
# isolate        78
# isolate_nou    22
# Name: wordid, dtype: int64
# laminate_nou    96
# laminate_vrb     4
# Name: wordid, dtype: int64
# lead_nou-vrb    91
# lead_nou        24
# Name: wordid, dtype: int64
# learned_vrb    93
# learned_adj     7
# Name: wordid, dtype: int64
# live_adj    61
# live_vrb    37
# Name: wordid, dtype: int64
# lives_vrb    64
# lives_nou    37
# Name: wordid, dtype: int64
# minute        84
# minute_adj    13
# Name: wordid, dtype: int64
# misuse_nou    91
# misuse_vrb     7
# Name: wordid, dtype: int64
# mobile        95
# mobile_geo     4
# Name: wordid, dtype: int64
# nestle_nam    72
# nestle_vrb    14
# Name: wordid, dtype: int64
# ornament_nou    96
# ornament_vrb     4
# Name: wordid, dtype: int64
# overthrow_vrb    66
# overthrow_nou    34
# Name: wordid, dtype: int64
# pasty_adj    70
# pasty_nou    24
# Name: wordid, dtype: int64
# perfect_adj    95
# perfect_vrb     6
# Name: wordid, dtype: int64
# perfume_nou    97
# perfume_vrb     3
# Name: wordid, dtype: int64
# permit_nou    54
# permit_vrb    45
# Name: wordid, dtype: int64
# pervert_nou    76
# pervert_vrb    24
# Name: wordid, dtype: int64
# polish_geo    97
# polish         3
# Name: wordid, dtype: int64
# postulate_nou    65
# postulate_vrb    35
# Name: wordid, dtype: int64
# precipitate_vrb        60
# precipitate_adj-nou    40
# Name: wordid, dtype: int64
# present_adj-nou    91
# present_vrb         9
# Name: wordid, dtype: int64
# produce_vrb    92
# produce_nou     8
# Name: wordid, dtype: int64
# progress_nou    81
# progress_vrb    18
# Name: wordid, dtype: int64
# protest_nou    90
# protest_vrb    10
# Name: wordid, dtype: int64
# read_present    66
# read_past       59
# Name: wordid, dtype: int64
# reading_en     82
# reading_geo    18
# Name: wordid, dtype: int64
# rebel_nou    93
# rebel_vrb     7
# Name: wordid, dtype: int64
# record_nou    88
# record_vrb    12
# Name: wordid, dtype: int64
# recount_nou    72
# recount_vrb    28
# Name: wordid, dtype: int64
# refund_nou    73
# refund_vrb    27
# Name: wordid, dtype: int64
# refuse_vrb    85
# refuse_nou    15
# Name: wordid, dtype: int64
# reject_vrb    91
# reject_nou     5
# Name: wordid, dtype: int64
# rerelease        86
# rerelease_vrb    14
# Name: wordid, dtype: int64
# resume_vrb    90
# resume_nou     8
# Name: wordid, dtype: int64
# retard_vrb    79
# retard_nou    15
# Name: wordid, dtype: int64
# rodeo        93
# rodeo_geo     3
# Name: wordid, dtype: int64
# sake       83
# sake_jp    16
# Name: wordid, dtype: int64
# separate_adj    94
# separate_vrb     7
# Name: wordid, dtype: int64
# sow        60
# sow_nou    36
# Name: wordid, dtype: int64
# subordinate_adj-nou    97
# subordinate_vrb         3
# Name: wordid, dtype: int64
# supplement_nou    66
# supplement_vrb    33
# Name: wordid, dtype: int64
# suspect_adj-nou    73
# suspect_vrb        27
# Name: wordid, dtype: int64
# syndicate_nou    96
# syndicate_vrb     4
# Name: wordid, dtype: int64
# tear_vrb    66
# tear_nou    33
# Name: wordid, dtype: int64
# transform        68
# transform_nou    32
# Name: wordid, dtype: int64
# transplant_nou    94
# transplant_vrb     6
# Name: wordid, dtype: int64
# transport_nou    93
# transport_vrb     6
# Name: wordid, dtype: int64
# upset_nou    72
# upset_vrb    27
# Name: wordid, dtype: int64
# use_nou    58
# use_vrb    43
# Name: wordid, dtype: int64
# uses_vrb    87
# uses_nou    13
# Name: wordid, dtype: int64
# wind_nou    94
# wind_vrb     6
# Name: wordid, dtype: int64
# winds_nou    91
# winds_vrb     6
# Name: wordid, dtype: int64
# wound_nou-vrb    66
# wound_vrb        33
# Name: wordid, dtype: int64

# %% [markdown]
# ## Serialize splits

# %%
for i, gp in all_data.groupby('homograph'): 
    train, dev, test = stratify_sample(gp)

    #serialize
    train.to_csv(NEW_TRAIN + '{}.tsv'.format(i), sep='\t', index=False)
    dev.to_csv(NEW_DEV + '{}.tsv'.format(i), sep='\t', index=False)
    test.to_csv(NEW_TEST + '{}.tsv'.format(i), sep='\t', index=False)
# Out:
# abuse_nou
# 90
# train
# 72
# dev
# 9
# test
# 9
# abuse_vrb
# 10
# train
# 8
# dev
# 1
# test
# 1
# abuses_nou
# 83
# train
# 66
# dev
# 8
# test
# 9
# abuses_vrb
# 17
# train
# 14
# dev
# 2
# test
# 1
# advocate_nou
# 83
# train
# 66
# dev
# 8
# test
# 9
# advocate_vrb
# 17
# train
# 14
# dev
# 2
# test
# 1
# affect
# 95
# train
# 76
# dev
# 10
# test
# 9
# affect_nou-psy
# 5
# train
# 4
# dev
# 1
# test
# 1
# affiliate_nou
# 96
# train
# 77
# dev
# 10
# test
# 9
# affiliate_vrb
# 3
# train
# 1
# dev
# 1
# test
# 1
# aged
# 96
# train
# 77
# dev
# 10
# test
# 9
# aged_adj
# 5
# train
# 4
# dev
# 1
# test
# 1
# aggregate_adj-nou
# 88
# train
# 70
# dev
# 9
# test
# 9
# aggregate_vrb
# 10
# train
# 8
# dev
# 1
# test
# 1
# alternate_adj-nou
# 97
# train
# 78
# dev
# 10
# test
# 9
# alternate_vrb
# 5
# train
# 4
# dev
# 1
# test
# 1
# analyses_nou
# 89
# train
# 71
# dev
# 9
# test
# 9
# analyses_vrb
# 11
# train
# 9
# dev
# 1
# test
# 1
# animate_adj-nou
# 37
# train
# 30
# dev
# 4
# test
# 3
# animate_vrb
# 58
# train
# 46
# dev
# 6
# test
# 6
# approximate_adj-nou
# 88
# train
# 70
# dev
# 9
# test
# 9
# approximate_vrb
# 11
# train
# 9
# dev
# 1
# test
# 1
# articulate_adj
# 46
# train
# 37
# dev
# 4
# test
# 5
# articulate_vrb
# 54
# train
# 43
# dev
# 6
# test
# 5
# associate_adj-nou
# 88
# train
# 70
# dev
# 9
# test
# 9
# associate_vrb
# 12
# train
# 10
# dev
# 1
# test
# 1
# attribute_nou
# 54
# train
# 43
# dev
# 6
# test
# 5
# attribute_vrb
# 46
# train
# 37
# dev
# 4
# test
# 5
# axes_nou
# 51
# train
# 41
# dev
# 5
# test
# 5
# axes_nou-vrb
# 49
# train
# 39
# dev
# 5
# test
# 5
# bass
# 84
# train
# 67
# dev
# 8
# test
# 9
# bass_corp
# 13
# train
# 10
# dev
# 2
# test
# 1
# blessed_adj
# 45
# train
# 36
# dev
# 4
# test
# 5
# blessed_vrb
# 51
# train
# 41
# dev
# 5
# test
# 5
# bow_nou-knot
# 47
# train

# %% [markdown]
# # Description
# **Functionality**: This module creates a new train, dev and test set with WHD and SWBD data.
#
# **Use**: The augmented data is used to train non-baseline models.

# %% [markdown]
# ### Imports

# %%
import os
import shutil
from glob import iglob
import pandas as pd
from tqdm import tqdm
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ### Variables

# %%
#Paths 

SWBD = "C:/Users/jseal/Dev/dissertation/Data/SWBD/SWBD_Homographs/swbd_homs.tsv"
NEW_SAMPLES_FORMATTED = "C:/Users/jseal/Dev/dissertation/Data/SWBD/SWBD_Homographs/swbd_new_samples_formatted.tsv"
SWBD_HOMS_META = "C:/Users/jseal/Dev/dissertation/Data/SWBD/SWBD_Homographs/swbd_homs_meta.tsv"
LOW_ACC_PATH = 'C:/Users/jseal/Dev/dissertation/Data/WHD_ALBERT/classes_w_accuracy_below_1-albert.tsv' #albert is lowest performing model
LABELS_PATH = 'C:/Users/jseal/Dev/dissertation/Data/WHD_Bert/variant_stratified/labels.txt'
WORDIDS_PATH = 'C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/wordids.tsv'

WHD_DATA = "C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/"
THREE_SPLITS = WHD_DATA + "three_split_stratified_variant_data_corrected/"
TRAIN = THREE_SPLITS + "train/"
DEV = THREE_SPLITS + "dev/"
TEST = THREE_SPLITS + "test/"
WHD_PATHS = [TRAIN, DEV, TEST]
TRAIN_AUG = THREE_SPLITS + "train_swbd_aug/"
DEV_AUG = THREE_SPLITS + "dev_swbd_aug/"
TEST_AUG = THREE_SPLITS + "test_swbd_aug/"
PATHS = [TRAIN_AUG, DEV_AUG, TEST_AUG]

pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Functions

# %%
def make_df(split_dir): 
    dfs = []
    for f in tqdm(iglob(split_dir +'*.tsv')):
        f_name = os.path.basename(f)
        dfs.append(pd.read_table(f))
    return dfs


def stratify_sample(data_df):
    data_df = data_df.sample(frac=1)
    #Append stratified samples per wordid, with enforcement of at least one sample per split
    train_samples = []
    dev_samples = []
    test_samples = []
    for i, gp in data_df.groupby("wordid"):         
        #Randomize samples
        gp = gp.sample(frac=1)
        if len(gp) == 1:
            train = gp
        elif len(gp) == 2:     
            train = gp.head(1) 
            test = gp.tail(1)
        #If only three samples, assign one to each split
        elif len(gp) == 3: 
            train = gp.head(1) 
            test = gp.tail(1)
            dev = gp[~gp.orig_idx.isin(train.orig_idx)]
            dev = dev[~dev.orig_idx.isin(test.orig_idx)]
            print('train')
            print(train.shape[0])
            print('dev')
            print(dev.shape[0])
            assert len(dev) > 0, f"dev has no samples"
            assert (set(train.orig_idx) & set(dev.orig_idx)) == set(), f"train and dev not mutex. Mutual idx: " + str(set(train.orig_idx) & set(dev.orig_idx))
            print('test')
            print(test.shape[0])
            assert len(test) > 0, f"test has no samples"
            assert (set(train.orig_idx) & set(test.orig_idx)) == set(), f"train and test not mutex. Mutual idx: " + str(set(train.orig_idx) & set(test.orig_idx))
            assert (set(dev.orig_idx) & set(test.orig_idx)) == set(), f"dev and test not mutex. Mutual idx: : " + str(set(dev.orig_idx) & set(test.orig_idx))
            
            train_samples.append(train)
            dev_samples.append(dev)
            test_samples.append(test)
        
        else:
            n = gp.shape[0]
            #Take 80% for train
            train = gp.sample(frac=.8)
            print('train')
            print(train.shape[0])
            #Used to check if the data left after train is 
            #created has at least 2 samples - one for dev, and one for test
            check_rest = gp[~gp.index.isin(train.index)]
        
            if (len(check_rest) < 2): 

                #If less than 2, take the last sample from train, and make a new train
                train_new = train[:-1]
                train_samples.append(train_new)
                # Make new remaining data by removing smaller, new train set
                dev_test = gp[~gp.index.isin(train_new.index)]
                dev = dev_test.head(1)
                print('dev')
                print(dev.shape[0])
                assert len(dev) > 0, f"dev has no samples"
                assert (set(train_new.orig_idx) & set(dev.orig_idx)) == set(), f"train and dev not mutex. Mutual idx: " + str(set(train_new.orig_idx) & set(dev.orig_idx))
                dev_samples.append(dev)
                
                test = dev_test.tail(1)
                print('test')
                print(test.shape[0])
                assert len(test) > 0, f"test has no samples"
                assert (set(train_new.orig_idx) & set(test.orig_idx)) == set(), f"train and test not mutex. Mutual idx: " + str(set(train.orig_idx) & set(test.orig_idx))
                assert (set(dev.orig_idx) & set(test.orig_idx)) == set(), f"dev and test not mutex. Mutual idx: : " + str(set(dev.orig_idx) & set(test.orig_idx))
                test_samples.append(test)
            else: 
                train_samples.append(train)
                dev_test = gp[~gp.index.isin(train.index)]
                
                dev = dev_test.sample(frac=.5)
                print('dev')
                print(dev.shape[0])
                assert len(dev) > 0, f"dev has no samples"
                assert (set(train.orig_idx) & set(dev.orig_idx)) == set(), f"train and dev not mutex. Mutual idx: " + str(set(train.orig_idx) & set(dev.orig_idx))
                dev_samples.append(dev)
                
                test = dev_test[~dev_test.index.isin(dev.index)]
                print('test')
                print(test.shape[0])
                assert len(test) > 0, f"test has no samples"
                assert (set(train.orig_idx) & set(test.orig_idx)) == set(), f"train and test not mutex. Mutual idx: " + str(set(train.orig_idx) & set(test.orig_idx))
                assert (set(dev.orig_idx) & set(test.orig_idx)) == set(), f"dev and test not mutex. Mutual idx: : " + str(set(dev.orig_idx) & set(test.orig_idx))
                test_samples.append(test)
    if train_samples: 
        train_df = pd.concat(train_samples)
    else: 
        train_df = pd.DataFrame()
    if dev_samples:     
        dev_df = pd.concat(dev_samples)
    else: 
        dev_df = pd.DataFrame()
    if test_samples:
        test_df = pd.concat(test_samples)
    else: 
        test_df = pd.DataFrame()

    return train_df, dev_df, test_df

# %% [markdown]
# # Script

# %%
swbd_df = pd.read_csv(SWBD, sep='\t')
wordids_df = pd.read_csv(WORDIDS_PATH, sep='\t')
new_samples_df = pd.read_csv(NEW_SAMPLES_FORMATTED, sep='\t')

# %%
def correct_me(x):
    x = x.capitalize()
    x = x.replace(" i ", " I ")
    x = x.replace('<unk>','')
    nlp_x = nlp(x)
    ents = [tok.text for tok in nlp_x.ents if ('<' not in tok.text) 
                                                        and ((tok.label_ == 'GPE') 
                                                             or (tok.label_ == 'NORP')
                                                             or (tok.label_ == 'PERSON')
                                                             or (tok.label_ == 'LOC')
                                                             or (tok.label_ == 'ORG'))]
    x = [tok.capitalize() if tok in ents else tok for tok in x.split(' ')]
    return ' '.join(x)

# %%
new_samples_df['sentence_new'] = new_samples_df.sentence.apply(lambda x: correct_me(x))

# %%
new_samples_df.sentence_new
# Out:
# 0      Well I guess I would first identify myself as ...
# 1                                   And I aged ten years
# 2                             We we  very similarly aged
# 3      Once once I was declared an alternate and I wa...
# 4      Even when I was in elementary school years ago...
# 5      The neighborhood that we live they are switchi...
# 6                         I was an alternate on the case
# 7      And one of the ones that had an impact was uh ...
# 8      There are so many people with with their petty...
# 9      So I have not done uh much freshwater fishing ...
# 10     And they  say well there s a big bass tourname...
# 11                                    Catching tree bass
# 12                                      Do you have bass
# 13               Now they have a lot of bass tournaments
# 14     We have a lot of uh uh couple of lakes in our ...
# 15                 And I do a lot of fishing for uh bass
# 16     I think that uh probably around here people fi...
# 17     The last time I went uh bass fishing I was wit...
# 18                 You know I have done some bow hunting
# 19         For me I would much rather have a bow anytime
# 20     And there s a power structure that you have bo...
# 21     I mean when you a religion that most of the pe...
# 22     Even if I m uh doing something like an Afghan ...
# 23                       And we are so close to shopping
# 24     They can not close off the Mexican border not ...
# 25     So any any vacation that we go on is usually i...
# 26                             And they  get close to it
# 27     I I m in Washington d c or at least very close...
# 28     And uh it s just remarkable how close it will ...
# 29     Now maybe you know that s pretty close to what...
# 30     The child is going why do n't you want to be c...
# 31                I mean I  never seen two cats so close
# 32                           So they were all real close
# 33     Do n't you want to be close to me I mean you k...
# 34     We keep in close contact with grandparents and...
# 35     And I and I i kind of see that that you know p...
# 36         I do n't know how close I  follow them though
# 37     How do you feel about them I mean since you  k...
# 38       Um especially there was a little store close by
# 39     Because s san antonio is n't that close to you...
# 40                             Well that s close to here
# 41     And and the two cars that apparently are close...
# 42                                 So it s getting close
# 43     About maybe oh close to a year ago now I guess...
# 44                      But that s uh the they  so close
# 45      And I think maybe he would if it came real close
# 46     And because my brother is there uh he would ha...
# 47     But uh you know since I live here so close to ...
# 48     Well now can I improvise with adding and using...
# 49     And so we would drive up to see that when  whe...
# 50     And they  also see that there s there s a diff...
# 51     Well well we live we live really close to lake...
# 52                                            Real close
# 53     But but supposedly once you have an office in ...
# 54     In Texas I m serious if it gets cold and it lo...
# 55     Like if I if I put her in a room all by hersel...
# 56     But to me Texas see and Kentucky we had to hav...
# 57     I love to just lay back on the couch and and t...
# 58                    And uh I just close it out I guess
# 59     Well if they close it in see we  have the best...
# 60     Well back during the viet nam conflict that no...
# 61     One of the things that I found interesting las...
# 62     It s like they were using them as friends when...
# 63     And they say that uh that there was  that ther...
# 64     And I think the issue should be settled before...
# 65     So there possibly were because you know you al...
# 66           You mean in the in the most recent conflict
# 67     So we have a conflict of interests on the weekend
# 68                           So they  pretty content now
# 69               And it s like hey we  content with this
# 70     As a matter of fact I m very content to spend ...
# 71     And I do n't know why we could n't have duplic...
# 72     And uh we we were a little bit too frequent I ...
# 73     And presently we have quite a few frequent fly...
# 74                      Women are n't nearly as frequent
# 75     So um I think you need to make you know if you...
# 76     But they  they  supposed to initiate that some...
# 77     And uh I think that was a big stepping stone f...
# 78     Was it hard to decide who to invite and who no...
# 79     Was it hard to decide who to invite and who no...
# 80     And nor and they  doing something that normall...
# 162    You know so uh the only thing we  you know tha...
# 163    And then we have to take another one that s mi...
# 164    How are we supposed to present the imagine tha...
# 165    Uh it sounds like in a certain sense at least ...
# 166    And uh I find a little present on the floor so...
# 167    Well it was the equivalent of a christmas present
# 168    And I happened to need a birthday present for ...
# 169    Now I was warlock too which is supposed to be ...
# 170             Well at the present time I have two dogs
# 171                            And you present your case
# 172    It s more in how you present it versus you kno...
# 173    How are we supposed to present the imagine tha...
# 174    Well I had heard a couple of people you know t...
# 175    Well another thing I think would be helpful wo...
# 176    And I hope maybe we  going to get somewhere wi...
# 177    The the difficulty with with dancing with wolv...
# 178    What s bad for the Soviet system is that they ...
# 179    And if he ca n't produce evidence not argument...
# 180    The only commitments that they  interested in ...
# 181    But there is a lot of energy in it if you can ...
# 182    I when I was younger I read about every king a...
# 183                                       So I then read
# 184                                    I think I read oh
# 185    But I as I say I was pretty much ashamed that ...
# 186    I m trying to think the last actual book I rea...
# 187                  But that s the last thing I i  read
# 188    I  read polls now where they  excused him beca...
# 189    On that same topic have you ever read anything...
# 190    So I do n't know how they expect them to uh pa...
# 191    But it seems as though if you really want to s...
# 192    Um I guess I  got so many books like that that...
# 193    You just say well look read the miles per hour...
# 194    Because they ca n't even get the menial job wi...
# 195    But when I do get to sit down and and read I l...
# 196    And I read the front page of the wall street j...
# 197    Uh a lot of times I do just read magazines and...
# 198    I d say first of all they need to go back to s...
# 199      And I have just now gotten around to reading it
# 200    Well I was just reading an article in uh a nor...
# 201    But uh I mean they they say it s like the sixt...
# 202                       So I like reading those to her
# 203    I was reading through a book on uh  human  res...
# 204    But it s well it s kind of it s kind of like r...
# 205                          But it s nice light reading
# 206    But I never seem to have the time to do that k...
# 207                                     Just joy reading
# 208    And I was just reading through a bicycle magaz...
# 209    And uh I was reading dune which seeming rather...
# 210    I was reading just recently where the typical ...
# 211                 They actually should do some reading
# 212    Not only am am I  reading it to decide whether...
# 213                          Well I was reading the book
# 214    And I uh of course I do n't ever get around to...
# 215               And it s really excellent fast reading
# 216    So I do n't know why what that was reading it for
# 217    But gee I just do n't have much time for enjoy...
# 218    But um I would always end up arriving at work ...
# 219            That what I  been reading lately a lot of
# 220            As a matter of fact he s reading on level
# 221    So I spend a lot of time looking through those...
# 222                                    You  reading dune
# 223        So I just finished reading that for enjoyment
# 224    Uh I was reading a an article in time the othe...
# 225    But I remember reading something a few months ...
# 226    And and I m getting rather good at reading wan...
# 227               There s one that I m reading right now
# 228    And you know there s part either as part of or...
# 229    Sometimes I put the cornstarch in a separate bowl
# 230    I m not sure all what we  going to have to do ...
# 231          But I m getting two separate  machines also
# 232    And someone else is n't going to take the time...
# 233        And he went to a a separate drug testing firm
# 234    And uh you know the type of facilities whether...
# 235                     And then I buy the bibs separate
# 236    The city brought ought you know set  separate ...
# 237       Like you have a separate account for that then
# 238              Did did they separate them by age group
# 239    And my thirteen year old is pretty separate fr...
# 240    Well they must they must keep it separate if t...
# 241    They have this day now that it s you know sepa...
# 242          And then how many a a freezer separate from
# 243    But then if you deteriorate um they have a sep...
# 244    Uh around here we have a program where uh we w...
# 245    Uh there s too much labor involved I guess to ...
# 246      But in uh in the paper one you have to separate
# 247    And you separate your glass and paper and uh a...
# 248                                        Separate them
# 249     And we have to separate our papers and our glass
# 250          You know they really did separate them well
# 251    They separate them as they as they you know du...
# 252    And uh they try to get you to go ahead and sep...
# 253    And that s real discouraging thinking you  sit...
# 254    The law enforcement community uh uh you know h...
# 255    But I do get tired of having to separate paper...
# 256    I really do n't understand that part on what t...
# 257    And you know we separate everything out and th...
# 258    We have a pilot program in Arlington going on ...
# 259    But that does n't negate that you do reap what...
# 260    And I just threw them on the side intending to...
# 261    So I just cut the leaves off and transplant an...
# 262    Uh and of course the side effects of this is t...
# 263    You know she always seems to have better thing...
# 264                                   We just use trail
# 265    So as far as at home use uh we  pick up a six ...
# 266    Have you ever used do you use  ever have you e...
# 267                   You can use it like any other card
# 268    But I did not know how to use those voting mac...
# 269    Well uh do you uh do you ever use the a t m ma...
# 270    You probably use  or something like that for y...
# 271            But I do n't usually use a word  to do it
# 272    Course the only problem with that is then nobo...
# 273    If you  going to use credit cards you need to ...
# 274    If I walk into a bad neighborhood I m sure I d...
# 275    And then you just dip the carcass in uh boilin...
# 276    Uh I do n't remember what they call it sort of...
# 277    I  heard that people that finally learn how to...
# 278                          So you ca n't use it anyway
# 279                         Well do you use credit cards
# 280    And we use to go go out to that about once a week
# 281                                          I use tapes
# 282    For the average person is exactly what he can ...
# 283    And if we ca n't take it and use it easily wel...
# 284                              So what do you use for
# 285                               What do you use it for
# 286    And then you pay that off and do n't use it un...
# 287    And you might even be able to to use it for fo...
# 288                           But we use it the same way
# 289                   And so I do n't use drugs any more
# 290    Do they save like the paper they they use at t...
# 291                         I suppose you could use that
# 292    You know because you know because uh the count...
# 293    They  come in and tell us that the switchboard...
# 294                              It could really wind up
# 295    Uh when you get to be my age and you start abu...
# 296    And I always wind up getting under the hood an...
# 297                And you wind up waiting about an hour
# 298    And uh I find if you  not careful you wind up ...
# 299    We all need that time just some quiet time to ...
# 300    And a lot of times what I wind up doing is pic...
# 301    Because people that uh do n't make very much m...
# 302    And they wind up back on the streets after fiv...
# 303    And so I wind up going out camping with uh a b...
# 304    So I wind up with my getting money back on my ...
# 305    Uh well um first off we d probably wind up wit...
# 306    And uh still you wind up meeting people you uh...
# 307    But we have such an affluent a society society...
# 308     And and it was a little bit hard to uh wind down
# 309         A a as soon as we wind up uh uh you know for
# 310    You know it s going to wind up hurting your st...
# 311    And you know they  they  wind up being good again
# 312                            What did you wind up with
# 313    So wound up back about two hundred miles aware...
# 314    And uh our cats wound up getting fleas uh from...
# 315    We wound up just choosing a another mennonite ...
# 316    So it s uh wound up that uh we  the old folks now
# 317    But the the interesting thing is that paint we...
# 318                             And he  he wound up pull
# 319    I wish uh it had started a long time ago is th...
# 320                           Wound up in administration
# 321    But course it s one of these with a twist wher...
# 322                        We wound up selling the house
# 323                          We  wound up sending in one
# 324                         And so it kind of wound down
# 325    But neither of them wound up going over which ...
# Name: sentence_new, dtype: object

# %%
#Labels/wordids after variance and low-resource data culling
with open(LABELS_PATH) as f:
    labels = f.readlines()
labels = [l.strip() for l in labels] 
final_wordids_df = wordids_df[wordids_df.wordid.isin(labels)]

#SWBD homograph pronunciations
swbd_new = set(swbd_df.new_label.tolist())

#Handling for stress mark interpretation as single quote
swbd_for_merge = []
for p in swbd_new:
    if type(p) == str:
        p = "\"" + p + "\""
        swbd_for_merge.append(p)
        
swbd_pronunciations = final_wordids_df.pronunciation.tolist()
prons_check = [pron[1:] if pron.startswith("'") else pron for pron in swbd_pronunciations] 

def get_pron(label):
    check_real = zip(prons_check, swbd_pronunciations)
    for c, r in check_real: 
        if label == c:
            return r
        
swbd_df['pronunciation'] = swbd_df['new_label'].apply(lambda x: get_pron(x))
final = pd.merge(final_wordids_df, swbd_df, on='pronunciation')

# %%
swbd_homs_meta = pd.read_csv(SWBD_HOMS_META, sep='\t')

# %%
swbd_homs_meta = swbd_homs_meta[['wordid', 'allowed_new_samples']]

# %%
new_samples = []
for i, grp in final.groupby('wordid'):
    for row in swbd_homs_meta.iterrows():
        if row[1][0] == i:
            if len(grp) >= row[1][1]:
                samples = grp.sample(n=row[1][1])
                new_samples.append(samples)
            else:
                new_samples.append(grp)

new_samples_df = pd.concat(new_samples)
new_samples_df.groupby('homograph_x')['wordid'].value_counts().sum()
# Out:
# 326

# %%
import re
new_samples_df['sentence'] = new_samples_df['sentence'].apply(lambda x : correct_me(x))
new_samples_df['sentence']
# Out:
# 26      Well I guess I would first identify myself as ...
# 27                                   And I aged ten years
# 28                             We we  very similarly aged
# 29      Once once I was declared an alternate and I wa...
# 30      Even when I was in elementary school years ago...
# 31      The neighborhood that we live they are switchi...
# 32                         I was an alternate on the case
# 33      And one of the ones that had an impact was uh ...
# 37      There are so many people with with their petty...
# 38      So I have not done uh much freshwater fishing ...
# 39      And they  say well there s a big bass tourname...
# 40                                     Catching tree bass
# 41                                       Do you have bass
# 42                Now they have a lot of bass tournaments
# 43      We have a lot of uh uh couple of lakes in our ...
# 44                  And I do a lot of fishing for uh bass
# 45      I think that uh probably around here people fi...
# 46      The last time I went uh bass fishing I was wit...
# 49                  You know I have done some bow hunting
# 50          For me I would much rather have a bow anytime
# 51      And there s a power structure that you have bo...
# 52      I mean when you a religion that most of the pe...
# 144     I think if we had to sell now we could come cl...
# 124     So it s close to getting uh one t v per person...
# 80                       But uh I guess it s close enough
# 81       why do you think that it s less close than it...
# 138     They can not close off the Mexican border not ...
# 91      The house that house that I bought is close to...
# 110     But I i would imagine that because of the how ...
# 140         See and here in lubbock everything s so close
# 113     And of course we were close enough that we cou...
# 53         It looks like it s come close to that as it is
# 146     And so uh it s not quite as close as it used t...
# 69       I live here because it s close to the university
# 120     And they  also see that there s there s a diff...
# 90      Well we live uh pretty close to the mesquite g...
# 92      Latin you know is very very very close to spanish
# 136     That the people that worked there were very we...
# 83      Well but the majority of them are in like just...
# 86      The child is going why do n't you want to be c...
# 122     It when I came on it was great because I had n...
# 141                  Your family does n't live close then
# 99                              Well that s close to here
# 73      And uh it s just remarkable how close it will ...
# 72                                  So it s getting close
# 54      I do n't know that it s ever been seriously co...
# 74                 I mean I  never seen two cats so close
# 1018    I d say first of all they need to go back to s...
# 927                                         I was reading
# 923     I I was reading the other day about uh corpus ...
# 1020                        I uh was reading in uh a book
# 963      Therefore my my reading pleasures are quite wide
# 964                           But it s nice light reading
# 991     I was reading just recently where the typical ...
# 986     If I m really interested in what I m reading I...
# 928     That is an intriguing type of book to be readi...
# 985     Um I do n't do as much reading like I say as I...
# 926     But I never seem to have the time to do that k...
# 939     And I think that that s why reading is so impo...
# 950                There s one that I m reading right now
# 954                            But but it is good reading
# 984     If I start into something and I really enjoy w...
# 948     And I read the whole damn book while I was hom...
# 947     So I do n't know why what that was reading it for
# 979            And all I do is teach reading all day long
# 1443    And you know there s part either as part of or...
# 1444    Sometimes I put the cornstarch in a separate bowl
# 1445    I m not sure all what we  going to have to do ...
# 1446          But I m getting two separate  machines also
# 1447    And someone else is n't going to take the time...
# 1448        And he went to a a separate drug testing firm
# 1449    And uh you know the type of facilities whether...
# 1450                     And then I buy the bibs separate
# 1451    The city brought ought you know set  separate ...
# 1452       Like you have a separate account for that then
# 1453              Did did they separate them by age group
# 1454    And my thirteen year old is pretty separate fr...
# 1455    Well they must they must keep it separate if t...
# 1456    They have this day now that it s you know sepa...
# 1457          And then how many a a freezer separate from
# 1458    But then if you deteriorate um they have a sep...
# 1459    Uh around here we have a program where uh we w...
# 1460    Uh there s too much labor involved I guess to ...
# 1461      But in uh in the paper one you have to separate
# 1462    And you separate your glass and paper and uh a...
# 1463                                        Separate them
# 1464     And we have to separate our papers and our glass
# 1465          You know they really did separate them well
# 1466    They separate them as they as they you know du...
# 1467    And uh they try to get you to go ahead and sep...
# 1468    And that s real discouraging thinking you  sit...
# 1469    The law enforcement community uh uh you know h...
# 1470    But I do get tired of having to separate paper...
# 1471    I really do n't understand that part on what t...
# 1472    And you know we separate everything out and th...
# 1473    We have a pilot program in Arlington going on ...
# 1474    But that does n't negate that you do reap what...
# 1502    And I just threw them on the side intending to...
# 1503    So I just cut the leaves off and transplant an...
# 1504    Uh and of course the side effects of this is t...
# 1609    But I think that if I learn how to use one I w...
# 1833                          So you ca n't use it anyway
# 1606    And they  the ones that are the tough ones to ...
# 1784                                  And so we use those
# 1807    So if there s people out there that are willin...
# 1915    If someone was out to get you I think that a c...
# 1878         And we like here we use the p c s to do that
# 1630    I just do n't know if I d have the time to use it
# 1667                    What do you use yours at home for
# 1702    Mostly I use it for writing papers and things ...
# 1712    I mean I mean n everybody knows that it that t...
# 1773    I do n't use it as much as my children and my ...
# 1822                                         We use a lot
# 1896                                   And I and I use it
# 1902    Which one do you feel is better since you use ...
# 1766        And a uh we  use a wood burning stove as well
# 1872         She s not going to do it not going to use it
# 1837    Course the only problem with that is then nobo...
# 1882    Because I did n't think I was really going to ...
# 1803    Or if they  sent you a uh a number that you ca...
# 1810      So that people would use this stuff  over again
# 1853    So you know and yet they yet people get very f...
# 1864                             Now I i do use gas cards
# 1664                                   Use it as a just a
# 1865             They do n't know that I do n't use drugs
# 1625       I use to do a lot more and sell at craft shows
# 1770    It also depends on who s cooking it and how mu...
# 1682    It is the only way that you can use television...
# 1619                               What do you use it for
# 1961    You know because you know because uh the count...
# 1962    They  come in and tell us that the switchboard...
# 1963                              It could really wind up
# 1964    Uh when you get to be my age and you start abu...
# 1965    And I always wind up getting under the hood an...
# 1966                And you wind up waiting about an hour
# 1967    And uh I find if you  not careful you wind up ...
# 1968    We all need that time just some quiet time to ...
# 1969    And a lot of times what I wind up doing is pic...
# 1970    Because people that uh do n't make very much m...
# 1971    And they wind up back on the streets after fiv...
# 1972    And so I wind up going out camping with uh a b...
# 1973    So I wind up with my getting money back on my ...
# 1974    Uh well um first off we d probably wind up wit...
# 1975    And uh still you wind up meeting people you uh...
# 1976    But we have such an affluent a society society...
# 1977     And and it was a little bit hard to uh wind down
# 1978         A a as soon as we wind up uh uh you know for
# 1979    You know it s going to wind up hurting your st...
# 1980    And you know they  they  wind up being good again
# 1981                            What did you wind up with
# 1986    So wound up back about two hundred miles aware...
# 1987    And uh our cats wound up getting fleas uh from...
# 1988    We wound up just choosing a another mennonite ...
# 1989    So it s uh wound up that uh we  the old folks now
# 1990    But the the interesting thing is that paint we...
# 1991                             And he  he wound up pull
# 1992    I wish uh it had started a long time ago is th...
# 1993                           Wound up in administration
# 1994    But course it s one of these with a twist wher...
# 1995                        We wound up selling the house
# 1996                          We  wound up sending in one
# 1997                         And so it kind of wound down
# 1998    But neither of them wound up going over which ...
# Name: sentence, dtype: object

# %%
new_samples_df.head()
# Out:
#    homograph_x             wordid           label pronunciation  \
# 26        aged           aged_adj             old        'eɪʤəd
# 27        aged           aged_adj             old        'eɪʤəd
# 28        aged           aged_adj             old        'eɪʤəd
# 29   alternate  alternate_adj-nou  adjective-noun     'ɑːltɚnət
# 30   alternate  alternate_adj-nou  adjective-noun     'ɑːltɚnət
#
#      homograph_type fine_homograph_type                       file_name  \
# 26          Lexical                 PSI     sw02145_s2_1-s2_13.TextGrid
# 27          Lexical                 PSI  sw02305_s181_1-s181_5.TextGrid
# 28          Lexical                 PSI   sw02366_s21_2-s21_10.TextGrid
# 29  Morphosyntactic                 PoS   sw03503_s25_2-s25_23.TextGrid
# 30  Morphosyntactic                 PoS   sw02324_s76_1-s76_50.TextGrid
#
#    homograph_y    WHD_IPA_representations MFA-Arpabet-2-IPA  \
# 26        aged           ['eɪʤəd' 'eɪʤd']              edʒd
# 27        aged           ['eɪʤəd' 'eɪʤd']              edʒd
# 28        aged           ['eɪʤəd' 'eɪʤd']              edʒd
# 29   alternate  ['ɑːltɚnət' 'ɑːltɚˌneɪt']          ˈɔltɝnʌt
# 30   alternate  ['ɑːltɚnət' 'ɑːltɚˌneɪt']          ˈɔltɝnʌt
#
#    Human-mapped_column_D_to_C_w_notes  \
# 26                               eɪʤd
# 27                               eɪʤd
# 28                               eɪʤd
# 29                           ɑːltɚnət
# 30                           ɑːltɚnət
#
#                                              sentence new_label
# 26  Well I guess I would first identify myself as ...     eɪʤəd
# 27                               And I aged ten years     eɪʤəd
# 28                         We we  very similarly aged     eɪʤəd
# 29  Once once I was declared an alternate and I wa...  ɑːltɚnət
# 30  Even when I was in elementary school years ago...  ɑːltɚnət

# %%
samples_for_paper = new_samples_df[['homograph_x', 'WHD_IPA_representations', 'MFA-Arpabet-2-IPA', 'pronunciation', 'sentence']].rename(columns = {'homograph_x' : 'homograph', 'MFA-Arpabet-2-IPA' : 'auto-IPA', 'pronunciation' : 'WHD IPA'})

# %%
samples_for_paper.head()
# Out:
#     homograph    WHD_IPA_representations  auto-IPA    WHD IPA  \
# 26       aged           ['eɪʤəd' 'eɪʤd']      edʒd     'eɪʤəd
# 27       aged           ['eɪʤəd' 'eɪʤd']      edʒd     'eɪʤəd
# 28       aged           ['eɪʤəd' 'eɪʤd']      edʒd     'eɪʤəd
# 29  alternate  ['ɑːltɚnət' 'ɑːltɚˌneɪt']  ˈɔltɝnʌt  'ɑːltɚnət
# 30  alternate  ['ɑːltɚnət' 'ɑːltɚˌneɪt']  ˈɔltɝnʌt  'ɑːltɚnət
#
#                                              sentence
# 26  Well I guess I would first identify myself as ...
# 27                               And I aged ten years
# 28                         We we  very similarly aged
# 29  Once once I was declared an alternate and I wa...
# 30  Even when I was in elementary school years ago...

# %%
samples_for_paper.to_csv('./SWBD_WHD_samples.tsv', sep='\t', index=False)

# %%
samples_for_paper.to_latex(index=False,longtable=True, buf='SWBDhomprons', caption='SWBD homograph pronunciation data', label='SWBDhomprons')

# %%
new_samples = new_samples_df[['homograph_x', 'wordid', 'sentence']].rename(columns = {'homograph_x' : 'homograph'})

new_samples['orig_idx'] = new_samples.index

# %%
#new_samples.to_csv("C:/Users/jseal/Dev/dissertation/Data/SWBD/SWBD_Homographs/swbd_new_samples_formatted.tsv", sep='\t')

# %%
#all_data = combine_train_eval_swbd()

# %%
#all_data.head(10)

# %%
for i, gp in new_samples.groupby('homograph'): 
    print(gp['wordid'].value_counts())
# Out:
# aged_adj    3
# Name: wordid, dtype: int64
# alternate_adj-nou    5
# Name: wordid, dtype: int64
# axes_nou-vrb    1
# Name: wordid, dtype: int64
# bass_corp    9
# Name: wordid, dtype: int64
# bow_nou-ship    2
# bow_nou-knot    2
# Name: wordid, dtype: int64
# close_adj-nou    31
# close_vrb         7
# Name: wordid, dtype: int64
# conflict_nou    8
# Name: wordid, dtype: int64
# content_adj-nou-vrb    3
# Name: wordid, dtype: int64
# duplicate_adj-nou    1
# Name: wordid, dtype: int64
# frequent_adj    4
# Name: wordid, dtype: int64
# initiate_vrb    2
# Name: wordid, dtype: int64
# invite_vrb    3
# Name: wordid, dtype: int64
# lead_nou-vrb    8
# Name: wordid, dtype: int64
# lives_vrb    29
# lives_nou    29
# Name: wordid, dtype: int64
# misuse_vrb    1
# Name: wordid, dtype: int64
# mobile    5
# Name: wordid, dtype: int64
# present_adj-nou    18
# present_vrb         4
# Name: wordid, dtype: int64
# produce_vrb    7
# Name: wordid, dtype: int64
# read_past       8
# read_present    8
# Name: wordid, dtype: int64
# reading_en    30
# Name: wordid, dtype: int64
# separate_adj    16
# separate_vrb    15
# Name: wordid, dtype: int64
# sow    1
# Name: wordid, dtype: int64
# transplant_vrb    2
# Name: wordid, dtype: int64
# transport_nou    1
# Name: wordid, dtype: int64
# use_vrb    29
# Name: wordid, dtype: int64
# wind_vrb    21
# Name: wordid, dtype: int64
# wound_vrb    13
# Name: wordid, dtype: int64

# %%
new_samples.wordid.nunique()
# Out:
# 33

# %% [markdown]
# ## Serialize splits

# %%
for i, gp in new_samples.groupby('homograph'): 
    train, dev, test = stratify_sample(gp)
    if not train.empty: 
        train = train[['homograph', 'wordid', 'sentence']]
        train_whd = pd.read_csv(TRAIN + "/" + i + ".tsv", sep="\t")
        train_final = pd.concat([train, train_whd], ignore_index=True)
        train_final = train_final.sample(frac=1)
    else: 
        train_final = train_whd
    if not dev.empty:
        dev = dev[['homograph', 'wordid', 'sentence']]
        dev_whd = pd.read_csv(DEV + "/" + i + ".tsv", sep="\t")
        dev_final = pd.concat([dev, dev_whd], ignore_index=True)
        dev_final = dev_final.sample(frac=1)
    else: 
        dev_final = dev_whd
    if not test.empty:
        test = test[['homograph', 'wordid', 'sentence']]
        test_whd = pd.read_csv(TEST + "/" + i + ".tsv", sep="\t")
        test_final = pd.concat([test, test_whd], ignore_index=True)
        test_final = test_final.sample(frac=1)
    else: 
        test = test_whd

    for path in PATHS:
        if not os.path.exists(path):
            os.mkdir(path)
    #serialize
    train_final.to_csv(TRAIN_AUG + '{}.tsv'.format(i), sep='\t', index=False)
    dev_final.to_csv(DEV_AUG + '{}.tsv'.format(i), sep='\t', index=False)
    test_final.to_csv(TEST_AUG + '{}.tsv'.format(i), sep='\t', index=False)
# Out:
# train
# 1
# dev
# 1
# test
# 1
# train
# 4
# dev
# 1
# test
# 1
# train
# 7
# dev
# 1
# test
# 1
# train
# 25
# dev
# 3
# test
# 3
# train
# 6
# dev
# 1
# test
# 1
# train
# 6
# dev
# 1
# test
# 1
# train
# 1
# dev
# 1
# test
# 1
# train
# 3
# dev
# 1
# test
# 1
# train
# 1
# dev
# 1
# test
# 1
# train
# 6
# dev
# 1
# test
# 1
# train
# 23
# dev
# 3
# test
# 3
# train
# 23
# dev
# 3
# test
# 3
# train
# 4
# dev
# 1
# test
# 1
# train
# 14
# dev
# 2
# test
# 2
# train
# 3
# dev
# 1
# test
# 1
# train
# 6
# dev
# 1
# test
# 1
# train
# 6
# dev
# 1
# test
# 1
# train
# 6
# dev
# 1
# test
# 1
# train
# 24
# dev
# 3
# test
# 3
# train
# 13
# dev
# 2
# test
# 1
# train
# 12
# dev
# 2
# test
# 1
# train
# 23
# dev
# 3
# test
# 3
# train
# 17
# dev
# 2
# test
# 2
# train
# 10
# dev
# 2
# test
# 1

# %%
augmented_homographs = []
for i, gp in new_samples.groupby('homograph'): 
    augmented_homographs.append(i)

# %%
for f in iglob(TRAIN +"/*"): 
    homograph = os.path.basename(f)[:-4]
    if homograph not in augmented_homographs:
        shutil.copyfile(f, TRAIN_AUG + os.path.basename(f))
        
for f in iglob(DEV +"/*"): 
    homograph = os.path.basename(f)[:-4]
    if homograph not in augmented_homographs:
        shutil.copyfile(f, DEV_AUG + os.path.basename(f))
        
for f in iglob(TEST +"/*"): 
    homograph = os.path.basename(f)[:-4]
    if homograph not in augmented_homographs:
        shutil.copyfile(f, TEST_AUG + os.path.basename(f))

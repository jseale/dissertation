# %% [markdown]
# # Description
# **Functionality**:
#
# **Use**:

# %%
import os
import shutil
from glob import glob
import pandas as pd
from tqdm import tqdm

# %%
#Paths 
WHD_DATA = "C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/"
TRAIN = WHD_DATA + "train/"
EVAL = WHD_DATA + "eval/"

WHD_DATA_VARIANT = "C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/variant_data/"
TRAIN_VARIANT = WHD_DATA_VARIANT + "train/"
EVAL_VARIANT = WHD_DATA_VARIANT + "eval/"

pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Script

# %%
dfs = []

for f in tqdm(glob(TRAIN +'*.tsv')):
    df = pd.read_table(f)
    dfs.append(df)

train_df = pd.concat(dfs)
to_remove = set()
for idx, group in train_df.groupby('homograph'): 
    if group['wordid'].nunique() == 1: 
        to_remove.update(group['homograph'])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 162/162 [00:00<00:00, 761.87it/s]
# 2
# ['abstract_adj-nou' 'abstract_vrb']
# 2
# ['abuse_nou' 'abuse_vrb']
# 2
# ['abuses_nou' 'abuses_vrb']
# 1
# ['addict_nou']
# 2
# ['advocate_nou' 'advocate_vrb']
# 2
# ['affect' 'affect_nou-psy']
# 2
# ['affiliate_vrb' 'affiliate_nou']
# 2
# ['aged' 'aged_adj']
# 2
# ['aggregate_adj-nou' 'aggregate_vrb']
# 2
# ['alternate_adj-nou' 'alternate_vrb']
# 2
# ['analyses_nou' 'analyses_vrb']
# 2
# ['animate_vrb' 'animate_adj-nou']
# 2
# ['appropriate_adj' 'appropriate_vrb']
# 2
# ['approximate_adj-nou' 'approximate_vrb']
# 2
# ['articulate_adj' 'articulate_vrb']
# 2
# ['associate_adj-nou' 'associate_vrb']
# 2
# ['attribute_vrb' 'attribute_nou']
# 3
# ['august_nam' 'august' 'august_adj']
# 2
# ['axes_nou' 'axes_nou-vrb']
# 2
# ['bass' 'bass_corp']
# 2
# ['blessed_adj' 'blessed_vrb']
# 2
# ['bologna_geo' 'bologna']
# 2
# ['bow_nou-knot' 'bow_nou-ship']
# 2
# ['buffet_nou' 'buffet_vrb']
# 2
# ['celtic_adj-nou-sports' 'celtic']
# 2
# ['close_adj-nou' 'close_vrb']
# 2
# ['combine_vrb' 'combine_nou']
# 1
# ['compact_adj-nou']
# 2
# ['compound_nou' 'compound_vrb']
# 2
# ['compress' 'compress_nou']
# 2
# ['conduct_vrb' 'conduct_nou']
# 2
# ['confines_nou' 'confines_vrb']
# 2
# ['conflict_nou' 'conflict_vrb']
# 1
# ['conglomerate_adj-nou']
# 2
# ['conjugate_adj-nou' 'conjugate_vrb']
# 2
# ['conscript_nou' 'conscript_vrb']
# 2
# ['console_nou' 'console_vrb']
# 1
# ['consort_nou']
# 2
# ['construct_vrb' 'construct_nou']
# 2
# ['consummate_adj' 'consummate_vrb']
# 2
# ['content_nou' 'content_adj-nou-vrb']
# 2
# ['contest_nou' 'contest_vrb']
# 2
# ['contract_nou' 'contract_vrb']
# 2
# ['contrast_nou' 'contrast_vrb']
# 2
# ['converse_vrb' 'converse_adj-nou']
# 2
# ['convert_vrb' 'convert_nou']
# 2
# ['convict_nou' 'convict_vrb']
# 2
# ['coordinate_vrb' 'coordinate_adj-nou']
# 2
# ['correlate_nou-vrb' 'correlate_nou']
# 2
# ['decrease_nou' 'decrease_vrb']
# 2
# ['defect_nou' 'defect_vrb']
# 2
# ['degenerate_adj-nou' 'degenerate_vrb']
# 2
# ['delegate_nou' 'delegate_vrb']
# 2
# ['deliberate_adj' 'deliberate_vrb']
# 1
# ['desert_nou']
# 2
# ['deviate_vrb' 'deviate_nou']
# 2
# ['diagnoses_nou' 'diagnoses_vrb']
# 2
# ['diffuse_adj' 'diffuse_vrb']
# 2
# ['discard_nou' 'discard_vrb']
# 2
# ['discharge_nou' 'discharge_vrb']
# 2
# ['discount_nou' 'discount_vrb']
# 2
# ['document_nou' 'document_vrb']
# 2
# ['dove_vrb' 'dove']
# 2
# ['duplicate_adj-nou' 'duplicate_vrb']
# 1
# ['elaborate_adj']
# 1
# ['entrance_nou']
# 2
# ['escort_nou' 'escort_vrb']
# 2
# ['estimate_nou' 'estimate_vrb']
# 2
# ['excuse_nou' 'excuse_vrb']
# 2
# ['expatriate_nou' 'expatriate_vrb']
# 2
# ['exploit_vrb' 'exploit_nou']
# 2
# ['export_nou' 'export_vrb']
# 2
# ['expose_vrb' 'expose_nou']
# 2
# ['extract_vrb' 'extract_nou']
# 2
# ['fragment_nou' 'fragment_vrb']
# 2
# ['frequent_adj' 'frequent_vrb']
# 2
# ['graduate_adj-nou' 'graduate_vrb']
# 2
# ['house_nou' 'house_vrb']
# 2
# ['impact_nou' 'impact_vrb']
# 2
# ['implant_nou' 'implant_vrb']
# 2
# ['implement_vrb' 'implement_nou']
# 2
# ['import_nou' 'import_vrb']
# 1
# ['incense_nou']
# 2
# ['incline_nou' 'incline_vrb']
# 2
# ['increase_vrb' 'increase_nou']
# 2
# ['increment_vrb' 'increment_nou']
# 2
# ['initiate_vrb' 'initiate_nou']
# 2
# ['insert_vrb' 'insert_nou']
# 1
# ['instrument_nou']
# 2
# ['insult_nou' 'insult_vrb']
# 1
# ['interchange_nou']
# 1
# ['intimate_adj']
# 2
# ['intrigue_nou' 'intrigue_nou-vrb']
# 2
# ['invalid_adj' 'invalid_nou']
# 2
# ['invert_vrb' 'invert_adj-nou']
# 2
# ['invite_vrb' 'invite_nou']
# 2
# ['isolate_nou' 'isolate']
# 2
# ['jesus' 'jesus_es']
# 1
# ['job']
# 2
# ['laminate_nou' 'laminate_vrb']
# 2
# ['lead_nou-vrb' 'lead_nou']
# 2
# ['learned_adj' 'learned_vrb']
# 2
# ['live_adj' 'live_vrb']
# 2
# ['lives_vrb' 'lives_nou']
# 2
# ['mate' 'mate_nou']
# 2
# ['minute' 'minute_adj']
# 2
# ['misuse_nou' 'misuse_vrb']
# 2
# ['mobile' 'mobile_geo']
# 2
# ['moderate_adj-nou' 'moderate_vrb']
# 1
# ['moped_nou']
# 1
# ['mouth_nou']
# 2
# ['nestle_nam' 'nestle_vrb']
# 1
# ['object_nou']
# 2
# ['ornament_nou' 'ornament_vrb']
# 2
# ['overthrow_nou' 'overthrow_vrb']
# 2
# ['pasty_adj' 'pasty_nou']
# 2
# ['perfect_adj' 'perfect_vrb']
# 2
# ['perfume_nou' 'perfume_vrb']
# 2
# ['permit_nou' 'permit_vrb']
# 2
# ['pervert_nou' 'pervert_vrb']
# 1
# ['pigment_nou']
# 2
# ['polish_geo' 'polish']
# 2
# ['postulate_nou' 'postulate_vrb']
# 2
# ['precipitate_vrb' 'precipitate_adj-nou']
# 2
# ['predicate_nou' 'predicate_vrb']
# 2
# ['present_adj-nou' 'present_vrb']
# 2
# ['produce_vrb' 'produce_nou']
# 2
# ['progress_nou' 'progress_vrb']
# 2
# ['project_nou' 'project_vrb']
# 2
# ['protest_nou' 'protest_vrb']
# 2
# ['ravel_nam' 'ravel_nou']
# 2
# ['read_past' 'read_present']
# 2
# ['reading_en' 'reading_geo']
# 2
# ['rebel_nou' 'rebel_vrb']
# 2
# ['record_nou' 'record_vrb']
# 2
# ['recount_nou' 'recount_vrb']
# 2
# ['refund_nou' 'refund_vrb']
# 2
# ['refuse_vrb' 'refuse_nou']
# 2
# ['reject_vrb' 'reject_nou']
# 2
# ['rerelease' 'rerelease_vrb']
# 2
# ['resume_vrb' 'resume_nou']
# 2
# ['retard_vrb' 'retard_nou']
# 2
# ['rodeo' 'rodeo_geo']
# 1
# ['row_1']
# 2
# ['sake_jp' 'sake']
# 2
# ['separate_adj' 'separate_vrb']
# 2
# ['sow_nou' 'sow']
# 1
# ['subject_adj-nou']
# 2
# ['subordinate_adj-nou' 'subordinate_vrb']
# 2
# ['supplement_vrb' 'supplement_nou']
# 2
# ['suspect_vrb' 'suspect_adj-nou']
# 2
# ['syndicate_nou' 'syndicate_vrb']
# 2
# ['tear_nou' 'tear_vrb']
# 2
# ['transform_nou' 'transform']
# 2
# ['transplant_nou' 'transplant_vrb']
# 2
# ['transport_nou' 'transport_vrb']
# 2
# ['upset_nou' 'upset_vrb']
# 2
# ['use_nou' 'use_vrb']
# 2
# ['uses_vrb' 'uses_nou']
# 2
# ['wind_nou' 'wind_vrb']
# 2
# ['winds_nou' 'winds_vrb']
# 2
# ['wound_nou-vrb' 'wound_vrb']

# %%
to_remove
# Out:
# {'addict',
#  'compact',
#  'conglomerate',
#  'consort',
#  'desert',
#  'elaborate',
#  'entrance',
#  'incense',
#  'instrument',
#  'interchange',
#  'intimate',
#  'job',
#  'moped',
#  'mouth',
#  'object',
#  'pigment',
#  'row',
#  'subject'}

# %%
for f in tqdm(glob(TRAIN +'*.tsv')):
    f_name = os.path.basename(f)
    if f_name[:-4] not in to_remove: 
        shutil.copy(f, TRAIN_VARIANT)

# %%
for f in tqdm(glob(EVAL +'*.tsv')):
    f_name = os.path.basename(f)
    if f_name[:-4] not in to_remove: 
        shutil.copy(f, EVAL_VARIANT)

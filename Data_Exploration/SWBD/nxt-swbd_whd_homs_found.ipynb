# %% [markdown]
# # Description
# **Functionality**: This module explores the homographs and pronunciation labels obtained from the NXT SWBD data set.
# **Use**:

# %% [markdown]
# ### Imports

# %%
import os
from datetime import datetime
import xml.etree.ElementTree as ET
import glob
from collections import Counter
import pandas as pd
from typing import List

# %% [markdown]
# ### Variables

# %%
DATA_PATH = 'C:/Users/jseal/Dev/dissertation/Data/SWBD/SWBD_Homographs/swbd_homs.tsv'
LABELS_PATH = 'C:/Users/jseal/Dev/dissertation/Data/WHD_Bert/variant_stratified/labels.txt'
WORDIDS_PATH = 'C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/wordids.tsv'
LOW_ACC_PATH = 'C:/Users/jseal/Dev/dissertation/Data/WHD_ALBERT/classes_w_accuracy_below_1-albert.tsv' #albert is lowest performing model

# %% [markdown]
# ### Functions

# %% [markdown]
# ## Script

# %%
data_df = pd.read_csv(DATA_PATH, sep='\t')
data_df.head()
# Out:
#                          file_name homograph WHD_IPA_representations  \
# 0   sw03012_s136_1-s136_4.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
# 1  sw04184_s102_1-s102_19.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
# 2    sw02597_s50_1-s50_25.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
# 3    sw04649_s99_1-s99_50.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
# 4  sw03049_s138_1-s138_15.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
#
#   MFA-Arpabet-2-IPA                 Human-mapped_column_D_to_C_w_notes  \
# 0            ʌˈbjuz                                            ə'bjuːz
# 1            ʌˈbjuz  ! - need to listen, col D seems incorrect, cou...
# 2            ʌˈbjuz                                            ə'bjuːz
# 3            ʌˈbjus                                            ə'bjuːs
# 4            ʌˈbjuz                                            ə'bjuːz
#
#                                             sentence new_label
# 0                                and they abuse that   ə'bjuːz
# 1  it takes a lot of training and a lot of abuse ...   ə'bjuːs
# 2  and they <unk> they do n't you know they do n'...   ə'bjuːz
# 3  i think the problems are more ones of cost and...   ə'bjuːs
# 4  i think it s time we had a lady abuse the guys...   ə'bjuːz

# %%
wordids_df = pd.read_csv(WORDIDS_PATH, sep='\t')
wordids_df.head()
# Out:
#   homograph            wordid           label pronunciation   homograph_type  \
# 0  abstract  abstract_adj-nou  adjective-noun    'æbˌstɹækt  Morphosyntactic
# 1  abstract      abstract_vrb            verb     əb'stɹækt  Morphosyntactic
# 2     abuse         abuse_nou            noun       ə'bjuːs  Morphosyntactic
# 3     abuse         abuse_vrb            verb       ə'bjuːz  Morphosyntactic
# 4    abuses        abuses_nou            noun     ə'bjuːsəz  Morphosyntactic
#
#   fine_homograph_type
# 0                 PoS
# 1                 PoS
# 2                 PoS
# 3                 PoS
# 4                 PoS

# %%
with open(LABELS_PATH) as f:
    labels = f.readlines()
labels = [l.strip() for l in labels]

# %%
len(labels)
# Out:
# 257

# %%
final_wordids_df = wordids_df[wordids_df.wordid.isin(labels)]

# %%
len(final_wordids_df)
# Out:
# 256

# %%
final_wordids_df.homograph.nunique()
# Out:
# 128

# %% [markdown]
# ### Get wordids, counts

# %%
data_df.new_label.nunique()
# Out:
# 130

# %%
swbd_new = set(data_df.new_label.tolist())
swbd_new
# Out:
# {'None',
#  'aɪsəˌleɪt',
#  'baʊ',
#  'blɛst',
#  'boʊ',
#  'bæs',
#  'diːˌkɹiːs',
#  'diːˌviːˌeɪt',
#  'doʊv',
#  'duːpləkət',
#  'dɑːkjəˌmɛnt',
#  "də'fɛkt",
#  "də'kɹiːs",
#  "də'lɪbɚət",
#  'dɛləˌɡeɪt',
#  'dɛzɚt',
#  'dɪsˌkaʊnt',
#  'eɪʤəd',
#  'fɹiːkwənt',
#  'haʊs',
#  'juːs',
#  'juːsəz',
#  'juːz',
#  'juːzəz',
#  'kloʊs',
#  'kloʊz',
#  'kɑːmˌpækt',
#  'kɑːnfləkt',
#  'kɑːnˌtɛnt',
#  'kɑːnˌtɛst',
#  'kɑːnˌtɹækt',
#  'kɑːnˌtɹæst',
#  "kəm'baɪn",
#  "kəm'pɹɛs",
#  "kən'stɹʌkt",
#  "kən'tɛnt",
#  "kən'tɹæst",
#  "kən'vɚt",
#  "kən'vɪkt",
#  'laɪv',
#  'laɪvz',
#  'liːd',
#  'lɚnd',
#  'lɛd',
#  'lɪv',
#  'lɪvz',
#  'maʊθ',
#  'moʊbəl',
#  'moʊˌbiːl',
#  "mɑːdɚ'eɪt",
#  'mɪnət',
#  nan,
#  "pɚ'mɪt",
#  'pɚfəkt',
#  'pɚmət',
#  'pɹoʊˌduːs',
#  'pɹoʊˌtɛst',
#  'pɹɑːˌɡɹɛs',
#  'pɹɑːˌʤɛkt',
#  "pɹə'duːs",
#  "pɹə'tɛst",
#  "pɹə'ɡɹɛs",
#  'pɹɛzənt',
#  'seɪk',
#  'soʊ',
#  "səb'ʤɛkt",
#  "səs'pɛkt",
#  'sɛpɚət',
#  'sɛpɚˌeɪt',
#  'sʌbˌʤɛkt',
#  'sʌpləˌmɛnt',
#  'sʌsˌpɛkt',
#  'tɛɹ',
#  'tɹænsˌplænt',
#  'tɹænsˌpɔːɹt',
#  'waɪnd',
#  'waɪndz',
#  'waʊnd',
#  'wɪnd',
#  'ædvəkət',
#  'ædvəˌkeɪt',
#  'æksəz',
#  'ɑːbʤəkt',
#  'ɑːltɚnət',
#  "ə'bjuːs",
#  "ə'bjuːz",
#  "ə'fɛkt",
#  "ə'fɪˌliːət",
#  "ə'læbɚət",
#  "ə'pɹoʊˌpɹiːət",
#  "ə'soʊˌsiːət",
#  "ə'soʊˌsiːˌeɪt",
#  "ə'tɹɪˌbjuːt",
#  "əb'ʤɛkt",
#  "ək'skjuːs",
#  "ək'skjuːz",
#  "ək'spoʊz",
#  "ən'kɹiːs",
#  "ən'vaɪt",
#  "ən'væləd",
#  'ɛstəmət',
#  'ɡɹæˌʤuːət',
#  "ɡɹæˌʤuːˌeɪt'",
#  'ɪmˌpækt',
#  'ɪnstɹəmənt',
#  'ɪntəmət',
#  'ɪnˌklaɪn',
#  'ɪnˌkɹiːs',
#  'ɪnˌvaɪt',
#  'ɹiːd',
#  'ɹiːdəŋ',
#  'ɹiːˌfʌnd',
#  'ɹoʊ',
#  "ɹə'bɛl",
#  "ɹə'fjuːz",
#  "ɹə'kɔːɹd",
#  "ɹə'ʤɛkt",
#  'ɹɛbəl',
#  'ɹɛd',
#  'ɹɛkɚd',
#  'ɹɛzəˌmeɪ',
#  'ɹɛˌfjuːs',
#  'ʤiːzəs',
#  'ʤɑːb',
#  "ˌmɪs'juːz",
#  "ˌpɹiː'zɛnt",
#  "ˌtɹæns'plænt",
#  "ˌɪ'nɪˌʃiːˌeɪt",
#  "ˌɪntɚ'ʧeɪnʤ",
#  "ˌɹɪ'fʌnd",
#  "ˌʌp'sɛt"}

# %%
swbd_for_merge = []
for p in swbd_new:
    if type(p) == str:
        p = "\"" + p + "\""
        swbd_for_merge.append(p)
# Out:
# "əb'ʤɛkt"
# "pɹɛzənt"
# "ɹə'ʤɛkt"
# "pɚ'mɪt"
# "pɹoʊˌtɛst"
# "kɑːnfləkt"
# "diːˌkɹiːs"
# "liːd"
# "kəm'pɹɛs"
# "kən'vɪkt"
# "sʌsˌpɛkt"
# "səs'pɛkt"
# "dɪsˌkaʊnt"
# "ɹə'fjuːz"
# "pɹoʊˌduːs"
# "lɪvz"
# "ɹə'bɛl"
# "juːz"
# "baʊ"
# "sɛpɚət"
# "haʊs"
# "ˌpɹiː'zɛnt"
# "ə'læbɚət"
# "laɪvz"
# "ɹoʊ"
# "ək'skjuːz"
# "ɪntəmət"
# "də'lɪbɚət"
# "juːzəz"
# "sɛpɚˌeɪt"
# "ə'fɛkt"
# "ˌɪntɚ'ʧeɪnʤ"
# "ən'kɹiːs"
# "aɪsəˌleɪt"
# "ək'skjuːs"
# "ɛstəmət"
# "ɪmˌpækt"
# "sʌbˌʤɛkt"
# "ædvəkət"
# "mɪnət"
# "ɪnˌklaɪn"
# "fɹiːkwənt"
# "lɛd"
# "ʤiːzəs"
# "ˌtɹæns'plænt"
# "də'fɛkt"
# "waɪndz"
# "kɑːmˌpækt"
# "ɡɹæˌʤuːˌeɪt'"
# "doʊv"
# "duːpləkət"
# "ɹɛbəl"
# "ən'vaɪt"
# "ɑːbʤəkt"
# "kɑːnˌtɹækt"
# "ɪnˌvaɪt"
# "ɑːltɚnət"
# "ɪnˌkɹiːs"
# "kən'stɹʌkt"
# "kloʊz"
# "pɹə'duːs"
# "ə'bjuːs"
# "dɑːkjəˌmɛnt"
# "ək'spoʊz"
# "kən'vɚt"
# "də'kɹiːs"
# "seɪk"
# "ˌʌp'sɛt"
# "moʊbəl"
# "wɪnd"
# "kən'tɹæst"
# "sʌpləˌmɛnt"
# "pɹə'ɡɹɛs"
# "juːsəz"
# "moʊˌbiːl"
# "diːˌviːˌeɪt"
# "ə'soʊˌsiːˌeɪt"
# "mɑːdɚ'eɪt"
# "waɪnd"
# "ɹə'kɔːɹd"
# "ɹɛd"
# "soʊ"
# "pɚmət"
# "kəm'baɪn"
# "ɹɛˌfjuːs"
# "ə'bjuːz"
# "dɛzɚt"
# "tɹænsˌplænt"
# "kɑːnˌtɹæst"
# "bæs"
# "ə'pɹoʊˌpɹiːət"
# "ædvəˌkeɪt"
# "pɹɑːˌʤɛkt"
# "boʊ"
# "tɹænsˌpɔːɹt"
# "ɹɛzəˌmeɪ"
# "ɹiːd"
# "ɹiːdəŋ"
# "ən'væləd"
# "lɚnd"
# "səb'ʤɛkt"
# "laɪv"
# "ɡɹæˌʤuːət"
# "kən'tɛnt"
# "kloʊs"
# "æksəz"
# "pɚfəkt"
# "pɹɑːˌɡɹɛs"
# "ˌɪ'nɪˌʃiːˌeɪt"
# "ɹiːˌfʌnd"
# "ʤɑːb"
# "pɹə'tɛst"
# "ɪnstɹəmənt"
# "ˌɹɪ'fʌnd"
# "dɛləˌɡeɪt"
# "None"
# "waʊnd"
# "blɛst"
# "maʊθ"
# "ə'fɪˌliːət"
# "tɛɹ"
# "ɹɛkɚd"
# "ə'soʊˌsiːət"
# "lɪv"
# "eɪʤəd"
# "kɑːnˌtɛst"
# "kɑːnˌtɛnt"
# "ˌmɪs'juːz"
# "juːs"
# "ə'tɹɪˌbjuːt"

# %%
swbd_pronunciations = final_wordids_df.pronunciation.tolist()
swbd_pronunciations
# Out:
# ["ə'bjuːs",
#  "ə'bjuːz",
#  "ə'bjuːsəz",
#  "ə'bjuːzə",
#  "'ædvəkət",
#  "'ædvəˌkeɪt",
#  "'æˌfɛkt",
#  "ə'fɛkt",
#  "ə'fɪˌliːət",
#  "ə0'fɪˌliːˌeɪt",
#  "'eɪʤəd",
#  "'eɪʤd",
#  "'æɡɹəɡət",
#  "'æɡɹəˌɡeɪt",
#  "'ɑːltɚnət",
#  "'ɑːltɚˌneɪt",
#  "ə'næləˌsiːz",
#  "'ænəˌlaɪzəz",
#  "'ænəmət",
#  "'ænəˌmeɪt",
#  "ə'pɹɑːksəmət",
#  "ə'pɹɑːsəˌmeɪt",
#  "ɑːɹ'tɪkjələt",
#  "ˌɑːɹ'tɪkjəˌleɪt",
#  "ə'soʊˌsiːət",
#  "ə'soʊˌsiːˌeɪt",
#  "'ætɹəˌbjuːt",
#  "ə'tɹɪˌbjuːt",
#  "'ækˌsiːz",
#  "'æksəz",
#  "'beɪs",
#  "'bæs",
#  "'blɛsəd",
#  "'blɛst",
#  "'boʊ",
#  "'baʊ",
#  "ˌbʌ'feɪ",
#  "'bʌfət",
#  "'sɛltək",
#  "'kɛltək",
#  "'kloʊs",
#  "'kloʊz",
#  "'kɑːmˌbaɪn",
#  "kəm'baɪn",
#  "'kɑːmˌpaʊnd",
#  "kəm'paʊnd",
#  "'kɑːmˌpɹɛs",
#  "kəm'pɹɛs",
#  "'kɑːnˌdʌkt",
#  "kən'dʌkt",
#  "'kɑːnˌfaɪnz",
#  "kən'faɪnz",
#  "'kɑːnfləkt",
#  "kən'flɪkt",
#  "'kɑːnʤəɡət",
#  "'kɑːnʤəˌɡeɪt",
#  "'kɑːnˌskɹɪpt",
#  "kən'skɹɪpt",
#  "'kɑːnˌstɹʌkt",
#  "kən'stɹʌkt",
#  "'kɑːnsəmət",
#  "'kɑːnsəˌmeɪt",
#  "kən'tɛnt",
#  "'kɑːnˌtɛnt",
#  "'kɑːnˌtɛst",
#  "kən'tɛst",
#  "'kɑːnvɚs",
#  "kən'vɚs",
#  "'kɑːnvɚt",
#  "kən'vɚt",
#  "'kɑːnvəkt",
#  "kən'vɪkt",
#  "ˌkoʊ'ɔːɹdənət",
#  "ˌkoʊ'ɔːɹdəˌneɪt",
#  "'kɔːɹələt",
#  "'kɔːɹəˌleɪt",
#  "'diːˌkɹiːs",
#  "də'kɹiːs",
#  "'diːˌfɛkt",
#  "də'fɛkt",
#  "də'ʤɛnɚət",
#  "də'ʤɛnɚˌeɪt",
#  "'dɛləɡət",
#  "'dɛləˌɡeɪt",
#  "də'lɪbɚət",
#  "də'lɪbɚˌeɪt",
#  "ˌdaɪəɡ'noʊˌsiːz",
#  "ˌdaɪəɡ'noʊsəz",
#  "də'fjuːs",
#  "də'fjuːz",
#  "'dɪsˌkɑːɹd",
#  "dəs'kɑːɹd",
#  "'dɪsˌʧɑːɹʤ",
#  "dəs'ʧɑːɹʤ",
#  "'dɪsˌkaʊnt",
#  "dəs'kaʊnt",
#  "'dɑːˌkjuːmənt",
#  "'dɑːkjəˌmɛnt",
#  "'dʌv",
#  "'doʊv",
#  "'duːpləkət",
#  "'duːpləkˌeɪt",
#  "'ɛsˌkɔːɹt",
#  "əs'kɔːɹt",
#  "'ɛstəmət",
#  "'ɛstəˌmeɪt",
#  "ək'skjuːs",
#  "ək'skjuːz",
#  "'ɛkˌsplɔɪt",
#  "ək'splɔɪt",
#  "'ɛkˌspɔːɹt",
#  "ək'spɔːɹt",
#  "ˌɛkˌspoʊ'zeɪ",
#  "ək'spoʊz",
#  "'ɛkˌstɹækt",
#  "ək'stɹækt",
#  "'fɹæɡmənt",
#  "ˌfɹæɡ'mɛnt",
#  "'fɹiːkwənt",
#  "ˌfɹiː'kwɛnt",
#  "'ɡɹæˌʤuːət",
#  "'ɡɹæˌʤuːˌeɪt",
#  "'ɪmˌpækt",
#  "əm'pækt",
#  "'ɪmˌplænt",
#  "əm'plænt",
#  "'ɪmpləmənt",
#  "'ɪmpləˌmɛnt",
#  "'ɪmˌpɔːɹt",
#  "əm'pɔːɹt",
#  "'ɪnˌklaɪn",
#  "ən'klaɪn",
#  "'ɪnˌkɹiːs",
#  "ən'kɹiːs",
#  "'ɪnkɹəmənt",
#  "'ɪnkɹəˌmɛnt",
#  "ə'nɪˌʃiːət",
#  "ˌɪ'nɪˌʃiːˌeɪt",
#  "'ɪnsɚt",
#  "ən'sɚt",
#  "'ɪnˌsʌlt",
#  "ˌɪn'sʌlt",
#  "'ɪnˌtɹiːɡ",
#  "ən'tɹiːɡ",
#  "ən'væləd",
#  "'ɪnvələd",
#  "'ɪnvɚt",
#  "ən'vɚt",
#  "'ɪnˌvaɪt",
#  "ən'vaɪt",
#  "'aɪsələt",
#  "'aɪsəˌleɪt",
#  "'læmənət",
#  "'læməˌneɪt",
#  "'lɛd",
#  "'liːd",
#  "'lɚnəd",
#  "'lɚnd",
#  "'laɪv",
#  "'lɪv",
#  "'laɪvz",
#  "'lɪvz",
#  "ˌmaɪ'nuːt",
#  "'mɪnət",
#  "ˌmɪs'juːs",
#  "ˌmɪs'juːz",
#  "'moʊbəl",
#  "ˌmoʊ'biːl",
#  "'nɛˌsliː",
#  "'nɛsəl",
#  "'ɔːɹnəmənt",
#  "ˌɔɹːnə'mɛnt",
#  "'oʊvɚˌθɹoʊ",
#  "ˌoʊvɚ'θɹoʊ",
#  "'peɪˌstiː",
#  "'pæsˌtiː",
#  "'pɚfəkt",
#  "pɚ'fɛkt",
#  "'pɚˌfjuːm",
#  "pɚ'fjuːm",
#  "'pɚmət",
#  "pɚ'mɪt",
#  "'pɚvɚt",
#  "pɚ'vɚt",
#  "'poʊləʃ",
#  "'pɑːləʃ",
#  "'pɑːsʧələt",
#  "'pɑːsʧəˌleɪt",
#  "pɹə'sɪpətət",
#  "pɹə'sɪpəˌteɪt",
#  "'pɹɛzənt",
#  "ˌpɹiː'zɛnt",
#  "'pɹoʊˌduːs",
#  "pɹə'duːs",
#  "'pɹɑːˌɡɹɛs",
#  "pɹə'ɡɹɛs",
#  "'pɹoʊˌtɛst",
#  "pɹə'tɛst",
#  "'ɹiːdəŋ",
#  "'ɹɛdəŋ",
#  "'ɹɛd",
#  "'ɹiːd",
#  "'ɹɛbəl",
#  "ɹə'bɛl",
#  "'ɹɛkɚd",
#  "ɹə'kɔːɹd",
#  "'ɹiːˌkaʊnt",
#  "ˌɹiː'kaʊnt",
#  "'ɹiːˌfʌnd",
#  "ˌɹɪ'fʌnd",
#  "'ɹɛˌfjuːs",
#  "ɹə'fjuːz",
#  "'ɹiːˌʤɛkt",
#  "ɹə'ʤɛkt",
#  "'ɹiːɹəˌliːs",
#  "ˌɹiːɹə'liːs",
#  "'ɹɛzəˌmeɪ",
#  "ɹə'zuːm",
#  "'ɹiːˌtɑːɹd",
#  "ɹə'tɑːɹd",
#  "ˌɹoʊ'deɪˌoʊ",
#  "'ɹoʊˌdiːˌoʊ",
#  "'sɑːˌkeɪ",
#  "'seɪk",
#  "'sɛpɚət",
#  "'sɛpɚˌeɪt",
#  "'saʊ",
#  "'soʊ",
#  "sə'bɔːɹdənət",
#  "sə'bɔːɹdəˌneɪt",
#  "'sʌpləmənt",
#  "'sʌpləˌmɛnt",
#  "'sʌsˌpɛkt",
#  "səs'pɛkt",
#  "'sɪndəkət",
#  "'sɪndəˌkeɪt",
#  "'tiːɹ",
#  "'tɛɹ",
#  "'tɹænsˌfɔːɹm",
#  "ˌtɹæns'fɔːɹm",
#  "'tɹænsˌplænt",
#  "ˌtɹæns'plænt",
#  "'tɹænsˌpɔːɹt",
#  "ˌtɹæns'pɔːɹt",
#  "'ʌpˌsɛt",
#  "ˌʌp'sɛt",
#  "'juːsəz",
#  "'juːzəz",
#  "'juːs",
#  "'juːz",
#  "'wɪnd",
#  "'waɪnd",
#  "'wɪndz",
#  "'waɪndz",
#  "'wuːnd",
#  "'waʊnd"]

# %%
prons_check = [pron[1:] if pron.startswith("'") else pron for pron in swbd_pronunciations] 
prons_check
# Out:
# ["ə'bjuːs",
#  "ə'bjuːz",
#  "ə'bjuːsəz",
#  "ə'bjuːzə",
#  'ædvəkət',
#  'ædvəˌkeɪt',
#  'æˌfɛkt',
#  "ə'fɛkt",
#  "ə'fɪˌliːət",
#  "ə0'fɪˌliːˌeɪt",
#  'eɪʤəd',
#  'eɪʤd',
#  'æɡɹəɡət',
#  'æɡɹəˌɡeɪt',
#  'ɑːltɚnət',
#  'ɑːltɚˌneɪt',
#  "ə'næləˌsiːz",
#  'ænəˌlaɪzəz',
#  'ænəmət',
#  'ænəˌmeɪt',
#  "ə'pɹɑːksəmət",
#  "ə'pɹɑːsəˌmeɪt",
#  "ɑːɹ'tɪkjələt",
#  "ˌɑːɹ'tɪkjəˌleɪt",
#  "ə'soʊˌsiːət",
#  "ə'soʊˌsiːˌeɪt",
#  'ætɹəˌbjuːt',
#  "ə'tɹɪˌbjuːt",
#  'ækˌsiːz',
#  'æksəz',
#  'beɪs',
#  'bæs',
#  'blɛsəd',
#  'blɛst',
#  'boʊ',
#  'baʊ',
#  "ˌbʌ'feɪ",
#  'bʌfət',
#  'sɛltək',
#  'kɛltək',
#  'kloʊs',
#  'kloʊz',
#  'kɑːmˌbaɪn',
#  "kəm'baɪn",
#  'kɑːmˌpaʊnd',
#  "kəm'paʊnd",
#  'kɑːmˌpɹɛs',
#  "kəm'pɹɛs",
#  'kɑːnˌdʌkt',
#  "kən'dʌkt",
#  'kɑːnˌfaɪnz',
#  "kən'faɪnz",
#  'kɑːnfləkt',
#  "kən'flɪkt",
#  'kɑːnʤəɡət',
#  'kɑːnʤəˌɡeɪt',
#  'kɑːnˌskɹɪpt',
#  "kən'skɹɪpt",
#  'kɑːnˌstɹʌkt',
#  "kən'stɹʌkt",
#  'kɑːnsəmət',
#  'kɑːnsəˌmeɪt',
#  "kən'tɛnt",
#  'kɑːnˌtɛnt',
#  'kɑːnˌtɛst',
#  "kən'tɛst",
#  'kɑːnvɚs',
#  "kən'vɚs",
#  'kɑːnvɚt',
#  "kən'vɚt",
#  'kɑːnvəkt',
#  "kən'vɪkt",
#  "ˌkoʊ'ɔːɹdənət",
#  "ˌkoʊ'ɔːɹdəˌneɪt",
#  'kɔːɹələt',
#  'kɔːɹəˌleɪt',
#  'diːˌkɹiːs',
#  "də'kɹiːs",
#  'diːˌfɛkt',
#  "də'fɛkt",
#  "də'ʤɛnɚət",
#  "də'ʤɛnɚˌeɪt",
#  'dɛləɡət',
#  'dɛləˌɡeɪt',
#  "də'lɪbɚət",
#  "də'lɪbɚˌeɪt",
#  "ˌdaɪəɡ'noʊˌsiːz",
#  "ˌdaɪəɡ'noʊsəz",
#  "də'fjuːs",
#  "də'fjuːz",
#  'dɪsˌkɑːɹd',
#  "dəs'kɑːɹd",
#  'dɪsˌʧɑːɹʤ',
#  "dəs'ʧɑːɹʤ",
#  'dɪsˌkaʊnt',
#  "dəs'kaʊnt",
#  'dɑːˌkjuːmənt',
#  'dɑːkjəˌmɛnt',
#  'dʌv',
#  'doʊv',
#  'duːpləkət',
#  'duːpləkˌeɪt',
#  'ɛsˌkɔːɹt',
#  "əs'kɔːɹt",
#  'ɛstəmət',
#  'ɛstəˌmeɪt',
#  "ək'skjuːs",
#  "ək'skjuːz",
#  'ɛkˌsplɔɪt',
#  "ək'splɔɪt",
#  'ɛkˌspɔːɹt',
#  "ək'spɔːɹt",
#  "ˌɛkˌspoʊ'zeɪ",
#  "ək'spoʊz",
#  'ɛkˌstɹækt',
#  "ək'stɹækt",
#  'fɹæɡmənt',
#  "ˌfɹæɡ'mɛnt",
#  'fɹiːkwənt',
#  "ˌfɹiː'kwɛnt",
#  'ɡɹæˌʤuːət',
#  'ɡɹæˌʤuːˌeɪt',
#  'ɪmˌpækt',
#  "əm'pækt",
#  'ɪmˌplænt',
#  "əm'plænt",
#  'ɪmpləmənt',
#  'ɪmpləˌmɛnt',
#  'ɪmˌpɔːɹt',
#  "əm'pɔːɹt",
#  'ɪnˌklaɪn',
#  "ən'klaɪn",
#  'ɪnˌkɹiːs',
#  "ən'kɹiːs",
#  'ɪnkɹəmənt',
#  'ɪnkɹəˌmɛnt',
#  "ə'nɪˌʃiːət",
#  "ˌɪ'nɪˌʃiːˌeɪt",
#  'ɪnsɚt',
#  "ən'sɚt",
#  'ɪnˌsʌlt',
#  "ˌɪn'sʌlt",
#  'ɪnˌtɹiːɡ',
#  "ən'tɹiːɡ",
#  "ən'væləd",
#  'ɪnvələd',
#  'ɪnvɚt',
#  "ən'vɚt",
#  'ɪnˌvaɪt',
#  "ən'vaɪt",
#  'aɪsələt',
#  'aɪsəˌleɪt',
#  'læmənət',
#  'læməˌneɪt',
#  'lɛd',
#  'liːd',
#  'lɚnəd',
#  'lɚnd',
#  'laɪv',
#  'lɪv',
#  'laɪvz',
#  'lɪvz',
#  "ˌmaɪ'nuːt",
#  'mɪnət',
#  "ˌmɪs'juːs",
#  "ˌmɪs'juːz",
#  'moʊbəl',
#  "ˌmoʊ'biːl",
#  'nɛˌsliː',
#  'nɛsəl',
#  'ɔːɹnəmənt',
#  "ˌɔɹːnə'mɛnt",
#  'oʊvɚˌθɹoʊ',
#  "ˌoʊvɚ'θɹoʊ",
#  'peɪˌstiː',
#  'pæsˌtiː',
#  'pɚfəkt',
#  "pɚ'fɛkt",
#  'pɚˌfjuːm',
#  "pɚ'fjuːm",
#  'pɚmət',
#  "pɚ'mɪt",
#  'pɚvɚt',
#  "pɚ'vɚt",
#  'poʊləʃ',
#  'pɑːləʃ',
#  'pɑːsʧələt',
#  'pɑːsʧəˌleɪt',
#  "pɹə'sɪpətət",
#  "pɹə'sɪpəˌteɪt",
#  'pɹɛzənt',
#  "ˌpɹiː'zɛnt",
#  'pɹoʊˌduːs',
#  "pɹə'duːs",
#  'pɹɑːˌɡɹɛs',
#  "pɹə'ɡɹɛs",
#  'pɹoʊˌtɛst',
#  "pɹə'tɛst",
#  'ɹiːdəŋ',
#  'ɹɛdəŋ',
#  'ɹɛd',
#  'ɹiːd',
#  'ɹɛbəl',
#  "ɹə'bɛl",
#  'ɹɛkɚd',
#  "ɹə'kɔːɹd",
#  'ɹiːˌkaʊnt',
#  "ˌɹiː'kaʊnt",
#  'ɹiːˌfʌnd',
#  "ˌɹɪ'fʌnd",
#  'ɹɛˌfjuːs',
#  "ɹə'fjuːz",
#  'ɹiːˌʤɛkt',
#  "ɹə'ʤɛkt",
#  'ɹiːɹəˌliːs',
#  "ˌɹiːɹə'liːs",
#  'ɹɛzəˌmeɪ',
#  "ɹə'zuːm",
#  'ɹiːˌtɑːɹd',
#  "ɹə'tɑːɹd",
#  "ˌɹoʊ'deɪˌoʊ",
#  'ɹoʊˌdiːˌoʊ',
#  'sɑːˌkeɪ',
#  'seɪk',
#  'sɛpɚət',
#  'sɛpɚˌeɪt',
#  'saʊ',
#  'soʊ',
#  "sə'bɔːɹdənət",
#  "sə'bɔːɹdəˌneɪt",
#  'sʌpləmənt',
#  'sʌpləˌmɛnt',
#  'sʌsˌpɛkt',
#  "səs'pɛkt",
#  'sɪndəkət',
#  'sɪndəˌkeɪt',
#  'tiːɹ',
#  'tɛɹ',
#  'tɹænsˌfɔːɹm',
#  "ˌtɹæns'fɔːɹm",
#  'tɹænsˌplænt',
#  "ˌtɹæns'plænt",
#  'tɹænsˌpɔːɹt',
#  "ˌtɹæns'pɔːɹt",
#  'ʌpˌsɛt',
#  "ˌʌp'sɛt",
#  'juːsəz',
#  'juːzəz',
#  'juːs',
#  'juːz',
#  'wɪnd',
#  'waɪnd',
#  'wɪndz',
#  'waɪndz',
#  'wuːnd',
#  'waʊnd']

# %%
def get_pron(label):
    check_real = zip(prons_check, swbd_pronunciations)
    for c, r in check_real: 
        if label == c:
            return r
            

data_df['pronunciation'] = data_df['new_label'].apply(lambda x: get_pron(x))
data_df
# Out:
#                             file_name homograph WHD_IPA_representations  \
# 0      sw03012_s136_1-s136_4.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
# 1     sw04184_s102_1-s102_19.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
# 2       sw02597_s50_1-s50_25.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
# 3       sw04649_s99_1-s99_50.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
# 4     sw03049_s138_1-s138_15.TextGrid     abuse   ["ə'bjuːs" "ə'bjuːz"]
# ...                               ...       ...                     ...
# 2930  sw03108_s132_1-s132_27.TextGrid     wound       ['wuːnd' 'waʊnd']
# 2931   sw02365_s174_1-s174_7.TextGrid     wound       ['wuːnd' 'waʊnd']
# 2932   sw03073_s215_1-s215_8.TextGrid     wound       ['wuːnd' 'waʊnd']
# 2933   sw03070_s186_1-s186_7.TextGrid     wound       ['wuːnd' 'waʊnd']
# 2934    sw04004_s28_1-s28_20.TextGrid     wound       ['wuːnd' 'waʊnd']
#
#      MFA-Arpabet-2-IPA                 Human-mapped_column_D_to_C_w_notes  \
# 0               ʌˈbjuz                                            ə'bjuːz
# 1               ʌˈbjuz  ! - need to listen, col D seems incorrect, cou...
# 2               ʌˈbjuz                                            ə'bjuːz
# 3               ʌˈbjus                                            ə'bjuːs
# 4               ʌˈbjuz                                            ə'bjuːz
# ...                ...                                                ...
# 2930             waʊnd                                        exact match
# 2931              wund  waʊnd (? - could listen, not sure what's going...
# 2932             waʊnd                                        exact match
# 2933             waʊnd                                        exact match
# 2934             waʊnd                                        exact match
#
#                                                sentence new_label  \
# 0                                   and they abuse that   ə'bjuːz
# 1     it takes a lot of training and a lot of abuse ...   ə'bjuːs
# 2     and they <unk> they do n't you know they do n'...   ə'bjuːz
# 3     i think the problems are more ones of cost and...   ə'bjuːs
# 4     i think it s time we had a lady abuse the guys...   ə'bjuːz
# ...                                                 ...       ...
# 2930  but course it s one of these with a twist wher...     waʊnd
# 2931                      we wound up selling the house     waʊnd
# 2932                   we <unk> wound up sending in one     waʊnd
# 2933                       and so it kind of wound down     waʊnd
# 2934  but neither of them wound up going over which ...     waʊnd
#
#      pronunciaton pronunciation
# 0         ə'bjuːz       ə'bjuːz
# 1         ə'bjuːs       ə'bjuːs
# 2         ə'bjuːz       ə'bjuːz
# 3         ə'bjuːs       ə'bjuːs
# 4         ə'bjuːz       ə'bjuːz
# ...           ...           ...
# 2930       'waʊnd        'waʊnd
# 2931       'waʊnd        'waʊnd
# 2932       'waʊnd        'waʊnd
# 2933       'waʊnd        'waʊnd
# 2934       'waʊnd        'waʊnd
#
# [2935 rows x 9 columns]

# %%
final = pd.merge(final_wordids_df, data_df, on='pronunciation')

# %%
final.head()
# Out:
#   homograph_x     wordid label pronunciation   homograph_type  \
# 0       abuse  abuse_nou  noun       ə'bjuːs  Morphosyntactic
# 1       abuse  abuse_nou  noun       ə'bjuːs  Morphosyntactic
# 2       abuse  abuse_nou  noun       ə'bjuːs  Morphosyntactic
# 3       abuse  abuse_nou  noun       ə'bjuːs  Morphosyntactic
# 4       abuse  abuse_nou  noun       ə'bjuːs  Morphosyntactic
#
#   fine_homograph_type                        file_name homograph_y  \
# 0                 PoS  sw04184_s102_1-s102_19.TextGrid       abuse
# 1                 PoS    sw04649_s99_1-s99_50.TextGrid       abuse
# 2                 PoS    sw02466_s59_1-s59_21.TextGrid       abuse
# 3                 PoS   sw04792_s100_1-s100_9.TextGrid       abuse
# 4                 PoS    sw04649_s34_1-s34_22.TextGrid       abuse
#
#   WHD_IPA_representations MFA-Arpabet-2-IPA  \
# 0   ["ə'bjuːs" "ə'bjuːz"]            ʌˈbjuz
# 1   ["ə'bjuːs" "ə'bjuːz"]            ʌˈbjus
# 2   ["ə'bjuːs" "ə'bjuːz"]            ʌˈbjuz
# 3   ["ə'bjuːs" "ə'bjuːz"]            ʌˈbjus
# 4   ["ə'bjuːs" "ə'bjuːz"]            ʌˈbjuz
#
#                   Human-mapped_column_D_to_C_w_notes  \
# 0  ! - need to listen, col D seems incorrect, cou...
# 1                                            ə'bjuːs
# 2  ! - need to listen, col D seems incorrect, cou...
# 3                                            ə'bjuːs
# 4  ! - need to listen, col D seems incorrect, cou...
#
#                                             sentence new_label pronunciaton
# 0  it takes a lot of training and a lot of abuse ...   ə'bjuːs      ə'bjuːs
# 1  i think the problems are more ones of cost and...   ə'bjuːs      ə'bjuːs
# 2  right now some of the things i m working with ...   ə'bjuːs      ə'bjuːs
# 3      that sounds like a little abuse of our system   ə'bjuːs      ə'bjuːs
# 4  well the thing i really worry about is uh the ...   ə'bjuːs      ə'bjuːs

# %%
final.pronunciation.nunique()
# Out:
# 105

# %%
final.wordid.nunique()
# Out:
# 105

# %%
pd.set_option('display.max_rows', None)

# %%
final.groupby('homograph_x')['wordid'].value_counts()
# Out:
# homograph_x  wordid
# abuse        abuse_nou                8
#              abuse_vrb                5
# advocate     advocate_nou             4
#              advocate_vrb             2
# affect       affect                   6
# affiliate    affiliate_nou            1
# aged         aged_adj                 3
# alternate    alternate_adj-nou        5
# associate    associate_adj-nou        1
#              associate_vrb            1
# attribute    attribute_vrb            1
# axes         axes_nou-vrb             1
# bass         bass_corp                9
# blessed      blessed_vrb              2
# bow          bow_nou-knot             2
#              bow_nou-ship             2
# close        close_adj-nou          100
#              close_vrb                7
# combine      combine_vrb              4
# compress     compress                 1
# conflict     conflict_nou             8
# construct    construct_vrb            1
# content      content_nou              4
#              content_adj-nou-vrb      3
# contest      contest_nou              3
# convert      convert_vrb             10
# convict      convict_vrb             10
# decrease     decrease_vrb             4
#              decrease_nou             1
# defect       defect_vrb               1
# delegate     delegate_vrb             1
# deliberate   deliberate_adj           5
# discount     discount_nou             4
# document     document_vrb             2
# dove         dove_vrb                 1
# duplicate    duplicate_adj-nou        1
# estimate     estimate_nou             1
# excuse       excuse_vrb              19
#              excuse_nou              15
# expose       expose_vrb               1
# frequent     frequent_adj             4
# graduate     graduate_adj-nou        20
# impact       impact_nou              18
# incline      incline_nou              1
# increase     increase_vrb             7
#              increase_nou             4
# initiate     initiate_vrb             2
# invalid      invalid_adj              1
# invite       invite_vrb               3
#              invite_nou               1
# isolate      isolate                  3
# lead         lead_nou-vrb             8
#              lead_nou                 1
# learned      learned_vrb             42
# live         live_vrb               337
#              live_adj                 8
# lives        lives_vrb               51
#              lives_nou               34
# minute       minute                  46
# misuse       misuse_vrb               1
# mobile       mobile                   5
# perfect      perfect_adj             20
# permit       permit_nou               3
#              permit_vrb               3
# present      present_adj-nou         18
#              present_vrb              4
# produce      produce_vrb              7
#              produce_nou              1
# progress     progress_nou             6
#              progress_vrb             1
# protest      protest_vrb              2
#              protest_nou              1
# read         read_present           229
#              read_past              134
# reading      reading_en             101
# rebel        rebel_vrb                2
#              rebel_nou                1
# record       record_nou              29
#              record_vrb               4
# refund       refund_nou               2
#              refund_vrb               1
# refuse       refuse_vrb               5
#              refuse_nou               2
# reject       reject_vrb               2
# resume       resume_nou               4
# sake         sake                     4
# separate     separate_adj            16
#              separate_vrb            15
# sow          sow                      1
# supplement   supplement_vrb           3
# suspect      suspect_vrb             16
#              suspect_adj-nou          3
# tear         tear_vrb                 4
# transplant   transplant_vrb           2
#              transplant_nou           1
# transport    transport_nou            1
# upset        upset_vrb               32
# use          use_vrb                358
#              use_nou                 28
# uses         uses_vrb                13
#              uses_nou                 1
# wind         wind_nou                24
#              wind_vrb                21
# winds        winds_vrb                4
# wound        wound_vrb               13
# Name: wordid, dtype: int64

# %%
low_acc_df = pd.read_csv(LOW_ACC_PATH, sep='\t')

# %%
final_wordids = final.wordid.unique().tolist()
low_acc_wordids = low_acc_df.wordid.unique().tolist()

# %%
len(final_wordids)
# Out:
# 105

# %%
len(low_acc_wordids)
# Out:
# 77

# %%
intersect_low_final = [value for value in final_wordids if value in low_acc_wordids]

# %%
len(intersect_low_final)
# Out:
# 33

# %%
len(intersect_low_final)/len(low_acc_wordids)
# Out:
# 0.42857142857142855

# %%
low_acc_df
# Out:
#     Unnamed: 0  Unnamed: 0.1    homograph               wordid  wordid_count  \
# 0            3             1       abuses           abuses_vrb            16
# 1            8             0    affiliate        affiliate_vrb             3
# 2           11             1         aged             aged_adj             4
# 3           14             0    alternate    alternate_adj-nou            87
# 4           15             1    alternate        alternate_vrb             5
# 5           18             0      animate          animate_vrb            50
# 6           29             1         axes         axes_nou-vrb            43
# 7           31             1         bass            bass_corp            13
# 8           34             0          bow         bow_nou-knot            43
# 9           35             1          bow         bow_nou-ship            47
# 10          37             1       buffet           buffet_vrb             5
# 11          40             0        close        close_adj-nou            84
# 12          41             1        close            close_vrb             5
# 13          44             0     compound         compound_nou            87
# 14          45             1     compound         compound_vrb             3
# 15          47             1     compress         compress_nou             4
# 16          48             0      conduct          conduct_vrb            49
# 17          52             0     conflict         conflict_nou            86
# 18          53             1     conflict         conflict_vrb             4
# 19          55             1    conjugate        conjugate_vrb             4
# 20          63             1      content  content_adj-nou-vrb             1
# 21          85             1   deliberate       deliberate_vrb             3
# 22          93             1    discharge        discharge_vrb            10
# 23          95             1     discount         discount_vrb             3
# 24         100             0    duplicate    duplicate_adj-nou            67
# 25         111             1       export           export_vrb            14
# 26         117             1     fragment         fragment_vrb             3
# 27         118             0     frequent         frequent_adj            86
# 28         121             1     graduate         graduate_vrb             3
# 29         123             1       impact           impact_vrb             2
# 30         131             1      incline          incline_vrb             3
# 31         135             1    increment        increment_nou            78
# 32         136             0     initiate         initiate_vrb            83
# 33         138             0       insert           insert_vrb            43
# 34         139             1       insert           insert_nou            47
# 35         143             1     intrigue     intrigue_nou-vrb             4
# 36         148             0       invite           invite_vrb            71
# 37         152             0     laminate         laminate_nou            87
# 38         153             1     laminate         laminate_vrb             3
# 39         154             0         lead         lead_nou-vrb            83
# 40         156             0      learned          learned_adj             7
# 41         160             0        lives            lives_vrb            57
# 42         161             1        lives            lives_nou            34
# 43         165             1       misuse           misuse_vrb             7
# 44         166             0       mobile               mobile            85
# 45         167             1       mobile           mobile_geo             4
# 46         168             0       nestle           nestle_nam            63
# 47         169             1       nestle           nestle_vrb            14
# 48         171             1     ornament         ornament_vrb             4
# 49         172             0    overthrow        overthrow_nou            28
# 50         175             1        pasty            pasty_nou            22
# 51         179             1      perfume          perfume_vrb             2
# 52         185             1       polish               polish             3
# 53         190             0      present      present_adj-nou            83
# 54         191             1      present          present_vrb             7
# 55         192             0      produce          produce_vrb            84
# 56         198             0         read            read_past            52
# 57         199             1         read         read_present            60
# 58         200             0      reading           reading_en            74
# 59         201             1      reading          reading_geo            16
# 60         213             1       reject           reject_nou             5
# 61         216             0       resume           resume_vrb            80
# 62         218             0       retard           retard_vrb            71
# 63         219             1       retard           retard_nou            14
# 64         221             1        rodeo            rodeo_geo             3
# 65         222             0         sake              sake_jp            13
# 66         224             0     separate         separate_adj            85
# 67         225             1     separate         separate_vrb             6
# 68         227             1          sow                  sow            52
# 69         229             1  subordinate      subordinate_vrb             3
# 70         235             1    syndicate        syndicate_vrb             4
# 71         236             0         tear             tear_nou            32
# 72         241             1   transplant       transplant_vrb             5
# 73         242             0    transport        transport_nou            84
# 74         247             1          use              use_vrb            37
# 75         251             1         wind             wind_vrb             6
# 76         255             1        wound            wound_vrb            28
#
#     ttl  percent_ttl  accuracy
# 0    90     0.177778  0.500000
# 1    89     0.033708  0.000000
# 2    91     0.043956  0.000000
# 3    92     0.945652  0.900000
# 4    92     0.054348  0.000000
# 5    86     0.581395  0.833333
# 6    90     0.477778  0.200000
# 7    87     0.149425  0.666667
# 8    90     0.477778  0.500000
# 9    90     0.522222  0.500000
# 10   88     0.056818  0.000000
# 11   89     0.943820  0.900000
# 12   89     0.056180  0.000000
# 13   90     0.966667  0.818182
# 14   90     0.033333  0.000000
# 15   88     0.045455  0.000000
# 16   90     0.544444  0.800000
# 17   90     0.955556  0.900000
# 18   90     0.044444  0.000000
# 19   90     0.044444  0.000000
# 20   90     0.011111  0.000000
# 21   89     0.033708  0.000000
# 22   90     0.111111  0.000000
# 23   90     0.033333  0.000000
# 24   90     0.744444  0.875000
# 25   89     0.157303  0.500000
# 26   89     0.033708  0.000000
# 27   90     0.955556  0.900000
# 28   90     0.033333  0.000000
# 29   90     0.022222  0.000000
# 30   89     0.033708  0.000000
# 31   89     0.876404  0.875000
# 32   90     0.922222  0.888889
# 33   90     0.477778  0.800000
# 34   90     0.522222  0.800000
# 35   90     0.044444  0.000000
# 36   90     0.788889  0.875000
# 37   90     0.966667  0.900000
# 38   90     0.033333  0.000000
# 39  104     0.798077  0.888889
# 40   90     0.077778  0.000000
# 41   91     0.626374  0.833333
# 42   91     0.373626  0.500000
# 43   88     0.079545  0.000000
# 44   89     0.955056  0.900000
# 45   89     0.044944  0.000000
# 46   77     0.818182  0.857143
# 47   77     0.181818  0.000000
# 48   90     0.044444  0.000000
# 49   90     0.311111  0.750000
# 50   85     0.258824  0.000000
# 51   90     0.022222  0.000000
# 52   90     0.033333  0.000000
# 53   90     0.922222  0.888889
# 54   90     0.077778  0.000000
# 55   90     0.933333  0.888889
# 56  112     0.464286  0.833333
# 57  112     0.535714  0.833333
# 58   90     0.822222  0.777778
# 59   90     0.177778  0.000000
# 60   86     0.058140  0.000000
# 61   88     0.909091  0.888889
# 62   85     0.835294  0.875000
# 63   85     0.164706  0.500000
# 64   86     0.034884  0.000000
# 65   89     0.146067  0.500000
# 66   91     0.934066  0.900000
# 67   91     0.065934  0.000000
# 68   86     0.604651  0.833333
# 69   90     0.033333  0.000000
# 70   90     0.044444  0.000000
# 71   89     0.359551  0.750000
# 72   90     0.055556  0.000000
# 73   89     0.943820  0.900000
# 74   91     0.406593  0.750000
# 75   90     0.066667  0.000000
# 76   89     0.314607  0.750000

# %%
low_acc_df.percent_ttl.describe()
# Out:
# count    77.000000
# mean      0.370036
# std       0.357885
# min       0.011111
# 25%       0.044444
# 50%       0.177778
# 75%       0.744444
# max       0.966667
# Name: percent_ttl, dtype: float64

# %%
len(low_acc_df[low_acc_df.percent_ttl <= .4])/77
# Out:
# 0.5844155844155844

# %%
low_acc_finals = final[final.wordid.isin(low_acc_wordids)]
low_acc_finals.groupby('homograph_x')['wordid'].value_counts()
# Out:
# homograph_x  wordid
# aged         aged_adj                 3
# alternate    alternate_adj-nou        5
# axes         axes_nou-vrb             1
# bass         bass_corp                9
# bow          bow_nou-knot             2
#              bow_nou-ship             2
# close        close_adj-nou          100
#              close_vrb                7
# conflict     conflict_nou             8
# content      content_adj-nou-vrb      3
# duplicate    duplicate_adj-nou        1
# frequent     frequent_adj             4
# initiate     initiate_vrb             2
# invite       invite_vrb               3
# lead         lead_nou-vrb             8
# lives        lives_vrb               51
#              lives_nou               34
# misuse       misuse_vrb               1
# mobile       mobile                   5
# present      present_adj-nou         18
#              present_vrb              4
# produce      produce_vrb              7
# read         read_present           229
#              read_past              134
# reading      reading_en             101
# separate     separate_adj            16
#              separate_vrb            15
# sow          sow                      1
# transplant   transplant_vrb           2
# transport    transport_nou            1
# use          use_vrb                358
# wind         wind_vrb                21
# wound        wound_vrb               13
# Name: wordid, dtype: int64

# %%
swbd_counts_low_acc = low_acc_finals['wordid'].value_counts()
swbd_wordid_cts = swbd_counts_low_acc.reset_index().rename(columns={'index' : 'wordid', 'wordid' : 'swbd_wordid_cts'})

# %%
swbd_whd_df = pd.merge(swbd_wordid_cts, low_acc_df, on='wordid')

# %%
swbd_whd_df = swbd_whd_df[['wordid', 'swbd_wordid_cts', 'homograph', 'wordid_count', 'ttl', 'percent_ttl', 'accuracy']]
swbd_whd_df
# Out:
#                  wordid  swbd_wordid_cts   homograph  wordid_count  ttl  \
# 0               use_vrb              358         use            37   91
# 1          read_present              229        read            60  112
# 2             read_past              134        read            52  112
# 3            reading_en              101     reading            74   90
# 4         close_adj-nou              100       close            84   89
# 5             lives_vrb               51       lives            57   91
# 6             lives_nou               34       lives            34   91
# 7              wind_vrb               21        wind             6   90
# 8       present_adj-nou               18     present            83   90
# 9          separate_adj               16    separate            85   91
# 10         separate_vrb               15    separate             6   91
# 11            wound_vrb               13       wound            28   89
# 12            bass_corp                9        bass            13   87
# 13         conflict_nou                8    conflict            86   90
# 14         lead_nou-vrb                8        lead            83  104
# 15            close_vrb                7       close             5   89
# 16          produce_vrb                7     produce            84   90
# 17               mobile                5      mobile            85   89
# 18    alternate_adj-nou                5   alternate            87   92
# 19          present_vrb                4     present             7   90
# 20         frequent_adj                4    frequent            86   90
# 21             aged_adj                3        aged             4   91
# 22  content_adj-nou-vrb                3     content             1   90
# 23           invite_vrb                3      invite            71   90
# 24       transplant_vrb                2  transplant             5   90
# 25         bow_nou-knot                2         bow            43   90
# 26         bow_nou-ship                2         bow            47   90
# 27         initiate_vrb                2    initiate            83   90
# 28           misuse_vrb                1      misuse             7   88
# 29         axes_nou-vrb                1        axes            43   90
# 30    duplicate_adj-nou                1   duplicate            67   90
# 31        transport_nou                1   transport            84   89
# 32                  sow                1         sow            52   86
#
#     percent_ttl  accuracy
# 0      0.406593  0.750000
# 1      0.535714  0.833333
# 2      0.464286  0.833333
# 3      0.822222  0.777778
# 4      0.943820  0.900000
# 5      0.626374  0.833333
# 6      0.373626  0.500000
# 7      0.066667  0.000000
# 8      0.922222  0.888889
# 9      0.934066  0.900000
# 10     0.065934  0.000000
# 11     0.314607  0.750000
# 12     0.149425  0.666667
# 13     0.955556  0.900000
# 14     0.798077  0.888889
# 15     0.056180  0.000000
# 16     0.933333  0.888889
# 17     0.955056  0.900000
# 18     0.945652  0.900000
# 19     0.077778  0.000000
# 20     0.955556  0.900000
# 21     0.043956  0.000000
# 22     0.011111  0.000000
# 23     0.788889  0.875000
# 24     0.055556  0.000000
# 25     0.477778  0.500000
# 26     0.522222  0.500000
# 27     0.922222  0.888889
# 28     0.079545  0.000000
# 29     0.477778  0.200000
# 30     0.744444  0.875000
# 31     0.943820  0.900000
# 32     0.604651  0.833333

# %%
swbd_whd_df['ttl_cap'] = 120

# %%
swbd_whd_df['allowed_new_samples'] = swbd_whd_df.ttl_cap - swbd_whd_df.ttl

# %%
swbd_whd_df
# Out:
#                  wordid  swbd_wordid_cts   homograph  wordid_count  ttl  \
# 0               use_vrb              358         use            37   91
# 1          read_present              229        read            60  112
# 2             read_past              134        read            52  112
# 3            reading_en              101     reading            74   90
# 4         close_adj-nou              100       close            84   89
# 5             lives_vrb               51       lives            57   91
# 6             lives_nou               34       lives            34   91
# 7              wind_vrb               21        wind             6   90
# 8       present_adj-nou               18     present            83   90
# 9          separate_adj               16    separate            85   91
# 10         separate_vrb               15    separate             6   91
# 11            wound_vrb               13       wound            28   89
# 12            bass_corp                9        bass            13   87
# 13         conflict_nou                8    conflict            86   90
# 14         lead_nou-vrb                8        lead            83  104
# 15            close_vrb                7       close             5   89
# 16          produce_vrb                7     produce            84   90
# 17               mobile                5      mobile            85   89
# 18    alternate_adj-nou                5   alternate            87   92
# 19          present_vrb                4     present             7   90
# 20         frequent_adj                4    frequent            86   90
# 21             aged_adj                3        aged             4   91
# 22  content_adj-nou-vrb                3     content             1   90
# 23           invite_vrb                3      invite            71   90
# 24       transplant_vrb                2  transplant             5   90
# 25         bow_nou-knot                2         bow            43   90
# 26         bow_nou-ship                2         bow            47   90
# 27         initiate_vrb                2    initiate            83   90
# 28           misuse_vrb                1      misuse             7   88
# 29         axes_nou-vrb                1        axes            43   90
# 30    duplicate_adj-nou                1   duplicate            67   90
# 31        transport_nou                1   transport            84   89
# 32                  sow                1         sow            52   86
#
#     percent_ttl  accuracy  ttl_cap  allowed_new_samples
# 0      0.406593  0.750000      120                   29
# 1      0.535714  0.833333      120                    8
# 2      0.464286  0.833333      120                    8
# 3      0.822222  0.777778      120                   30
# 4      0.943820  0.900000      120                   31
# 5      0.626374  0.833333      120                   29
# 6      0.373626  0.500000      120                   29
# 7      0.066667  0.000000      120                   30
# 8      0.922222  0.888889      120                   30
# 9      0.934066  0.900000      120                   29
# 10     0.065934  0.000000      120                   29
# 11     0.314607  0.750000      120                   31
# 12     0.149425  0.666667      120                   33
# 13     0.955556  0.900000      120                   30
# 14     0.798077  0.888889      120                   16
# 15     0.056180  0.000000      120                   31
# 16     0.933333  0.888889      120                   30
# 17     0.955056  0.900000      120                   31
# 18     0.945652  0.900000      120                   28
# 19     0.077778  0.000000      120                   30
# 20     0.955556  0.900000      120                   30
# 21     0.043956  0.000000      120                   29
# 22     0.011111  0.000000      120                   30
# 23     0.788889  0.875000      120                   30
# 24     0.055556  0.000000      120                   30
# 25     0.477778  0.500000      120                   30
# 26     0.522222  0.500000      120                   30
# 27     0.922222  0.888889      120                   30
# 28     0.079545  0.000000      120                   32
# 29     0.477778  0.200000      120                   30
# 30     0.744444  0.875000      120                   30
# 31     0.943820  0.900000      120                   31
# 32     0.604651  0.833333      120                   34

# %%
#swbd_whd_df['new_ttl'] =  swbd_whd_df.swbd_wordid_cts + swbd_whd_df.ttl

# %%
def get_sample_size(row): 
    if row.swbd_wordid_cts >= row.allowed_new_samples:
        print("here: {}".format(row.wordid))
        return row.allowed_new_samples + row.wordid_count
    else: 
        return row.swbd_wordid_cts + row.wordid_count

# %%
swbd_whd_df['new_wordid_ttl'] =  swbd_whd_df.apply(lambda row: get_sample_size(row), axis=1)
# Out:
# here: use_vrb
# here: read_present
# here: read_past
# here: reading_en
# here: close_adj-nou
# here: lives_vrb
# here: lives_nou

# %%
swbd_whd_df
# Out:
#                  wordid  swbd_wordid_cts   homograph  wordid_count  ttl  \
# 0               use_vrb              358         use            37   91
# 1          read_present              229        read            60  112
# 2             read_past              134        read            52  112
# 3            reading_en              101     reading            74   90
# 4         close_adj-nou              100       close            84   89
# 5             lives_vrb               51       lives            57   91
# 6             lives_nou               34       lives            34   91
# 7              wind_vrb               21        wind             6   90
# 8       present_adj-nou               18     present            83   90
# 9          separate_adj               16    separate            85   91
# 10         separate_vrb               15    separate             6   91
# 11            wound_vrb               13       wound            28   89
# 12            bass_corp                9        bass            13   87
# 13         conflict_nou                8    conflict            86   90
# 14         lead_nou-vrb                8        lead            83  104
# 15            close_vrb                7       close             5   89
# 16          produce_vrb                7     produce            84   90
# 17               mobile                5      mobile            85   89
# 18    alternate_adj-nou                5   alternate            87   92
# 19          present_vrb                4     present             7   90
# 20         frequent_adj                4    frequent            86   90
# 21             aged_adj                3        aged             4   91
# 22  content_adj-nou-vrb                3     content             1   90
# 23           invite_vrb                3      invite            71   90
# 24       transplant_vrb                2  transplant             5   90
# 25         bow_nou-knot                2         bow            43   90
# 26         bow_nou-ship                2         bow            47   90
# 27         initiate_vrb                2    initiate            83   90
# 28           misuse_vrb                1      misuse             7   88
# 29         axes_nou-vrb                1        axes            43   90
# 30    duplicate_adj-nou                1   duplicate            67   90
# 31        transport_nou                1   transport            84   89
# 32                  sow                1         sow            52   86
#
#     percent_ttl  accuracy  ttl_cap  allowed_new_samples  new_wordid_ttl
# 0      0.406593  0.750000      120                   29              66
# 1      0.535714  0.833333      120                    8              68
# 2      0.464286  0.833333      120                    8              60
# 3      0.822222  0.777778      120                   30             104
# 4      0.943820  0.900000      120                   31             115
# 5      0.626374  0.833333      120                   29              86
# 6      0.373626  0.500000      120                   29              63
# 7      0.066667  0.000000      120                   30              27
# 8      0.922222  0.888889      120                   30             101
# 9      0.934066  0.900000      120                   29             101
# 10     0.065934  0.000000      120                   29              21
# 11     0.314607  0.750000      120                   31              41
# 12     0.149425  0.666667      120                   33              22
# 13     0.955556  0.900000      120                   30              94
# 14     0.798077  0.888889      120                   16              91
# 15     0.056180  0.000000      120                   31              12
# 16     0.933333  0.888889      120                   30              91
# 17     0.955056  0.900000      120                   31              90
# 18     0.945652  0.900000      120                   28              92
# 19     0.077778  0.000000      120                   30              11
# 20     0.955556  0.900000      120                   30              90
# 21     0.043956  0.000000      120                   29               7
# 22     0.011111  0.000000      120                   30               4
# 23     0.788889  0.875000      120                   30              74
# 24     0.055556  0.000000      120                   30               7
# 25     0.477778  0.500000      120                   30              45
# 26     0.522222  0.500000      120                   30              49
# 27     0.922222  0.888889      120                   30              85
# 28     0.079545  0.000000      120                   32               8
# 29     0.477778  0.200000      120                   30              44
# 30     0.744444  0.875000      120                   30              68
# 31     0.943820  0.900000      120                   31              85
# 32     0.604651  0.833333      120                   34              53

# %%
swbd_whd_df['other_wd_ct'] = swbd_whd_df.ttl - swbd_whd_df.wordid_count

# %%
swbd_whd_df['aug_ttl'] = swbd_whd_df.other_wd_ct + swbd_whd_df.new_wordid_ttl

# %%
swbd_whd_df['percent_aug_ttl'] = swbd_whd_df.new_wordid_ttl / swbd_whd_df.aug_ttl

# %%
swbd_whd_df['abs_percent_ttl_change'] = (swbd_whd_df.percent_aug_ttl - swbd_whd_df.percent_ttl)*100

# %%
swbd_whd_df.abs_percent_ttl_change.describe()
# Out:
# count    33.000000
# mean      3.892790
# std       4.946972
# min       0.062422
# 25%       0.481100
# 50%       1.442308
# 75%       4.444444
# max      17.657658
# Name: abs_percent_ttl_change, dtype: float64

# %%
swbd_whd_df
# Out:
#                  wordid  swbd_wordid_cts   homograph  wordid_count  ttl  \
# 0               use_vrb              358         use            37   91
# 1          read_present              229        read            60  112
# 2             read_past              134        read            52  112
# 3            reading_en              101     reading            74   90
# 4         close_adj-nou              100       close            84   89
# 5             lives_vrb               51       lives            57   91
# 6             lives_nou               34       lives            34   91
# 7              wind_vrb               21        wind             6   90
# 8       present_adj-nou               18     present            83   90
# 9          separate_adj               16    separate            85   91
# 10         separate_vrb               15    separate             6   91
# 11            wound_vrb               13       wound            28   89
# 12            bass_corp                9        bass            13   87
# 13         conflict_nou                8    conflict            86   90
# 14         lead_nou-vrb                8        lead            83  104
# 15            close_vrb                7       close             5   89
# 16          produce_vrb                7     produce            84   90
# 17               mobile                5      mobile            85   89
# 18    alternate_adj-nou                5   alternate            87   92
# 19          present_vrb                4     present             7   90
# 20         frequent_adj                4    frequent            86   90
# 21             aged_adj                3        aged             4   91
# 22  content_adj-nou-vrb                3     content             1   90
# 23           invite_vrb                3      invite            71   90
# 24       transplant_vrb                2  transplant             5   90
# 25         bow_nou-knot                2         bow            43   90
# 26         bow_nou-ship                2         bow            47   90
# 27         initiate_vrb                2    initiate            83   90
# 28           misuse_vrb                1      misuse             7   88
# 29         axes_nou-vrb                1        axes            43   90
# 30    duplicate_adj-nou                1   duplicate            67   90
# 31        transport_nou                1   transport            84   89
# 32                  sow                1         sow            52   86
#
#     percent_ttl  accuracy  ttl_cap  allowed_new_samples  new_wordid_ttl  \
# 0      0.406593  0.750000      120                   29              66
# 1      0.535714  0.833333      120                    8              68
# 2      0.464286  0.833333      120                    8              60
# 3      0.822222  0.777778      120                   30             104
# 4      0.943820  0.900000      120                   31             115
# 5      0.626374  0.833333      120                   29              86
# 6      0.373626  0.500000      120                   29              63
# 7      0.066667  0.000000      120                   30              27
# 8      0.922222  0.888889      120                   30             101
# 9      0.934066  0.900000      120                   29             101
# 10     0.065934  0.000000      120                   29              21
# 11     0.314607  0.750000      120                   31              41
# 12     0.149425  0.666667      120                   33              22
# 13     0.955556  0.900000      120                   30              94
# 14     0.798077  0.888889      120                   16              91
# 15     0.056180  0.000000      120                   31              12
# 16     0.933333  0.888889      120                   30              91
# 17     0.955056  0.900000      120                   31              90
# 18     0.945652  0.900000      120                   28              92
# 19     0.077778  0.000000      120                   30              11
# 20     0.955556  0.900000      120                   30              90
# 21     0.043956  0.000000      120                   29               7
# 22     0.011111  0.000000      120                   30               4
# 23     0.788889  0.875000      120                   30              74
# 24     0.055556  0.000000      120                   30               7
# 25     0.477778  0.500000      120                   30              45
# 26     0.522222  0.500000      120                   30              49
# 27     0.922222  0.888889      120                   30              85
# 28     0.079545  0.000000      120                   32               8
# 29     0.477778  0.200000      120                   30              44
# 30     0.744444  0.875000      120                   30              68
# 31     0.943820  0.900000      120                   31              85
# 32     0.604651  0.833333      120                   34              53
#
#     other_wd_ct  aug_ttl  percent_aug_ttl  abs_percent_ttl_change
# 0            54      120         0.550000               14.340659
# 1            52      120         0.566667                3.095238
# 2            60      120         0.500000                3.571429
# 3            16      120         0.866667                4.444444
# 4             5      120         0.958333                1.451311
# 5            34      120         0.716667                9.029304
# 6            57      120         0.525000               15.137363
# 7            84      111         0.243243               17.657658
# 8             7      108         0.935185                1.296296
# 9             6      107         0.943925                0.985930
# 10           85      106         0.198113               13.217914
# 11           61      102         0.401961                8.735404
# 12           74       96         0.229167                7.974138
# 13            4       98         0.959184                0.362812
# 14           21      112         0.812500                1.442308
# 15           84       96         0.125000                6.882022
# 16            6       97         0.938144                0.481100
# 17            4       94         0.957447                0.239063
# 18            5       97         0.948454                0.280143
# 19           83       94         0.117021                3.924350
# 20            4       94         0.957447                0.189125
# 21           87       94         0.074468                3.051204
# 22           89       93         0.043011                3.189964
# 23           19       93         0.795699                0.681004
# 24           85       92         0.076087                2.053140
# 25           47       92         0.489130                1.135266
# 26           43       92         0.532609                1.038647
# 27            7       92         0.923913                0.169082
# 28           81       89         0.089888                1.034219
# 29           47       91         0.483516                0.573871
# 30           23       91         0.747253                0.280830
# 31            5       90         0.944444                0.062422
# 32           34       87         0.609195                0.454424

# %%
swbd_whd_df.to_csv("C:/Users/jseal/Dev/dissertation/Data/SWBD/SWBD_Homographs/swbd_homs_meta.tsv", sep='\t')

# %% [markdown]
# # Description
# **Functionality**: Confirm lack of variance in certain WHD homograph data classes
#
# **Use**: Use results to create only variant dataset

# %% [markdown]
# ### Import

# %%
import os
import math
import shutil
from glob import glob
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ### Variables

# %%
#Paths 
BASE = "C:/Users/jseal/Dev/dissertation/Data/WikipediaHomographData/data/"
WHD_DATA = BASE + "three_split_stratified_variant_data_corrected/"
TRAIN = WHD_DATA + "train/"
DEV = WHD_DATA + "dev/"
TEST = WHD_DATA + "test/"

pd.set_option('display.max_rows', None)

# %% [markdown]
# # Train

# %%
dfs = []
for f in tqdm(glob(TRAIN +'*.tsv')):
    df = pd.read_table(f)
    dfs.append(df)

train_df = pd.concat(dfs)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 128/128 [00:00<00:00, 815.04it/s]

# %%
train_df.head()
# Out:
#   homograph     wordid                                           sentence  \
# 0     abuse  abuse_nou  Some such suits accuse the Vatican of complici...
# 1     abuse  abuse_nou  The charges of third-degree sexual abuse were ...
# 2     abuse  abuse_nou  However, history has still shown the abuse of ...
# 3     abuse  abuse_nou  Ecological Risk Assessment: Use, Abuse, and Al...
# 4     abuse  abuse_nou  She described the abuse as "mild inappropriate...
#
#    start  end  orig_idx
# 0     59   64         0
# 1     35   40        56
# 2     37   42        24
# 3     33   38     11442
# 4     18   23        64

# %%
train_df.groupby('homograph')['wordid'].nunique().sort_values()
# Out:
# homograph
# abuse          2
# postulate      2
# polish         2
# pervert        2
# permit         2
# perfume        2
# perfect        2
# pasty          2
# overthrow      2
# ornament       2
# nestle         2
# mobile         2
# misuse         2
# minute         2
# precipitate    2
# lives          2
# learned        2
# lead           2
# laminate       2
# isolate        2
# invite         2
# invert         2
# invalid        2
# intrigue       2
# insult         2
# insert         2
# initiate       2
# increment      2
# increase       2
# live           2
# incline        2
# present        2
# progress       2
# wind           2
# uses           2
# use            2
# upset          2
# transport      2
# transplant     2
# transform      2
# tear           2
# syndicate      2
# suspect        2
# supplement     2
# subordinate    2
# sow            2
# produce        2
# separate       2
# rodeo          2
# retard         2
# resume         2
# rerelease      2
# reject         2
# refuse         2
# refund         2
# recount        2
# record         2
# rebel          2
# reading        2
# read           2
# protest        2
# sake           2
# import         2
# implement      2
# implant        2
# conscript      2
# conjugate      2
# conflict       2
# confines       2
# conduct        2
# compress       2
# compound       2
# combine        2
# close          2
# celtic         2
# buffet         2
# bow            2
# blessed        2
# construct      2
# bass           2
# attribute      2
# associate      2
# articulate     2
# approximate    2
# animate        2
# analyses       2
# alternate      2
# aggregate      2
# aged           2
# affiliate      2
# affect         2
# advocate       2
# abuses         2
# axes           2
# consummate     2
# content        2
# contest        2
# impact         2
# graduate       2
# frequent       2
# fragment       2
# extract        2
# expose         2
# export         2
# exploit        2
# excuse         2
# estimate       2
# escort         2
# duplicate      2
# dove           2
# document       2
# discount       2
# discharge      2
# discard        2
# diffuse        2
# diagnoses      2
# deliberate     2
# delegate       2
# degenerate     2
# defect         2
# decrease       2
# correlate      2
# coordinate     2
# convict        2
# convert        2
# converse       2
# winds          2
# wound          2
# Name: wordid, dtype: int64

# %%
hids = []
for idx, group in train_df.groupby('homograph'):
    #print(idx)
    ttl = 0
    grp = []
    for wordid in group['wordid'].unique():
        homograph_wordid = {}
        homograph_wordid['homograph'] = idx
        homograph_wordid["wordid"] = wordid
        count = len(group[group['wordid'] == wordid])
        homograph_wordid["wordid_count"] = count
        #print("{}:{}".format(wordid, count))
        grp.append(homograph_wordid)
        ttl += count
    hid_df = pd.DataFrame(grp)    
    hid_df["ttl"] = ttl
    hids.append(hid_df)
    #print("\n")
hids_df = pd.concat(hids)
hids_df["percent_ttl"] = hids_df['wordid_count']/hids_df["ttl"]
print(hids_df)
# Out:
#      homograph                 wordid  wordid_count  ttl  percent_ttl
# 0        abuse              abuse_nou            72   80     0.900000
# 1        abuse              abuse_vrb             8   80     0.100000
# 0       abuses             abuses_nou            66   80     0.825000
# 1       abuses             abuses_vrb            14   80     0.175000
# 0     advocate           advocate_nou            66   80     0.825000
# 1     advocate           advocate_vrb            14   80     0.175000
# 0       affect                 affect            76   79     0.962025
# 1       affect         affect_nou-psy             3   79     0.037975
# 0    affiliate          affiliate_nou            77   78     0.987179
# 1    affiliate          affiliate_vrb             1   78     0.012821
# 0         aged                   aged            77   80     0.962500
# 1         aged               aged_adj             3   80     0.037500
# 0    aggregate      aggregate_adj-nou            70   78     0.897436
# 1    aggregate          aggregate_vrb             8   78     0.102564
# 0    alternate      alternate_adj-nou            78   81     0.962963
# 1    alternate          alternate_vrb             3   81     0.037037
# 0     analyses           analyses_nou            71   80     0.887500
# 1     analyses           analyses_vrb             9   80     0.112500
# 0      animate        animate_adj-nou            30   76     0.394737
# 1      animate            animate_vrb            46   76     0.605263
# 0  approximate    approximate_adj-nou            70   79     0.886076
# 1  approximate        approximate_vrb             9   79     0.113924
# 0   articulate         articulate_adj            37   80     0.462500
# 1   articulate         articulate_vrb            43   80     0.537500
# 0    associate      associate_adj-nou            70   80     0.875000
# 1    associate          associate_vrb            10   80     0.125000
# 0    attribute          attribute_nou            43   80     0.537500
# 1    attribute          attribute_vrb            37   80     0.462500
# 0         axes               axes_nou            41   80     0.512500
# 1         axes           axes_nou-vrb            39   80     0.487500
# 0         bass                   bass            67   77     0.870130
# 1         bass              bass_corp            10   77     0.129870
# 0      blessed            blessed_adj            36   77     0.467532
# 1      blessed            blessed_vrb            41   77     0.532468
# 0          bow           bow_nou-knot            38   80     0.475000
# 1          bow           bow_nou-ship            42   80     0.525000
# 0       buffet             buffet_nou            74   77     0.961039
# 1       buffet             buffet_vrb             3   77     0.038961
# 0       celtic                 celtic            56   80     0.700000
# 1       celtic  celtic_adj-nou-sports            24   80     0.300000
# 0        close          close_adj-nou            74   78     0.948718
# 1        close              close_vrb             4   78     0.051282
# 0      combine            combine_nou             7   79     0.088608
# 1      combine            combine_vrb            72   79     0.911392
# 0     compound           compound_nou            78   79     0.987342
# 1     compound           compound_vrb             1   79     0.012658
# 0     compress               compress            74   77     0.961039
# 1     compress           compress_nou             3   77     0.038961
# 0      conduct            conduct_nou            38   80     0.475000
# 1      conduct            conduct_vrb            42   80     0.525000
# 0     confines           confines_nou            62   80     0.775000
# 1     confines           confines_vrb            18   80     0.225000
# 0     conflict           conflict_nou            77   79     0.974684
# 1     conflict           conflict_vrb             2   79     0.025316
# 0    conjugate      conjugate_adj-nou            76   79     0.962025
# 1    conjugate          conjugate_vrb             3   79     0.037975
# 0    conscript          conscript_nou            67   79     0.848101
# 1    conscript          conscript_vrb            12   79     0.151899
# 0    construct          construct_nou             8   80     0.100000
# 1    construct          construct_vrb            72   80     0.900000
# 0   consummate         consummate_adj            41   80     0.512500
# 1   consummate         consummate_vrb            39   80     0.487500
# 0      content    content_adj-nou-vrb             2   79     0.025316
# 1      content            content_nou            77   79     0.974684
# 0      contest            contest_nou            68   80     0.850000
# 1      contest            contest_vrb            12   80     0.150000
# 0     converse       converse_adj-nou            50   80     0.625000
# 1     converse           converse_vrb            30   80     0.375000
# 0      convert            convert_nou            11   80     0.137500
# 1      convert            convert_vrb            69   80     0.862500
# 0      convict            convict_nou            70   80     0.875000
# 1      convict            convict_vrb            10   80     0.125000
# 0   coordinate     coordinate_adj-nou            38   80     0.475000
# 1   coordinate         coordinate_vrb            42   80     0.525000
# 0    correlate          correlate_nou             8   80     0.100000
# 1    correlate      correlate_nou-vrb            72   80     0.900000
# 0     decrease           decrease_nou            37   79     0.468354
# 1     decrease           decrease_vrb            42   79     0.531646
# 0       defect             defect_nou            71   80     0.887500
# 1       defect             defect_vrb             9   80     0.112500
# 0   degenerate     degenerate_adj-nou            67   80     0.837500
# 1   degenerate         degenerate_vrb            13   80     0.162500
# 0     delegate           delegate_nou            74   80     0.925000
# 1     delegate           delegate_vrb             6   80     0.075000
# 0   deliberate         deliberate_adj            76   78     0.974359
# 1   deliberate         deliberate_vrb             2   78     0.025641
# 0    diagnoses          diagnoses_nou            62   80     0.775000
# 1    diagnoses          diagnoses_vrb            18   80     0.225000
# 0      diffuse            diffuse_adj            50   80     0.625000
# 1      diffuse            diffuse_vrb            30   80     0.375000
# 0      discard            discard_nou            22   80     0.275000
# 1      discard            discard_vrb            58   80     0.725000
# 0    discharge          discharge_nou            71   80     0.887500
# 1    discharge          discharge_vrb             9   80     0.112500
# 0     discount           discount_nou            78   79     0.987342
# 1     discount           discount_vrb             1   79     0.012658
# 0     document           document_nou            68   80     0.850000
# 1     document           document_vrb            12   80     0.150000
# 0         dove                   dove            46   51     0.901961
# 1         dove               dove_vrb             5   51     0.098039
# 0    duplicate      duplicate_adj-nou            58   80     0.725000
# 1    duplicate          duplicate_vrb            22   80     0.275000
# 0       escort             escort_nou            70   80     0.875000
# 1       escort             escort_vrb            10   80     0.125000
# 0     estimate           estimate_nou            58   80     0.725000
# 1     estimate           estimate_vrb            22   80     0.275000
# 0       excuse             excuse_nou            65   79     0.822785
# 1       excuse             excuse_vrb            14   79     0.177215
# 0      exploit            exploit_nou            11   80     0.137500
# 1      exploit            exploit_vrb            69   80     0.862500
# 0       export             export_nou            67   79     0.848101
# 1       export             export_vrb            12   79     0.151899
# 0       expose             expose_nou             4   78     0.051282
# 1       expose             expose_vrb            74   78     0.948718
# 0      extract            extract_nou            38   80     0.475000
# 1      extract            extract_vrb            42   80     0.525000
# 0     fragment           fragment_nou            77   78     0.987179
# 1     fragment           fragment_vrb             1   78     0.012821
# 0     frequent           frequent_adj            76   79     0.962025
# 1     frequent           frequent_vrb             3   79     0.037975
# 0     graduate       graduate_adj-nou            76   79     0.962025
# 1     graduate           graduate_vrb             3   79     0.037975
# 0       impact             impact_nou            78   79     0.987342
# 1       impact             impact_vrb             1   79     0.012658
# 0      implant            implant_nou            73   80     0.912500
# 1      implant            implant_vrb             7   80     0.087500
# 0    implement          implement_nou             8   80     0.100000
# 1    implement          implement_vrb            72   80     0.900000
# 0       import             import_nou            60   78     0.769231
# 1       import             import_vrb            18   78     0.230769
# 0      incline            incline_nou            76   78     0.974359
# 1      incline            incline_vrb             2   78     0.025641
# 0     increase           increase_nou            42   80     0.525000
# 1     increase           increase_vrb            38   80     0.475000
# 0    increment          increment_nou            70   80     0.875000
# 1    increment          increment_vrb            10   80     0.125000
# 0     initiate           initiate_nou             7   80     0.087500
# 1     initiate           initiate_vrb            73   80     0.912500
# 0       insert             insert_nou            42   80     0.525000
# 1       insert             insert_vrb            38   80     0.475000
# 0       insult             insult_nou            59   80     0.737500
# 1       insult             insult_vrb            21   80     0.262500
# 0     intrigue           intrigue_nou            76   79     0.962025
# 1     intrigue       intrigue_nou-vrb             3   79     0.037975
# 0      invalid            invalid_adj            61   79     0.772152
# 1      invalid            invalid_nou            18   79     0.227848
# 0       invert         invert_adj-nou            25   79     0.316456
# 1       invert             invert_vrb            54   79     0.683544
# 0       invite             invite_nou            17   80     0.212500
# 1       invite             invite_vrb            63   80     0.787500
# 0      isolate                isolate            62   80     0.775000
# 1      isolate            isolate_nou            18   80     0.225000
# 0     laminate           laminate_nou            77   79     0.974684
# 1     laminate           laminate_vrb             2   79     0.025316
# 0         lead               lead_nou            19   92     0.206522
# 1         lead           lead_nou-vrb            73   92     0.793478
# 0      learned            learned_adj             5   79     0.063291
# 1      learned            learned_vrb            74   79     0.936709
# 0         live               live_adj            49   79     0.620253
# 1         live               live_vrb            30   79     0.379747
# 0        lives              lives_nou            30   81     0.370370
# 1        lives              lives_vrb            51   81     0.629630
# 0       minute                 minute            67   77     0.870130
# 1       minute             minute_adj            10   77     0.129870
# 0       misuse             misuse_nou            73   78     0.935897
# 1       misuse             misuse_vrb             5   78     0.064103
# 0       mobile                 mobile            76   78     0.974359
# 1       mobile             mobile_geo             2   78     0.025641
# 0       nestle             nestle_nam            58   69     0.840580
# 1       nestle             nestle_vrb            11   69     0.159420
# 0     ornament           ornament_nou            77   79     0.974684
# 1     ornament           ornament_vrb             2   79     0.025316
# 0    overthrow          overthrow_nou            27   80     0.337500
# 1    overthrow          overthrow_vrb            53   80     0.662500
# 0        pasty              pasty_adj            56   75     0.746667
# 1        pasty              pasty_nou            19   75     0.253333
# 0      perfect            perfect_adj            76   80     0.950000
# 1      perfect            perfect_vrb             4   80     0.050000
# 0      perfume            perfume_nou            78   79     0.987342
# 1      perfume            perfume_vrb             1   79     0.012658
# 0       permit             permit_nou            43   79     0.544304
# 1       permit             permit_vrb            36   79     0.455696
# 0      pervert            pervert_nou            61   80     0.762500
# 1      pervert            pervert_vrb            19   80     0.237500
# 0       polish                 polish             1   79     0.012658
# 1       polish             polish_geo            78   79     0.987342
# 0    postulate          postulate_nou            52   80     0.650000
# 1    postulate          postulate_vrb            28   80     0.350000
# 0  precipitate    precipitate_adj-nou            32   80     0.400000
# 1  precipitate        precipitate_vrb            48   80     0.600000
# 0      present        present_adj-nou            73   80     0.912500
# 1      present            present_vrb             7   80     0.087500
# 0      produce            produce_nou             6   80     0.075000
# 1      produce            produce_vrb            74   80     0.925000
# 0     progress           progress_nou            65   79     0.822785
# 1     progress           progress_vrb            14   79     0.177215
# 0      protest            protest_nou            72   80     0.900000
# 1      protest            protest_vrb             8   80     0.100000
# 0         read              read_past            47  100     0.470000
# 1         read           read_present            53  100     0.530000
# 0      reading             reading_en            66   80     0.825000
# 1      reading            reading_geo            14   80     0.175000
# 0        rebel              rebel_nou            74   79     0.936709
# 1        rebel              rebel_vrb             5   79     0.063291
# 0       record             record_nou            70   80     0.875000
# 1       record             record_vrb            10   80     0.125000
# 0      recount            recount_nou            58   80     0.725000
# 1      recount            recount_vrb            22   80     0.275000
# 0       refund             refund_nou            58   80     0.725000
# 1       refund             refund_vrb            22   80     0.275000
# 0       refuse             refuse_nou            12   80     0.150000
# 1       refuse             refuse_vrb            68   80     0.850000
# 0       reject             reject_nou             3   76     0.039474
# 1       reject             reject_vrb            73   76     0.960526
# 0    rerelease              rerelease            69   80     0.862500
# 1    rerelease          rerelease_vrb            11   80     0.137500
# 0       resume             resume_nou             6   78     0.076923
# 1       resume             resume_vrb            72   78     0.923077
# 0       retard             retard_nou            12   75     0.160000
# 1       retard             retard_vrb            63   75     0.840000
# 0        rodeo                  rodeo            74   75     0.986667
# 1        rodeo              rodeo_geo             1   75     0.013333
# 0         sake                   sake            66   79     0.835443
# 1         sake                sake_jp            13   79     0.164557
# 0     separate           separate_adj            75   80     0.937500
# 1     separate           separate_vrb             5   80     0.062500
# 0          sow                    sow            48   77     0.623377
# 1          sow                sow_nou            29   77     0.376623
# 0  subordinate    subordinate_adj-nou            78   79     0.987342
# 1  subordinate        subordinate_vrb             1   79     0.012658
# 0   supplement         supplement_nou            53   79     0.670886
# 1   supplement         supplement_vrb            26   79     0.329114
# 0      suspect        suspect_adj-nou            58   80     0.725000
# 1      suspect            suspect_vrb            22   80     0.275000
# 0    syndicate          syndicate_nou            77   79     0.974684
# 1    syndicate          syndicate_vrb             2   79     0.025316
# 0         tear               tear_nou            26   79     0.329114
# 1         tear               tear_vrb            53   79     0.670886
# 0    transform              transform            54   80     0.675000
# 1    transform          transform_nou            26   80     0.325000
# 0   transplant         transplant_nou            75   79     0.949367
# 1   transplant         transplant_vrb             4   79     0.050633
# 0    transport          transport_nou            74   78     0.948718
# 1    transport          transport_vrb             4   78     0.051282
# 0        upset              upset_nou            58   80     0.725000
# 1        upset              upset_vrb            22   80     0.275000
# 0          use                use_nou            46   80     0.575000
# 1          use                use_vrb            34   80     0.425000
# 0         uses               uses_nou            10   80     0.125000
# 1         uses               uses_vrb            70   80     0.875000
# 0         wind               wind_nou            75   79     0.949367
# 1         wind               wind_vrb             4   79     0.050633
# 0        winds              winds_nou            73   77     0.948052
# 1        winds              winds_vrb             4   77     0.051948
# 0        wound          wound_nou-vrb            53   79     0.670886
# 1        wound              wound_vrb            26   79     0.329114

# %%
hids_df.ttl.mean()
# Out:
# 79.1484375

# %%
ratios = []
for i, grp in hids_df.groupby('homograph'): 
    ratio = {}
    counts = []
    ratio['homograph'] = i
    for wdid in grp['wordid']:
        counts.append(grp[grp['wordid'] == wdid]['wordid_count'].item())
    counts.sort()
    print(counts)
    gcd = math.gcd(counts[0], counts[1])
    print(gcd)
    ratio["ratio"] = str(counts[0]) + ":" + str(counts[1]) 
    #ratio["ratio"] = (counts[0]) / (counts[1])
    ratio["difference"] = counts[1] - counts[0]
    #ratio["percent_difference"] = ((counts[1] - counts[0]) / (counts[1] + counts[0]))*100
    ratios.append(ratio)
ratios
ratios_df = pd.DataFrame(ratios)
ratios_df.sort_values(by='ratio')
# Out:
# [8, 72]
# 8
# [14, 66]
# 2
# [14, 66]
# 2
# [3, 76]
# 1
# [1, 77]
# 1
# [3, 77]
# 1
# [8, 70]
# 2
# [3, 78]
# 3
# [9, 71]
# 1
# [30, 46]
# 2
# [9, 70]
# 1
# [37, 43]
# 1
# [10, 70]
# 10
# [37, 43]
# 1
# [39, 41]
# 1
# [10, 67]
# 1
# [36, 41]
# 1
# [38, 42]
# 2
# [3, 74]
# 1
# [24, 56]
# 8
# [4, 74]
# 2
# [7, 72]
# 1
# [1, 78]
# 1
# [3, 74]
# 1
# [38, 42]
# 2
# [18, 62]
# 2
# [2, 77]
# 1
# [3, 76]
# 1
# [12, 67]
# 1
# [8, 72]
# 8
# [39, 41]
# 1
# [2, 77]
# 1
# [12, 68]
# 4
# [30, 50]
# 10
# [11, 69]
# 1
# [10, 70]
# 10
# [38, 42]
# 2
# [8, 72]
# 8
# [37, 42]
# 1
# [9, 71]
# 1
# [13, 67]
# 1
# [6, 74]
# 2
# [2, 76]
# 2
# [18, 62]
# 2
# [30, 50]
# 10
# [22, 58]
# 2
# [9, 71]
# 1
# [1, 78]
# 1
# [12, 68]
# 4
# [5, 46]
# 1
# [22, 58]
# 2
# [10, 70]
# 10
# [22, 58]
# 2
# [14, 65]
# 1
# [11, 69]
# 1
# [12, 67]
# 1
# [4, 74]
# 2
# [38, 42]
# 2
# [1, 77]
# 1
# [3, 76]
# 1
# [3, 76]
# 1
# [1, 78]
# 1
# [7, 73]
# 1
# [8, 72]
# 8
# [18, 60]
# 6
# [2, 76]
# 2
# [38, 42]
# 2
# [10, 70]
# 10
# [7, 73]
# 1
# [38, 42]
# 2
# [21, 59]
# 1
# [3, 76]
# 1
# [18, 61]
# 1
# [25, 54]
# 1
# [17, 63]
# 1
# [18, 62]
# 2
# [2, 77]
# 1
# [19, 73]
# 1
# [5, 74]
# 1
# [30, 49]
# 1
# [30, 51]
# 3
# [10, 67]
# 1
# [5, 73]
# 1
# [2, 76]
# 2
# [11, 58]
# 1
# [2, 77]
# 1
# [27, 53]
# 1
# [19, 56]
# 1
# [4, 76]
# 4
# [1, 78]
# 1
# [36, 43]
# 1
# [19, 61]
# 1
# [1, 78]
# 1
# [28, 52]
# 4
# [32, 48]
# 16
# [7, 73]
# 1
# [6, 74]
# 2
# [14, 65]
# 1
# [8, 72]
# 8
# [47, 53]
# 1
# [14, 66]
# 2
# [5, 74]
# 1
# [10, 70]
# 10
# [22, 58]
# 2
# [22, 58]
# 2
# [12, 68]
# 4
# [3, 73]
# 1
# [11, 69]
# 1
# [6, 72]
# 6
# [12, 63]
# 3
# [1, 74]
# 1
# [13, 66]
# 1
# [5, 75]
# 5
# [29, 48]
# 1
# [1, 78]
# 1
# [26, 53]
# 1
# [22, 58]
# 2
# [2, 77]
# 1
# [26, 53]
# 1
# [26, 54]
# 2
# [4, 75]
# 1
# [4, 74]
# 2
# [22, 58]
# 2
# [34, 46]
# 2
# [10, 70]
# 10
# [4, 75]
# 1
# [4, 73]
# 1
# [26, 53]
# 1
#        homograph  ratio  difference
# 81        minute  10:67          57
# 15          bass  10:67          57
# 51        escort  10:70          60
# 67     increment  10:70          60
# 35       convict  10:70          60
# 102       record  10:70          60
# 12     associate  10:70          60
# 124         uses  10:70          60
# 84        nestle  11:58          47
# 34       convert  11:69          58
# 107    rerelease  11:69          58
# 54       exploit  11:69          58
# 109       retard  12:63          51
# 28     conscript  12:67          55
# 55        export  12:67          55
# 105       refuse  12:68          56
# 48      document  12:68          56
# 32       contest  12:68          56
# 111         sake  13:66          53
# 40    degenerate  13:67          54
# 53        excuse  14:65          51
# 97      progress  14:65          51
# 2       advocate  14:66          52
# 100      reading  14:66          52
# 1         abuses  14:66          52
# 74        invite  17:63          46
# 64        import  18:60          42
# 72       invalid  18:61          43
# 43     diagnoses  18:62          44
# 25      confines  18:62          44
# 75       isolate  18:62          44
# 87         pasty  19:56          37
# 91       pervert  19:61          42
# 77          lead  19:73          54
# 110        rodeo   1:74          73
# 4      affiliate   1:77          76
# 58      fragment   1:77          76
# 61        impact   1:78          77
# 89       perfume   1:78          77
# 22      compound   1:78          77
# 92        polish   1:78          77
# 114  subordinate   1:78          77
# 47      discount   1:78          77
# 70        insult  21:59          38
# 52      estimate  22:58          36
# 104       refund  22:58          36
# 50     duplicate  22:58          36
# 103      recount  22:58          36
# 116      suspect  22:58          36
# 122        upset  22:58          36
# 45       discard  22:58          36
# 19        celtic  24:56          32
# 73        invert  25:54          29
# 115   supplement  26:53          27
# 127        wound  26:53          27
# 118         tear  26:53          27
# 119    transform  26:54          28
# 86     overthrow  27:53          26
# 93     postulate  28:52          24
# 113          sow  29:48          19
# 83        mobile   2:76          74
# 42    deliberate   2:76          74
# 65       incline   2:76          74
# 26      conflict   2:77          75
# 117    syndicate   2:77          75
# 76      laminate   2:77          75
# 31       content   2:77          75
# 85      ornament   2:77          75
# 9        animate  30:46          16
# 79          live  30:49          19
# 44       diffuse  30:50          20
# 33      converse  30:50          20
# 80         lives  30:51          21
# 94   precipitate  32:48          16
# 123          use  34:46          12
# 16       blessed  36:41           5
# 90        permit  36:43           7
# 38      decrease  37:42           5
# 11    articulate  37:43           6
# 13     attribute  37:43           6
# 24       conduct  38:42           4
# 36    coordinate  38:42           4
# 69        insert  38:42           4
# 66      increase  38:42           4
# 57       extract  38:42           4
# 17           bow  38:42           4
# 30    consummate  39:41           2
# 14          axes  39:41           2
# 106       reject   3:73          70
# 18        buffet   3:74          71
# 23      compress   3:74          71
# 3         affect   3:76          73
# 59      frequent   3:76          73
# 60      graduate   3:76          73
# 27     conjugate   3:76          73
# 71      intrigue   3:76          73
# 5           aged   3:77          74
# 7      alternate   3:78          75
# 99          read  47:53           6
# 126        winds   4:73          69
# 56        expose   4:74          70
# 20         close   4:74          70
# 121    transport   4:74          70
# 120   transplant   4:75          71
# 125         wind   4:75          71
# 88       perfect   4:76          72
# 49          dove   5:46          41
# 82        misuse   5:73          68
# 78       learned   5:74          69
# 101        rebel   5:74          69
# 112     separate   5:75          70
# 108       resume   6:72          66
# 41      delegate   6:74          68
# 96       produce   6:74          68
# 21       combine   7:72          65
# 62       implant   7:73          66
# 95       present   7:73          66
# 68      initiate   7:73          66
# 6      aggregate   8:70          62
# 0          abuse   8:72          64
# 37     correlate   8:72          64
# 29     construct   8:72          64
# 98       protest   8:72          64
# 63     implement   8:72          64
# 10   approximate   9:70          61
# 46     discharge   9:71          62
# 39        defect   9:71          62
# 8       analyses   9:71          62

# %%
ratios_df.to_latex(index=False,longtable=True, buf='final_train_class_ratios', caption='Final WHD Train split class ratios and differences', label='whdfinaltrainclassratios')

# %%
len(ratios_df[ratios_df["difference"] <= 10]) / len(ratios_df)
# Out:
# 0.109375

# %%
len(ratios_df[(ratios_df["difference"] > 10) & (ratios_df["difference"] <= 20)]) / len(ratios_df)
# Out:
# 0.0546875

# %%
len(ratios_df[(ratios_df["difference"] > 20) & (ratios_df["difference"] <= 30)]) / len(ratios_df)
# Out:
# 0.0625

# %%
len(ratios_df[(ratios_df["difference"] > 30) & (ratios_df["difference"] <= 40)]) / len(ratios_df)
# Out:
# 0.078125

# %%
len(ratios_df[(ratios_df["difference"] > 40) & (ratios_df["difference"] <= 50)]) / len(ratios_df)
# Out:
# 0.0703125

# %%
len(ratios_df[(ratios_df["difference"] > 50) & (ratios_df["difference"] <= 60)]) / len(ratios_df)
# Out:
# 0.1953125

# %%
len(ratios_df[(ratios_df["difference"] >= 60) & (ratios_df["difference"] <= 70)]) / len(ratios_df)
# Out:
# 0.25

# %%
len(ratios_df[(ratios_df["difference"] > 70) & (ratios_df["difference"] <= 80)]) / len(ratios_df)
# Out:
# 0.2265625

# %%
len(ratios_df[(ratios_df["difference"] > 70) & (ratios_df["difference"] <= 77)])  / len(ratios_df)
# Out:
# 0.2265625

# %%
len(ratios_df[(ratios_df["difference"] > 80) & (ratios_df["difference"] <= 90)]) / len(ratios_df)
# Out:
# 0.0

# %%
len(ratios_df[(ratios_df["difference"] > 90) & (ratios_df["difference"] <= 100)]) / len(ratios_df)
# Out:
# 0.0

# %%
hids_df.describe()
# Out:
#        wordid_count         ttl  percent_ttl
# count    256.000000  256.000000   256.000000
# mean      39.574219   79.148438     0.500000
# std       27.722334    3.617148     0.351232
# min        1.000000   51.000000     0.012658
# 25%       10.750000   79.000000     0.135593
# 50%       41.000000   80.000000     0.500000
# 75%       69.000000   80.000000     0.864407
# max       78.000000  100.000000     0.987342

# %%
#hids_df.to_csv("hids.csv")

# %%
unique = train_df.groupby('homograph')['wordid'].nunique()
one_count = unique[unique == 1]
len(one_count)
# Out:
# 0

# %%
len(train_df)
# Out:
# 10131

# %%
#Some sentences used multiple times for different instances
train_deduped = train_df.drop_duplicates(subset=['sentence'])
len(train_deduped)
# Out:
# 10118

# %%
import numpy as np
dups = np.setdiff1d(train_deduped.index,train_df.index)

dups
# Out:
# array([], dtype=int64)

# %%
train_deduped.head()
# Out:
#   homograph     wordid                                           sentence  \
# 0     abuse  abuse_nou  Some such suits accuse the Vatican of complici...
# 1     abuse  abuse_nou  The charges of third-degree sexual abuse were ...
# 2     abuse  abuse_nou  However, history has still shown the abuse of ...
# 3     abuse  abuse_nou  Ecological Risk Assessment: Use, Abuse, and Al...
# 4     abuse  abuse_nou  She described the abuse as "mild inappropriate...
#
#    start  end  orig_idx
# 0     59   64         0
# 1     35   40        56
# 2     37   42        24
# 3     33   38     11442
# 4     18   23        64

# %%
dups = train_df[~train_df.index.isin(train_deduped.index)]

# %%
dups
# Out:
# Empty DataFrame
# Columns: [homograph, wordid, sentence, start, end, orig_idx]
# Index: []

# %% [markdown]
# # Dev

# %%
dfs = []
for f in tqdm(glob(DEV +'*.tsv')):
    df = pd.read_table(f)
    dfs.append(df)

dev_df = pd.concat(dfs)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 128/128 [00:00<00:00, 743.40it/s]

# %%
dev_df.head()
# Out:
#   homograph     wordid                                           sentence  \
# 0     abuse  abuse_nou  There were incidences of abuse, however, with ...
# 1     abuse  abuse_nou  In Ramona v. Isabella, Gary Ramona sued his da...
# 2     abuse  abuse_nou  They do not include other factors of disadvant...
# 3     abuse  abuse_nou  It smashed taboos surrounding mental health, a...
# 4     abuse  abuse_nou  Members of all three groups have been involved...
#
#    start  end  orig_idx
# 0     25   30        81
# 1    102  107        65
# 2    100  105        61
# 3     45   50        53
# 4     63   68        23

# %%
dev_df.groupby('homograph')['wordid'].nunique().sort_values()
# Out:
# homograph
# abuse          2
# postulate      2
# polish         2
# pervert        2
# permit         2
# perfume        2
# perfect        2
# pasty          2
# overthrow      2
# ornament       2
# nestle         2
# mobile         2
# misuse         2
# minute         2
# precipitate    2
# lives          2
# learned        2
# lead           2
# laminate       2
# isolate        2
# invite         2
# invert         2
# invalid        2
# intrigue       2
# insult         2
# insert         2
# initiate       2
# increment      2
# increase       2
# live           2
# incline        2
# present        2
# progress       2
# wind           2
# uses           2
# use            2
# upset          2
# transport      2
# transplant     2
# transform      2
# tear           2
# syndicate      2
# suspect        2
# supplement     2
# subordinate    2
# sow            2
# produce        2
# separate       2
# rodeo          2
# retard         2
# resume         2
# rerelease      2
# reject         2
# refuse         2
# refund         2
# recount        2
# record         2
# rebel          2
# reading        2
# read           2
# protest        2
# sake           2
# import         2
# implement      2
# implant        2
# conscript      2
# conjugate      2
# conflict       2
# confines       2
# conduct        2
# compress       2
# compound       2
# combine        2
# close          2
# celtic         2
# buffet         2
# bow            2
# blessed        2
# construct      2
# bass           2
# attribute      2
# associate      2
# articulate     2
# approximate    2
# animate        2
# analyses       2
# alternate      2
# aggregate      2
# aged           2
# affiliate      2
# affect         2
# advocate       2
# abuses         2
# axes           2
# consummate     2
# content        2
# contest        2
# impact         2
# graduate       2
# frequent       2
# fragment       2
# extract        2
# expose         2
# export         2
# exploit        2
# excuse         2
# estimate       2
# escort         2
# duplicate      2
# dove           2
# document       2
# discount       2
# discharge      2
# discard        2
# diffuse        2
# diagnoses      2
# deliberate     2
# delegate       2
# degenerate     2
# defect         2
# decrease       2
# correlate      2
# coordinate     2
# convict        2
# convert        2
# converse       2
# winds          2
# wound          2
# Name: wordid, dtype: int64

# %%
unique = dev_df.groupby('homograph')['wordid'].nunique()
one_count = unique[unique == 1]
one_count
# Out:
# Series([], Name: wordid, dtype: int64)

# %%
hids = []
for idx, group in dev_df.groupby('homograph'):
    #print(idx)
    ttl = 0
    grp = []
    for wordid in group['wordid'].unique():
        homograph_wordid = {}
        homograph_wordid['homograph'] = idx
        homograph_wordid["wordid"] = wordid
        count = len(group[group['wordid'] == wordid])
        homograph_wordid["wordid_count"] = count
        #print("{}:{}".format(wordid, count))
        grp.append(homograph_wordid)
        ttl += count
    hid_df = pd.DataFrame(grp)    
    hid_df["ttl"] = ttl
    hids.append(hid_df)
    #print("\n")
hids_df = pd.concat(hids)
hids_df["percent_ttl"] = hids_df['wordid_count']/hids_df["ttl"]
print(hids_df)
# Out:
#      homograph                 wordid  wordid_count  ttl  percent_ttl
# 0        abuse              abuse_nou             9   10     0.900000
# 1        abuse              abuse_vrb             1   10     0.100000
# 0       abuses             abuses_nou             8   10     0.800000
# 1       abuses             abuses_vrb             2   10     0.200000
# 0     advocate           advocate_nou             8   10     0.800000
# 1     advocate           advocate_vrb             2   10     0.200000
# 0       affect                 affect            10   11     0.909091
# 1       affect         affect_nou-psy             1   11     0.090909
# 0    affiliate          affiliate_nou            10   11     0.909091
# 1    affiliate          affiliate_vrb             1   11     0.090909
# 0         aged                   aged            10   11     0.909091
# 1         aged               aged_adj             1   11     0.090909
# 0    aggregate      aggregate_adj-nou             9   10     0.900000
# 1    aggregate          aggregate_vrb             1   10     0.100000
# 0    alternate      alternate_adj-nou            10   11     0.909091
# 1    alternate          alternate_vrb             1   11     0.090909
# 0     analyses           analyses_nou             9   10     0.900000
# 1     analyses           analyses_vrb             1   10     0.100000
# 0      animate        animate_adj-nou             4   10     0.400000
# 1      animate            animate_vrb             6   10     0.600000
# 0  approximate    approximate_adj-nou             9   10     0.900000
# 1  approximate        approximate_vrb             1   10     0.100000
# 0   articulate         articulate_adj             4   10     0.400000
# 1   articulate         articulate_vrb             6   10     0.600000
# 0    associate      associate_adj-nou             9   10     0.900000
# 1    associate          associate_vrb             1   10     0.100000
# 0    attribute          attribute_nou             6   10     0.600000
# 1    attribute          attribute_vrb             4   10     0.400000
# 0         axes               axes_nou             5   10     0.500000
# 1         axes           axes_nou-vrb             5   10     0.500000
# 0         bass                   bass             8   10     0.800000
# 1         bass              bass_corp             2   10     0.200000
# 0      blessed            blessed_adj             4    9     0.444444
# 1      blessed            blessed_vrb             5    9     0.555556
# 0          bow           bow_nou-knot             4   10     0.400000
# 1          bow           bow_nou-ship             6   10     0.600000
# 0       buffet             buffet_nou            10   11     0.909091
# 1       buffet             buffet_vrb             1   11     0.090909
# 0       celtic                 celtic             7   10     0.700000
# 1       celtic  celtic_adj-nou-sports             3   10     0.300000
# 0        close          close_adj-nou            10   11     0.909091
# 1        close              close_vrb             1   11     0.090909
# 0      combine            combine_nou             1   10     0.100000
# 1      combine            combine_vrb             9   10     0.900000
# 0     compound           compound_nou            10   11     0.909091
# 1     compound           compound_vrb             1   11     0.090909
# 0     compress               compress            10   11     0.909091
# 1     compress           compress_nou             1   11     0.090909
# 0      conduct            conduct_nou             5   10     0.500000
# 1      conduct            conduct_vrb             5   10     0.500000
# 0     confines           confines_nou             8   10     0.800000
# 1     confines           confines_vrb             2   10     0.200000
# 0     conflict           conflict_nou            10   11     0.909091
# 1     conflict           conflict_vrb             1   11     0.090909
# 0    conjugate      conjugate_adj-nou            10   11     0.909091
# 1    conjugate          conjugate_vrb             1   11     0.090909
# 0    conscript          conscript_nou             8   10     0.800000
# 1    conscript          conscript_vrb             2   10     0.200000
# 0    construct          construct_nou             1   10     0.100000
# 1    construct          construct_vrb             9   10     0.900000
# 0   consummate         consummate_adj             5   10     0.500000
# 1   consummate         consummate_vrb             5   10     0.500000
# 0      content    content_adj-nou-vrb             1   11     0.090909
# 1      content            content_nou            10   11     0.909091
# 0      contest            contest_nou             8   10     0.800000
# 1      contest            contest_vrb             2   10     0.200000
# 0     converse       converse_adj-nou             6   10     0.600000
# 1     converse           converse_vrb             4   10     0.400000
# 0      convert            convert_nou             2   10     0.200000
# 1      convert            convert_vrb             8   10     0.800000
# 0      convict            convict_nou             9   10     0.900000
# 1      convict            convict_vrb             1   10     0.100000
# 0   coordinate     coordinate_adj-nou             4    9     0.444444
# 1   coordinate         coordinate_vrb             5    9     0.555556
# 0    correlate          correlate_nou             1   10     0.100000
# 1    correlate      correlate_nou-vrb             9   10     0.900000
# 0     decrease           decrease_nou             4   10     0.400000
# 1     decrease           decrease_vrb             6   10     0.600000
# 0       defect             defect_nou             9   10     0.900000
# 1       defect             defect_vrb             1   10     0.100000
# 0   degenerate     degenerate_adj-nou             8   10     0.800000
# 1   degenerate         degenerate_vrb             2   10     0.200000
# 0     delegate           delegate_nou             9   10     0.900000
# 1     delegate           delegate_vrb             1   10     0.100000
# 0   deliberate         deliberate_adj            10   11     0.909091
# 1   deliberate         deliberate_vrb             1   11     0.090909
# 0    diagnoses          diagnoses_nou             8   10     0.800000
# 1    diagnoses          diagnoses_vrb             2   10     0.200000
# 0      diffuse            diffuse_adj             6   10     0.600000
# 1      diffuse            diffuse_vrb             4   10     0.400000
# 0      discard            discard_nou             2   10     0.200000
# 1      discard            discard_vrb             8   10     0.800000
# 0    discharge          discharge_nou             9   10     0.900000
# 1    discharge          discharge_vrb             1   10     0.100000
# 0     discount           discount_nou            10   11     0.909091
# 1     discount           discount_vrb             1   11     0.090909
# 0     document           document_nou             8   10     0.800000
# 1     document           document_vrb             2   10     0.200000
# 0         dove                   dove             6    7     0.857143
# 1         dove               dove_vrb             1    7     0.142857
# 0    duplicate      duplicate_adj-nou             8   10     0.800000
# 1    duplicate          duplicate_vrb             2   10     0.200000
# 0       escort             escort_nou             9   10     0.900000
# 1       escort             escort_vrb             1   10     0.100000
# 0     estimate           estimate_nou             7    9     0.777778
# 1     estimate           estimate_vrb             2    9     0.222222
# 0       excuse             excuse_nou             8   10     0.800000
# 1       excuse             excuse_vrb             2   10     0.200000
# 0      exploit            exploit_nou             2   10     0.200000
# 1      exploit            exploit_vrb             8   10     0.800000
# 0       export             export_nou             8   10     0.800000
# 1       export             export_vrb             2   10     0.200000
# 0       expose             expose_nou             1   11     0.090909
# 1       expose             expose_vrb            10   11     0.909091
# 0      extract            extract_nou             5   10     0.500000
# 1      extract            extract_vrb             5   10     0.500000
# 0     fragment           fragment_nou            10   11     0.909091
# 1     fragment           fragment_vrb             1   11     0.090909
# 0     frequent           frequent_adj            10   11     0.909091
# 1     frequent           frequent_vrb             1   11     0.090909
# 0     graduate       graduate_adj-nou            10   11     0.909091
# 1     graduate           graduate_vrb             1   11     0.090909
# 0       impact             impact_nou            10   11     0.909091
# 1       impact             impact_vrb             1   11     0.090909
# 0      implant            implant_nou             9   10     0.900000
# 1      implant            implant_vrb             1   10     0.100000
# 0    implement          implement_nou             1   10     0.100000
# 1    implement          implement_vrb             9   10     0.900000
# 0       import             import_nou             8   10     0.800000
# 1       import             import_vrb             2   10     0.200000
# 0      incline            incline_nou            10   11     0.909091
# 1      incline            incline_vrb             1   11     0.090909
# 0     increase           increase_nou             6   10     0.600000
# 1     increase           increase_vrb             4   10     0.400000
# 0    increment          increment_nou             8    9     0.888889
# 1    increment          increment_vrb             1    9     0.111111
# 0     initiate           initiate_nou             1   10     0.100000
# 1     initiate           initiate_vrb             9   10     0.900000
# 0       insert             insert_nou             5   10     0.500000
# 1       insert             insert_vrb             5   10     0.500000
# 0       insult             insult_nou             8   10     0.800000
# 1       insult             insult_vrb             2   10     0.200000
# 0     intrigue           intrigue_nou            10   11     0.909091
# 1     intrigue       intrigue_nou-vrb             1   11     0.090909
# 0      invalid            invalid_adj             8   10     0.800000
# 1      invalid            invalid_nou             2   10     0.200000
# 0       invert         invert_adj-nou             3   10     0.300000
# 1       invert             invert_vrb             7   10     0.700000
# 0       invite             invite_nou             2   10     0.200000
# 1       invite             invite_vrb             8   10     0.800000
# 0      isolate                isolate             8   10     0.800000
# 1      isolate            isolate_nou             2   10     0.200000
# 0     laminate           laminate_nou            10   11     0.909091
# 1     laminate           laminate_vrb             1   11     0.090909
# 0         lead               lead_nou             2   11     0.181818
# 1         lead           lead_nou-vrb             9   11     0.818182
# 0      learned            learned_adj             1   11     0.090909
# 1      learned            learned_vrb            10   11     0.909091
# 0         live               live_adj             6   10     0.600000
# 1         live               live_vrb             4   10     0.400000
# 0        lives              lives_nou             4   10     0.400000
# 1        lives              lives_vrb             6   10     0.600000
# 0       minute                 minute             8   10     0.800000
# 1       minute             minute_adj             2   10     0.200000
# 0       misuse             misuse_nou             9   10     0.900000
# 1       misuse             misuse_vrb             1   10     0.100000
# 0       mobile                 mobile            10   11     0.909091
# 1       mobile             mobile_geo             1   11     0.090909
# 0       nestle             nestle_nam             7    9     0.777778
# 1       nestle             nestle_vrb             2    9     0.222222
# 0     ornament           ornament_nou            10   11     0.909091
# 1     ornament           ornament_vrb             1   11     0.090909
# 0    overthrow          overthrow_nou             4   10     0.400000
# 1    overthrow          overthrow_vrb             6   10     0.600000
# 0        pasty              pasty_adj             7    9     0.777778
# 1        pasty              pasty_nou             2    9     0.222222
# 0      perfect            perfect_adj            10   11     0.909091
# 1      perfect            perfect_vrb             1   11     0.090909
# 0      perfume            perfume_nou            10   11     0.909091
# 1      perfume            perfume_vrb             1   11     0.090909
# 0       permit             permit_nou             6   10     0.600000
# 1       permit             permit_vrb             4   10     0.400000
# 0      pervert            pervert_nou             8   10     0.800000
# 1      pervert            pervert_vrb             2   10     0.200000
# 0       polish                 polish             1   11     0.090909
# 1       polish             polish_geo            10   11     0.909091
# 0    postulate          postulate_nou             6   10     0.600000
# 1    postulate          postulate_vrb             4   10     0.400000
# 0  precipitate    precipitate_adj-nou             4   10     0.400000
# 1  precipitate        precipitate_vrb             6   10     0.600000
# 0      present        present_adj-nou             9   10     0.900000
# 1      present            present_vrb             1   10     0.100000
# 0      produce            produce_nou             1   10     0.100000
# 1      produce            produce_vrb             9   10     0.900000
# 0     progress           progress_nou             8   10     0.800000
# 1     progress           progress_vrb             2   10     0.200000
# 0      protest            protest_nou             9   10     0.900000
# 1      protest            protest_vrb             1   10     0.100000
# 0         read              read_past             6   12     0.500000
# 1         read           read_present             6   12     0.500000
# 0      reading             reading_en             8   10     0.800000
# 1      reading            reading_geo             2   10     0.200000
# 0        rebel              rebel_nou            10   11     0.909091
# 1        rebel              rebel_vrb             1   11     0.090909
# 0       record             record_nou             9   10     0.900000
# 1       record             record_vrb             1   10     0.100000
# 0      recount            recount_nou             7   10     0.700000
# 1      recount            recount_vrb             3   10     0.300000
# 0       refund             refund_nou             8   10     0.800000
# 1       refund             refund_vrb             2   10     0.200000
# 0       refuse             refuse_nou             2   10     0.200000
# 1       refuse             refuse_vrb             8   10     0.800000
# 0       reject             reject_nou             1   10     0.100000
# 1       reject             reject_vrb             9   10     0.900000
# 0    rerelease              rerelease             8   10     0.800000
# 1    rerelease          rerelease_vrb             2   10     0.200000
# 0       resume             resume_nou             1   10     0.100000
# 1       resume             resume_vrb             9   10     0.900000
# 0       retard             retard_nou             2   10     0.200000
# 1       retard             retard_vrb             8   10     0.800000
# 0        rodeo                  rodeo            10   11     0.909091
# 1        rodeo              rodeo_geo             1   11     0.090909
# 0         sake                   sake             8   10     0.800000
# 1         sake                sake_jp             2   10     0.200000
# 0     separate           separate_adj            10   11     0.909091
# 1     separate           separate_vrb             1   11     0.090909
# 0          sow                    sow             6   10     0.600000
# 1          sow                sow_nou             4   10     0.400000
# 0  subordinate    subordinate_adj-nou            10   11     0.909091
# 1  subordinate        subordinate_vrb             1   11     0.090909
# 0   supplement         supplement_nou             6   10     0.600000
# 1   supplement         supplement_vrb             4   10     0.400000
# 0      suspect        suspect_adj-nou             8   10     0.800000
# 1      suspect            suspect_vrb             2   10     0.200000
# 0    syndicate          syndicate_nou            10   11     0.909091
# 1    syndicate          syndicate_vrb             1   11     0.090909
# 0         tear               tear_nou             4   10     0.400000
# 1         tear               tear_vrb             6   10     0.600000
# 0    transform              transform             7   10     0.700000
# 1    transform          transform_nou             3   10     0.300000
# 0   transplant         transplant_nou            10   11     0.909091
# 1   transplant         transplant_vrb             1   11     0.090909
# 0    transport          transport_nou            10   11     0.909091
# 1    transport          transport_vrb             1   11     0.090909
# 0        upset              upset_nou             7    9     0.777778
# 1        upset              upset_vrb             2    9     0.222222
# 0          use                use_nou             6   10     0.600000
# 1          use                use_vrb             4   10     0.400000
# 0         uses               uses_nou             2   10     0.200000
# 1         uses               uses_vrb             8   10     0.800000
# 0         wind               wind_nou            10   11     0.909091
# 1         wind               wind_vrb             1   11     0.090909
# 0        winds              winds_nou             9   10     0.900000
# 1        winds              winds_vrb             1   10     0.100000
# 0        wound          wound_nou-vrb             6   10     0.600000
# 1        wound              wound_vrb             4   10     0.400000

# %%
hids_df.ttl.mean()
# Out:
# 10.21875

# %%
ratios = []
for i, grp in hids_df.groupby('homograph'): 
    ratio = {}
    counts = []
    ratio['homograph'] = i
    for wdid in grp['wordid']:
        counts.append(grp[grp['wordid'] == wdid]['wordid_count'].item())
    counts.sort()
    print(counts)
    gcd = math.gcd(counts[0], counts[1])
    print(gcd)
    ratio["ratio"] = str(counts[0]) + ":" + str(counts[1]) 
    #ratio["ratio"] = (counts[0]) / (counts[1])
    ratio["difference"] = counts[1] - counts[0]
    #ratio["percent_difference"] = ((counts[1] - counts[0]) / (counts[1] + counts[0]))*100
    ratios.append(ratio)
ratios
ratios_df = pd.DataFrame(ratios)
ratios_df.sort_values(by='ratio')
# Out:
# [1, 9]
# 1
# [2, 8]
# 2
# [2, 8]
# 2
# [1, 10]
# 1
# [1, 10]
# 1
# [1, 10]
# 1
# [1, 9]
# 1
# [1, 10]
# 1
# [1, 9]
# 1
# [4, 6]
# 2
# [1, 9]
# 1
# [4, 6]
# 2
# [1, 9]
# 1
# [4, 6]
# 2
# [5, 5]
# 5
# [2, 8]
# 2
# [4, 5]
# 1
# [4, 6]
# 2
# [1, 10]
# 1
# [3, 7]
# 1
# [1, 10]
# 1
# [1, 9]
# 1
# [1, 10]
# 1
# [1, 10]
# 1
# [5, 5]
# 5
# [2, 8]
# 2
# [1, 10]
# 1
# [1, 10]
# 1
# [2, 8]
# 2
# [1, 9]
# 1
# [5, 5]
# 5
# [1, 10]
# 1
# [2, 8]
# 2
# [4, 6]
# 2
# [2, 8]
# 2
# [1, 9]
# 1
# [4, 5]
# 1
# [1, 9]
# 1
# [4, 6]
# 2
# [1, 9]
# 1
# [2, 8]
# 2
# [1, 9]
# 1
# [1, 10]
# 1
# [2, 8]
# 2
# [4, 6]
# 2
# [2, 8]
# 2
# [1, 9]
# 1
# [1, 10]
# 1
# [2, 8]
# 2
# [1, 6]
# 1
# [2, 8]
# 2
# [1, 9]
# 1
# [2, 7]
# 1
# [2, 8]
# 2
# [2, 8]
# 2
# [2, 8]
# 2
# [1, 10]
# 1
# [5, 5]
# 5
# [1, 10]
# 1
# [1, 10]
# 1
# [1, 10]
# 1
# [1, 10]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [2, 8]
# 2
# [1, 10]
# 1
# [4, 6]
# 2
# [1, 8]
# 1
# [1, 9]
# 1
# [5, 5]
# 5
# [2, 8]
# 2
# [1, 10]
# 1
# [2, 8]
# 2
# [3, 7]
# 1
# [2, 8]
# 2
# [2, 8]
# 2
# [1, 10]
# 1
# [2, 9]
# 1
# [1, 10]
# 1
# [4, 6]
# 2
# [4, 6]
# 2
# [2, 8]
# 2
# [1, 9]
# 1
# [1, 10]
# 1
# [2, 7]
# 1
# [1, 10]
# 1
# [4, 6]
# 2
# [2, 7]
# 1
# [1, 10]
# 1
# [1, 10]
# 1
# [4, 6]
# 2
# [2, 8]
# 2
# [1, 10]
# 1
# [4, 6]
# 2
# [4, 6]
# 2
# [1, 9]
# 1
# [1, 9]
# 1
# [2, 8]
# 2
# [1, 9]
# 1
# [6, 6]
# 6
# [2, 8]
# 2
# [1, 10]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [2, 8]
# 2
# [2, 8]
# 2
# [1, 9]
# 1
# [2, 8]
# 2
# [1, 9]
# 1
# [2, 8]
# 2
# [1, 10]
# 1
# [2, 8]
# 2
# [1, 10]
# 1
# [4, 6]
# 2
# [1, 10]
# 1
# [4, 6]
# 2
# [2, 8]
# 2
# [1, 10]
# 1
# [4, 6]
# 2
# [3, 7]
# 1
# [1, 10]
# 1
# [1, 10]
# 1
# [2, 7]
# 1
# [4, 6]
# 2
# [2, 8]
# 2
# [1, 10]
# 1
# [1, 9]
# 1
# [4, 6]
# 2
#        homograph ratio  difference
# 89       perfume  1:10           9
# 61        impact  1:10           9
# 20         close  1:10           9
# 92        polish  1:10           9
# 22      compound  1:10           9
# 23      compress  1:10           9
# 47      discount  1:10           9
# 18        buffet  1:10           9
# 88       perfect  1:10           9
# 27     conjugate  1:10           9
# 85      ornament  1:10           9
# 83        mobile  1:10           9
# 65       incline  1:10           9
# 31       content  1:10           9
# 78       learned  1:10           9
# 26      conflict  1:10           9
# 76      laminate  1:10           9
# 60      graduate  1:10           9
# 101        rebel  1:10           9
# 125         wind  1:10           9
# 121    transport  1:10           9
# 3         affect  1:10           9
# 4      affiliate  1:10           9
# 5           aged  1:10           9
# 120   transplant  1:10           9
# 42    deliberate  1:10           9
# 7      alternate  1:10           9
# 114  subordinate  1:10           9
# 112     separate  1:10           9
# 110        rodeo  1:10           9
# 56        expose  1:10           9
# 58      fragment  1:10           9
# 59      frequent  1:10           9
# 117    syndicate  1:10           9
# 71      intrigue  1:10           9
# 49          dove   1:6           5
# 67     increment   1:8           7
# 82        misuse   1:9           8
# 126        winds   1:9           8
# 62       implant   1:9           8
# 95       present   1:9           8
# 96       produce   1:9           8
# 98       protest   1:9           8
# 102       record   1:9           8
# 106       reject   1:9           8
# 108       resume   1:9           8
# 51        escort   1:9           8
# 68      initiate   1:9           8
# 0          abuse   1:9           8
# 63     implement   1:9           8
# 37     correlate   1:9           8
# 21       combine   1:9           8
# 35       convict   1:9           8
# 12     associate   1:9           8
# 39        defect   1:9           8
# 10   approximate   1:9           8
# 41      delegate   1:9           8
# 8       analyses   1:9           8
# 29     construct   1:9           8
# 46     discharge   1:9           8
# 6      aggregate   1:9           8
# 122        upset   2:7           5
# 87         pasty   2:7           5
# 84        nestle   2:7           5
# 52      estimate   2:7           5
# 116      suspect   2:8           6
# 28     conscript   2:8           6
# 48      document   2:8           6
# 91       pervert   2:8           6
# 97      progress   2:8           6
# 100      reading   2:8           6
# 105       refuse   2:8           6
# 104       refund   2:8           6
# 107    rerelease   2:8           6
# 1         abuses   2:8           6
# 109       retard   2:8           6
# 111         sake   2:8           6
# 124         uses   2:8           6
# 2       advocate   2:8           6
# 15          bass   2:8           6
# 50     duplicate   2:8           6
# 25      confines   2:8           6
# 70        insult   2:8           6
# 40    degenerate   2:8           6
# 81        minute   2:8           6
# 34       convert   2:8           6
# 72       invalid   2:8           6
# 43     diagnoses   2:8           6
# 74        invite   2:8           6
# 75       isolate   2:8           6
# 64        import   2:8           6
# 45       discard   2:8           6
# 55        export   2:8           6
# 53        excuse   2:8           6
# 54       exploit   2:8           6
# 32       contest   2:8           6
# 77          lead   2:9           7
# 103      recount   3:7           4
# 119    transform   3:7           4
# 19        celtic   3:7           4
# 73        invert   3:7           4
# 16       blessed   4:5           1
# 36    coordinate   4:5           1
# 9        animate   4:6           2
# 38      decrease   4:6           2
# 44       diffuse   4:6           2
# 113          sow   4:6           2
# 118         tear   4:6           2
# 115   supplement   4:6           2
# 123          use   4:6           2
# 127        wound   4:6           2
# 66      increase   4:6           2
# 80         lives   4:6           2
# 79          live   4:6           2
# 86     overthrow   4:6           2
# 33      converse   4:6           2
# 11    articulate   4:6           2
# 93     postulate   4:6           2
# 90        permit   4:6           2
# 17           bow   4:6           2
# 13     attribute   4:6           2
# 94   precipitate   4:6           2
# 57       extract   5:5           0
# 24       conduct   5:5           0
# 14          axes   5:5           0
# 69        insert   5:5           0
# 30    consummate   5:5           0
# 99          read   6:6           0

# %%
ratios_df.to_latex(index=False,longtable=True, buf='final_dev_class_ratios', caption='Final WHD Dev split class ratios and differences', label='whdfinaldevclassratios')

# %%
len(ratios_df[ratios_df["difference"] <= 1]) / len(ratios_df)
# Out:
# 0.0625

# %%
len(ratios_df[(ratios_df["difference"] > 1) & (ratios_df["difference"] <= 2)]) / len(ratios_df)
# Out:
# 0.1484375

# %%
len(ratios_df[(ratios_df["difference"] > 2) & (ratios_df["difference"] <= 3)]) / len(ratios_df)
# Out:
# 0.0

# %%
len(ratios_df[(ratios_df["difference"] > 3) & (ratios_df["difference"] <= 4)]) / len(ratios_df)
# Out:
# 0.03125

# %%
len(ratios_df[(ratios_df["difference"] > 4) & (ratios_df["difference"] <= 5)]) / len(ratios_df)
# Out:
# 0.0390625

# %%
len(ratios_df[(ratios_df["difference"] > 5) & (ratios_df["difference"] <= 6)]) / len(ratios_df)
# Out:
# 0.2421875

# %%
len(ratios_df[(ratios_df["difference"] > 6) & (ratios_df["difference"] <= 7)]) / len(ratios_df)
# Out:
# 0.015625

# %%
len(ratios_df[(ratios_df["difference"] > 7) & (ratios_df["difference"] <= 8)]) / len(ratios_df)
# Out:
# 0.1875

# %%
len(ratios_df[(ratios_df["difference"] > 8) & (ratios_df["difference"] <= 9)]) / len(ratios_df)
# Out:
# 0.2734375

# %%
len(ratios_df[(ratios_df["difference"] > 9) & (ratios_df["difference"] <= 10)]) / len(ratios_df)
# Out:
# 0.0

# %% [markdown]
# # TEST

# %%
dfs = []
for f in tqdm(glob(TEST +'*.tsv')):
    df = pd.read_table(f)
    dfs.append(df)

test_df = pd.concat(dfs)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 128/128 [00:00<00:00, 875.72it/s]

# %%
test_df.head()
# Out:
#   homograph     wordid                                           sentence  \
# 0     abuse  abuse_nou  He has worked to fund public education and to ...
# 1     abuse  abuse_nou  Despite his history of child sexual abuse agai...
# 2     abuse  abuse_nou  Allegations included rape, sodomy, fellatio an...
# 3     abuse  abuse_nou  In the hearse with Charlie he discusses the ab...
# 4     abuse  abuse_nou  Jersey Police have so far recorded claims of a...
#
#    start  end  orig_idx
# 0     65   70        47
# 1     36   41     11439
# 2     94   99        55
# 3     44   49     11443
# 4     45   50        20

# %%
test_df.groupby('homograph')['wordid'].nunique().sort_values()
# Out:
# homograph
# abuse          2
# postulate      2
# polish         2
# pervert        2
# permit         2
# perfume        2
# perfect        2
# pasty          2
# overthrow      2
# ornament       2
# nestle         2
# mobile         2
# misuse         2
# minute         2
# precipitate    2
# lives          2
# learned        2
# lead           2
# laminate       2
# isolate        2
# invite         2
# invert         2
# invalid        2
# intrigue       2
# insult         2
# insert         2
# initiate       2
# increment      2
# increase       2
# live           2
# incline        2
# present        2
# progress       2
# wind           2
# uses           2
# use            2
# upset          2
# transport      2
# transplant     2
# transform      2
# tear           2
# syndicate      2
# suspect        2
# supplement     2
# subordinate    2
# sow            2
# produce        2
# separate       2
# rodeo          2
# retard         2
# resume         2
# rerelease      2
# reject         2
# refuse         2
# refund         2
# recount        2
# record         2
# rebel          2
# reading        2
# read           2
# protest        2
# sake           2
# import         2
# implement      2
# implant        2
# conscript      2
# conjugate      2
# conflict       2
# confines       2
# conduct        2
# compress       2
# compound       2
# combine        2
# close          2
# celtic         2
# buffet         2
# bow            2
# blessed        2
# construct      2
# bass           2
# attribute      2
# associate      2
# articulate     2
# approximate    2
# animate        2
# analyses       2
# alternate      2
# aggregate      2
# aged           2
# affiliate      2
# affect         2
# advocate       2
# abuses         2
# axes           2
# consummate     2
# content        2
# contest        2
# impact         2
# graduate       2
# frequent       2
# fragment       2
# extract        2
# expose         2
# export         2
# exploit        2
# excuse         2
# estimate       2
# escort         2
# duplicate      2
# dove           2
# document       2
# discount       2
# discharge      2
# discard        2
# diffuse        2
# diagnoses      2
# deliberate     2
# delegate       2
# degenerate     2
# defect         2
# decrease       2
# correlate      2
# coordinate     2
# convict        2
# convert        2
# converse       2
# winds          2
# wound          2
# Name: wordid, dtype: int64

# %%
hids = []
for idx, group in test_df.groupby('homograph'):
    #print(idx)
    ttl = 0
    grp = []
    for wordid in group['wordid'].unique():
        homograph_wordid = {}
        homograph_wordid['homograph'] = idx
        homograph_wordid["wordid"] = wordid
        count = len(group[group['wordid'] == wordid])
        homograph_wordid["wordid_count"] = count
        #print("{}:{}".format(wordid, count))
        grp.append(homograph_wordid)
        ttl += count
    hid_df = pd.DataFrame(grp)    
    hid_df["ttl"] = ttl
    hids.append(hid_df)
    #print("\n")
hids_df = pd.concat(hids)
hids_df["percent_ttl"] = hids_df['wordid_count']/hids_df["ttl"]
print(hids_df)
# Out:
#      homograph                 wordid  wordid_count  ttl  percent_ttl
# 0        abuse              abuse_nou             9   10     0.900000
# 1        abuse              abuse_vrb             1   10     0.100000
# 0       abuses             abuses_nou             9   10     0.900000
# 1       abuses             abuses_vrb             1   10     0.100000
# 0     advocate           advocate_nou             9   10     0.900000
# 1     advocate           advocate_vrb             1   10     0.100000
# 0       affect                 affect             9   10     0.900000
# 1       affect         affect_nou-psy             1   10     0.100000
# 0    affiliate          affiliate_nou             9   10     0.900000
# 1    affiliate          affiliate_vrb             1   10     0.100000
# 0         aged                   aged             9   10     0.900000
# 1         aged               aged_adj             1   10     0.100000
# 0    aggregate      aggregate_adj-nou             9   10     0.900000
# 1    aggregate          aggregate_vrb             1   10     0.100000
# 0    alternate      alternate_adj-nou             9   10     0.900000
# 1    alternate          alternate_vrb             1   10     0.100000
# 0     analyses           analyses_nou             9   10     0.900000
# 1     analyses           analyses_vrb             1   10     0.100000
# 0      animate        animate_adj-nou             3    9     0.333333
# 1      animate            animate_vrb             6    9     0.666667
# 0  approximate    approximate_adj-nou             9   10     0.900000
# 1  approximate        approximate_vrb             1   10     0.100000
# 0   articulate         articulate_adj             5   10     0.500000
# 1   articulate         articulate_vrb             5   10     0.500000
# 0    associate      associate_adj-nou             9   10     0.900000
# 1    associate          associate_vrb             1   10     0.100000
# 0    attribute          attribute_nou             5   10     0.500000
# 1    attribute          attribute_vrb             5   10     0.500000
# 0         axes               axes_nou             5   10     0.500000
# 1         axes           axes_nou-vrb             5   10     0.500000
# 0         bass                   bass             9   10     0.900000
# 1         bass              bass_corp             1   10     0.100000
# 0      blessed            blessed_adj             5   10     0.500000
# 1      blessed            blessed_vrb             5   10     0.500000
# 0          bow           bow_nou-knot             5   10     0.500000
# 1          bow           bow_nou-ship             5   10     0.500000
# 0       buffet             buffet_nou             9   10     0.900000
# 1       buffet             buffet_vrb             1   10     0.100000
# 0       celtic                 celtic             7   10     0.700000
# 1       celtic  celtic_adj-nou-sports             3   10     0.300000
# 0        close          close_adj-nou             9   10     0.900000
# 1        close              close_vrb             1   10     0.100000
# 0      combine            combine_nou             1   10     0.100000
# 1      combine            combine_vrb             9   10     0.900000
# 0     compound           compound_nou             9   10     0.900000
# 1     compound           compound_vrb             1   10     0.100000
# 0     compress               compress             9   10     0.900000
# 1     compress           compress_nou             1   10     0.100000
# 0      conduct            conduct_nou             5   10     0.500000
# 1      conduct            conduct_vrb             5   10     0.500000
# 0     confines           confines_nou             7    9     0.777778
# 1     confines           confines_vrb             2    9     0.222222
# 0     conflict           conflict_nou             9   10     0.900000
# 1     conflict           conflict_vrb             1   10     0.100000
# 0    conjugate      conjugate_adj-nou             9   10     0.900000
# 1    conjugate          conjugate_vrb             1   10     0.100000
# 0    conscript          conscript_nou             9   10     0.900000
# 1    conscript          conscript_vrb             1   10     0.100000
# 0    construct          construct_nou             1   10     0.100000
# 1    construct          construct_vrb             9   10     0.900000
# 0   consummate         consummate_adj             5   10     0.500000
# 1   consummate         consummate_vrb             5   10     0.500000
# 0      content    content_adj-nou-vrb             1   10     0.100000
# 1      content            content_nou             9   10     0.900000
# 0      contest            contest_nou             9   10     0.900000
# 1      contest            contest_vrb             1   10     0.100000
# 0     converse       converse_adj-nou             7   10     0.700000
# 1     converse           converse_vrb             3   10     0.300000
# 0      convert            convert_nou             1   10     0.100000
# 1      convert            convert_vrb             9   10     0.900000
# 0      convict            convict_nou             9   10     0.900000
# 1      convict            convict_vrb             1   10     0.100000
# 0   coordinate     coordinate_adj-nou             5   10     0.500000
# 1   coordinate         coordinate_vrb             5   10     0.500000
# 0    correlate          correlate_nou             1   10     0.100000
# 1    correlate      correlate_nou-vrb             9   10     0.900000
# 0     decrease           decrease_nou             5   10     0.500000
# 1     decrease           decrease_vrb             5   10     0.500000
# 0       defect             defect_nou             9   10     0.900000
# 1       defect             defect_vrb             1   10     0.100000
# 0   degenerate     degenerate_adj-nou             9   10     0.900000
# 1   degenerate         degenerate_vrb             1   10     0.100000
# 0     delegate           delegate_nou             9   10     0.900000
# 1     delegate           delegate_vrb             1   10     0.100000
# 0   deliberate         deliberate_adj             9   10     0.900000
# 1   deliberate         deliberate_vrb             1   10     0.100000
# 0    diagnoses          diagnoses_nou             8   10     0.800000
# 1    diagnoses          diagnoses_vrb             2   10     0.200000
# 0      diffuse            diffuse_adj             7   10     0.700000
# 1      diffuse            diffuse_vrb             3   10     0.300000
# 0      discard            discard_nou             3   10     0.300000
# 1      discard            discard_vrb             7   10     0.700000
# 0    discharge          discharge_nou             9   10     0.900000
# 1    discharge          discharge_vrb             1   10     0.100000
# 0     discount           discount_nou             9   10     0.900000
# 1     discount           discount_vrb             1   10     0.100000
# 0     document           document_nou             9   10     0.900000
# 1     document           document_vrb             1   10     0.100000
# 0         dove                   dove             5    6     0.833333
# 1         dove               dove_vrb             1    6     0.166667
# 0    duplicate      duplicate_adj-nou             7   10     0.700000
# 1    duplicate          duplicate_vrb             3   10     0.300000
# 0       escort             escort_nou             9   10     0.900000
# 1       escort             escort_vrb             1   10     0.100000
# 0     estimate           estimate_nou             7   10     0.700000
# 1     estimate           estimate_vrb             3   10     0.300000
# 0       excuse             excuse_nou             8   10     0.800000
# 1       excuse             excuse_vrb             2   10     0.200000
# 0      exploit            exploit_nou             1   10     0.100000
# 1      exploit            exploit_vrb             9   10     0.900000
# 0       export             export_nou             9   10     0.900000
# 1       export             export_vrb             1   10     0.100000
# 0       expose             expose_nou             1   10     0.100000
# 1       expose             expose_vrb             9   10     0.900000
# 0      extract            extract_nou             5   10     0.500000
# 1      extract            extract_vrb             5   10     0.500000
# 0     fragment           fragment_nou             9   10     0.900000
# 1     fragment           fragment_vrb             1   10     0.100000
# 0     frequent           frequent_adj             9   10     0.900000
# 1     frequent           frequent_vrb             1   10     0.100000
# 0     graduate       graduate_adj-nou             9   10     0.900000
# 1     graduate           graduate_vrb             1   10     0.100000
# 0       impact             impact_nou             9   10     0.900000
# 1       impact             impact_vrb             1   10     0.100000
# 0      implant            implant_nou             9   10     0.900000
# 1      implant            implant_vrb             1   10     0.100000
# 0    implement          implement_nou             1   10     0.100000
# 1    implement          implement_vrb             9   10     0.900000
# 0       import             import_nou             7   10     0.700000
# 1       import             import_vrb             3   10     0.300000
# 0      incline            incline_nou             9   10     0.900000
# 1      incline            incline_vrb             1   10     0.100000
# 0     increase           increase_nou             5   10     0.500000
# 1     increase           increase_vrb             5   10     0.500000
# 0    increment          increment_nou             9   10     0.900000
# 1    increment          increment_vrb             1   10     0.100000
# 0     initiate           initiate_nou             1   10     0.100000
# 1     initiate           initiate_vrb             9   10     0.900000
# 0       insert             insert_nou             5   10     0.500000
# 1       insert             insert_vrb             5   10     0.500000
# 0       insult             insult_nou             7   10     0.700000
# 1       insult             insult_vrb             3   10     0.300000
# 0     intrigue           intrigue_nou             9   10     0.900000
# 1     intrigue       intrigue_nou-vrb             1   10     0.100000
# 0      invalid            invalid_adj             7   10     0.700000
# 1      invalid            invalid_nou             3   10     0.300000
# 0       invert         invert_adj-nou             3   10     0.300000
# 1       invert             invert_vrb             7   10     0.700000
# 0       invite             invite_nou             2   10     0.200000
# 1       invite             invite_vrb             8   10     0.800000
# 0      isolate                isolate             8   10     0.800000
# 1      isolate            isolate_nou             2   10     0.200000
# 0     laminate           laminate_nou             9   10     0.900000
# 1     laminate           laminate_vrb             1   10     0.100000
# 0         lead               lead_nou             3   12     0.250000
# 1         lead           lead_nou-vrb             9   12     0.750000
# 0      learned            learned_adj             1   10     0.100000
# 1      learned            learned_vrb             9   10     0.900000
# 0         live               live_adj             6    9     0.666667
# 1         live               live_vrb             3    9     0.333333
# 0        lives              lives_nou             3   10     0.300000
# 1        lives              lives_vrb             7   10     0.700000
# 0       minute                 minute             9   10     0.900000
# 1       minute             minute_adj             1   10     0.100000
# 0       misuse             misuse_nou             9   10     0.900000
# 1       misuse             misuse_vrb             1   10     0.100000
# 0       mobile                 mobile             9   10     0.900000
# 1       mobile             mobile_geo             1   10     0.100000
# 0       nestle             nestle_nam             7    8     0.875000
# 1       nestle             nestle_vrb             1    8     0.125000
# 0     ornament           ornament_nou             9   10     0.900000
# 1     ornament           ornament_vrb             1   10     0.100000
# 0    overthrow          overthrow_nou             3   10     0.300000
# 1    overthrow          overthrow_vrb             7   10     0.700000
# 0        pasty              pasty_adj             7   10     0.700000
# 1        pasty              pasty_nou             3   10     0.300000
# 0      perfect            perfect_adj             9   10     0.900000
# 1      perfect            perfect_vrb             1   10     0.100000
# 0      perfume            perfume_nou             9   10     0.900000
# 1      perfume            perfume_vrb             1   10     0.100000
# 0       permit             permit_nou             5   10     0.500000
# 1       permit             permit_vrb             5   10     0.500000
# 0      pervert            pervert_nou             7   10     0.700000
# 1      pervert            pervert_vrb             3   10     0.300000
# 0       polish                 polish             1   10     0.100000
# 1       polish             polish_geo             9   10     0.900000
# 0    postulate          postulate_nou             7   10     0.700000
# 1    postulate          postulate_vrb             3   10     0.300000
# 0  precipitate    precipitate_adj-nou             4   10     0.400000
# 1  precipitate        precipitate_vrb             6   10     0.600000
# 0      present        present_adj-nou             9   10     0.900000
# 1      present            present_vrb             1   10     0.100000
# 0      produce            produce_nou             1   10     0.100000
# 1      produce            produce_vrb             9   10     0.900000
# 0     progress           progress_nou             8   10     0.800000
# 1     progress           progress_vrb             2   10     0.200000
# 0      protest            protest_nou             9   10     0.900000
# 1      protest            protest_vrb             1   10     0.100000
# 0         read              read_past             6   13     0.461538
# 1         read           read_present             7   13     0.538462
# 0      reading             reading_en             8   10     0.800000
# 1      reading            reading_geo             2   10     0.200000
# 0        rebel              rebel_nou             9   10     0.900000
# 1        rebel              rebel_vrb             1   10     0.100000
# 0       record             record_nou             9   10     0.900000
# 1       record             record_vrb             1   10     0.100000
# 0      recount            recount_nou             7   10     0.700000
# 1      recount            recount_vrb             3   10     0.300000
# 0       refund             refund_nou             7   10     0.700000
# 1       refund             refund_vrb             3   10     0.300000
# 0       refuse             refuse_nou             1   10     0.100000
# 1       refuse             refuse_vrb             9   10     0.900000
# 0       reject             reject_nou             1   10     0.100000
# 1       reject             reject_vrb             9   10     0.900000
# 0    rerelease              rerelease             9   10     0.900000
# 1    rerelease          rerelease_vrb             1   10     0.100000
# 0       resume             resume_nou             1   10     0.100000
# 1       resume             resume_vrb             9   10     0.900000
# 0       retard             retard_nou             1    9     0.111111
# 1       retard             retard_vrb             8    9     0.888889
# 0        rodeo                  rodeo             9   10     0.900000
# 1        rodeo              rodeo_geo             1   10     0.100000
# 0         sake                   sake             9   10     0.900000
# 1         sake                sake_jp             1   10     0.100000
# 0     separate           separate_adj             9   10     0.900000
# 1     separate           separate_vrb             1   10     0.100000
# 0          sow                    sow             6    9     0.666667
# 1          sow                sow_nou             3    9     0.333333
# 0  subordinate    subordinate_adj-nou             9   10     0.900000
# 1  subordinate        subordinate_vrb             1   10     0.100000
# 0   supplement         supplement_nou             7   10     0.700000
# 1   supplement         supplement_vrb             3   10     0.300000
# 0      suspect        suspect_adj-nou             7   10     0.700000
# 1      suspect            suspect_vrb             3   10     0.300000
# 0    syndicate          syndicate_nou             9   10     0.900000
# 1    syndicate          syndicate_vrb             1   10     0.100000
# 0         tear               tear_nou             3   10     0.300000
# 1         tear               tear_vrb             7   10     0.700000
# 0    transform              transform             7   10     0.700000
# 1    transform          transform_nou             3   10     0.300000
# 0   transplant         transplant_nou             9   10     0.900000
# 1   transplant         transplant_vrb             1   10     0.100000
# 0    transport          transport_nou             9   10     0.900000
# 1    transport          transport_vrb             1   10     0.100000
# 0        upset              upset_nou             7   10     0.700000
# 1        upset              upset_vrb             3   10     0.300000
# 0          use                use_nou             6   11     0.545455
# 1          use                use_vrb             5   11     0.454545
# 0         uses               uses_nou             1   10     0.100000
# 1         uses               uses_vrb             9   10     0.900000
# 0         wind               wind_nou             9   10     0.900000
# 1         wind               wind_vrb             1   10     0.100000
# 0        winds              winds_nou             9   10     0.900000
# 1        winds              winds_vrb             1   10     0.100000
# 0        wound          wound_nou-vrb             7   10     0.700000
# 1        wound              wound_vrb             3   10     0.300000

# %%
hids_df.ttl.mean()
# Out:
# 9.9609375

# %%
ratios = []
for i, grp in hids_df.groupby('homograph'): 
    ratio = {}
    counts = []
    ratio['homograph'] = i
    for wdid in grp['wordid']:
        counts.append(grp[grp['wordid'] == wdid]['wordid_count'].item())
    counts.sort()
    print(counts)
    gcd = math.gcd(counts[0], counts[1])
    print(gcd)
    ratio["ratio"] = str(counts[0]) + ":" + str(counts[1]) 
    #ratio["ratio"] = (counts[0]) / (counts[1])
    ratio["difference"] = counts[1] - counts[0]
    #ratio["percent_difference"] = ((counts[1] - counts[0]) / (counts[1] + counts[0]))*100
    ratios.append(ratio)
ratios
ratios_df = pd.DataFrame(ratios)
ratios_df.sort_values(by='ratio')
# Out:
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [3, 6]
# 3
# [1, 9]
# 1
# [5, 5]
# 5
# [1, 9]
# 1
# [5, 5]
# 5
# [5, 5]
# 5
# [1, 9]
# 1
# [5, 5]
# 5
# [5, 5]
# 5
# [1, 9]
# 1
# [3, 7]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [5, 5]
# 5
# [2, 7]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [5, 5]
# 5
# [1, 9]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [5, 5]
# 5
# [1, 9]
# 1
# [5, 5]
# 5
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [2, 8]
# 2
# [3, 7]
# 1
# [3, 7]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 5]
# 1
# [3, 7]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [2, 8]
# 2
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [5, 5]
# 5
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [1, 9]
# 1
# [5, 5]
# 5
# [1, 9]
# 1
# [1, 9]
# 1
# [5, 5]
# 5
# [3, 7]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [3, 7]
# 1
# [2, 8]
# 2
# [2, 8]
# 2
# [1, 9]
# 1
# [3, 9]
# 3
# [1, 9]
# 1
# [3, 6]
# 3
# [3, 7]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 7]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [3, 7]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [5, 5]
# 5
# [3, 7]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [4, 6]
# 2
# [1, 9]
# 1
# [1, 9]
# 1
# [2, 8]
# 2
# [1, 9]
# 1
# [6, 7]
# 1
# [2, 8]
# 2
# [1, 9]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [3, 7]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 8]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [3, 6]
# 3
# [1, 9]
# 1
# [3, 7]
# 1
# [3, 7]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [3, 7]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
# [5, 6]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [1, 9]
# 1
# [3, 7]
# 1
#        homograph ratio  difference
# 49          dove   1:5           4
# 84        nestle   1:7           6
# 109       retard   1:8           7
# 82        misuse   1:9           8
# 81        minute   1:9           8
# 78       learned   1:9           8
# 76      laminate   1:9           8
# 71      intrigue   1:9           8
# 68      initiate   1:9           8
# 67     increment   1:9           8
# 65       incline   1:9           8
# 126        winds   1:9           8
# 0          abuse   1:9           8
# 61        impact   1:9           8
# 60      graduate   1:9           8
# 59      frequent   1:9           8
# 58      fragment   1:9           8
# 56        expose   1:9           8
# 55        export   1:9           8
# 54       exploit   1:9           8
# 51        escort   1:9           8
# 83        mobile   1:9           8
# 62       implant   1:9           8
# 85      ornament   1:9           8
# 88       perfect   1:9           8
# 125         wind   1:9           8
# 124         uses   1:9           8
# 121    transport   1:9           8
# 120   transplant   1:9           8
# 117    syndicate   1:9           8
# 114  subordinate   1:9           8
# 112     separate   1:9           8
# 111         sake   1:9           8
# 110        rodeo   1:9           8
# 48      document   1:9           8
# 108       resume   1:9           8
# 106       reject   1:9           8
# 105       refuse   1:9           8
# 102       record   1:9           8
# 101        rebel   1:9           8
# 98       protest   1:9           8
# 96       produce   1:9           8
# 95       present   1:9           8
# 92        polish   1:9           8
# 89       perfume   1:9           8
# 107    rerelease   1:9           8
# 47      discount   1:9           8
# 63     implement   1:9           8
# 18        buffet   1:9           8
# 26      conflict   1:9           8
# 27     conjugate   1:9           8
# 10   approximate   1:9           8
# 23      compress   1:9           8
# 28     conscript   1:9           8
# 46     discharge   1:9           8
# 29     construct   1:9           8
# 8       analyses   1:9           8
# 7      alternate   1:9           8
# 6      aggregate   1:9           8
# 22      compound   1:9           8
# 31       content   1:9           8
# 32       contest   1:9           8
# 5           aged   1:9           8
# 15          bass   1:9           8
# 21       combine   1:9           8
# 35       convict   1:9           8
# 1         abuses   1:9           8
# 2       advocate   1:9           8
# 42    deliberate   1:9           8
# 41      delegate   1:9           8
# 34       convert   1:9           8
# 40    degenerate   1:9           8
# 12     associate   1:9           8
# 39        defect   1:9           8
# 4      affiliate   1:9           8
# 37     correlate   1:9           8
# 20         close   1:9           8
# 3         affect   1:9           8
# 25      confines   2:7           5
# 97      progress   2:8           6
# 75       isolate   2:8           6
# 53        excuse   2:8           6
# 100      reading   2:8           6
# 43     diagnoses   2:8           6
# 74        invite   2:8           6
# 113          sow   3:6           3
# 9        animate   3:6           3
# 79          live   3:6           3
# 104       refund   3:7           4
# 115   supplement   3:7           4
# 116      suspect   3:7           4
# 103      recount   3:7           4
# 118         tear   3:7           4
# 119    transform   3:7           4
# 122        upset   3:7           4
# 45       discard   3:7           4
# 87         pasty   3:7           4
# 72       invalid   3:7           4
# 44       diffuse   3:7           4
# 50     duplicate   3:7           4
# 52      estimate   3:7           4
# 64        import   3:7           4
# 33      converse   3:7           4
# 70        insult   3:7           4
# 19        celtic   3:7           4
# 73        invert   3:7           4
# 80         lives   3:7           4
# 127        wound   3:7           4
# 91       pervert   3:7           4
# 93     postulate   3:7           4
# 86     overthrow   3:7           4
# 77          lead   3:9           6
# 94   precipitate   4:6           2
# 30    consummate   5:5           0
# 90        permit   5:5           0
# 69        insert   5:5           0
# 66      increase   5:5           0
# 24       conduct   5:5           0
# 16       blessed   5:5           0
# 36    coordinate   5:5           0
# 38      decrease   5:5           0
# 57       extract   5:5           0
# 13     attribute   5:5           0
# 17           bow   5:5           0
# 14          axes   5:5           0
# 11    articulate   5:5           0
# 123          use   5:6           1
# 99          read   6:7           1

# %%
ratios_df.to_latex(index=False,longtable=True, buf='final_test_class_ratios', caption='Final WHD Test split class ratios and differences', label='whdfinaltestclassratios')

# %%
len(ratios_df[ratios_df["difference"] <= 1]) / len(ratios_df)
# Out:
# 0.1171875

# %%
len(ratios_df[(ratios_df["difference"] > 1) & (ratios_df["difference"] <= 2)]) / len(ratios_df)
# Out:
# 0.0078125

# %%
len(ratios_df[(ratios_df["difference"] > 2) & (ratios_df["difference"] <= 3)]) / len(ratios_df)
# Out:
# 0.0234375

# %%
len(ratios_df[(ratios_df["difference"] > 3) & (ratios_df["difference"] <= 4)]) / len(ratios_df)
# Out:
# 0.1875

# %%
len(ratios_df[(ratios_df["difference"] > 4) & (ratios_df["difference"] <= 5)]) / len(ratios_df)
# Out:
# 0.0078125

# %%
len(ratios_df[(ratios_df["difference"] > 5) & (ratios_df["difference"] <= 6)]) / len(ratios_df)
# Out:
# 0.0625

# %%
len(ratios_df[(ratios_df["difference"] > 6) & (ratios_df["difference"] <= 7)]) / len(ratios_df)
# Out:
# 0.0078125

# %%
len(ratios_df[(ratios_df["difference"] > 7) & (ratios_df["difference"] <= 8)]) / len(ratios_df)
# Out:
# 0.5859375

# %%
len(ratios_df[ratios_df["difference"] == 8]) / len(ratios_df)
# Out:
# 0.5859375

# %%
len(ratios_df[(ratios_df["difference"] > 8) & (ratios_df["difference"] <= 9)]) / len(ratios_df)
# Out:
# 0.0

# %%
len(ratios_df[(ratios_df["difference"] > 9) & (ratios_df["difference"] <= 10)]) / len(ratios_df)
# Out:
# 0.0

# %% [markdown]
# # Split counts and percents

# %%
total = len(train_df) + len(dev_df) + len(test_df)
total
# Out:
# 12714

# %%
print(len(train_df))
print(train_df.homograph.nunique())
print(train_df.wordid.nunique())
print(len(train_df)/total)
# Out:
# 10131
# 128
# 256
# 0.7968381311939594

# %%
print(len(dev_df))
print(dev_df.homograph.nunique())
print(dev_df.wordid.nunique())
print(len(dev_df)/total)
# Out:
# 1308
# 128
# 256
# 0.1028787163756489

# %%
print(len(test_df))
print(test_df.homograph.nunique())
print(test_df.wordid.nunique())
print(len(test_df)/total)
# Out:
# 1275
# 128
# 256
# 0.1002831524303917
